# %% [markdown]
# # Georeferenciación Galeria Inmobiliaria

# %% [markdown]
# ## Cargue de librerías

# %% [markdown]
# En esta sección se realiza el cargue de las librerías necesarias para el procesamiento de los datos

# %%
import pandas as pd
import requests
import json
import time
import swifter
import geopandas as gpd
from shapely.geometry import Point
import shapely.wkt
import matplotlib
import unicodedata

# %% [markdown]
# ## Configuración y parametrización

# %% [markdown]
# En esta sección se definen los parámetros básicos de visualización de los dataframes, se establecen las direcciones de los servicios web a consumir y se definen las variables para establecer las hojas de interés dentro de cada archivo y los campos a georeferenciar en cada caso.

# %%
pd.set_option('display.max_columns', None)

# %%
#URL geocodificador
url = "https://catalogopmb.catastrobogota.gov.co/PMBWeb/web/api"

# %%
path_vivienda_usada = 'MAYO/Bogota_Programa_Vivienda_Usada_05-23.xlsb'
sheets_vivienda_usada = ['Sop. Venta', 'Sop. Arriendos']
vivienda_usada_dir = 'Dirección Nueva' 
path_comercio = 'MAYO/Bogota_Comercio_Def_05-23.xlsb'
sheets_comercio = ['Base Proyecto', 'Base Inmuebles', 'Base Historia']
comercio_dir = 'Dirección'
path_def = 'MAYO/Bogota_Def_05-23.xlsb'
sheets_def = ['Base Proyectos']
def_dir = 'Dirección'

# %% [markdown]
# ## Cargue de insumos

# %% [markdown]
# En esta sección se realiza el cargue de los diferentes insumos para su posterior procesamiento. Adicionalmente, se parametrizan las funciones de cargue a partir de la estructura y definición de cada una de las fuentes.

# %%
df_vivienda_usada_venta = pd.read_excel(path_vivienda_usada, sheet_name=sheets_vivienda_usada[0], skiprows=4)

# %%
df_vivienda_usada_arriendo = pd.read_excel(path_vivienda_usada, sheet_name=sheets_vivienda_usada[1], skiprows=4)

# %%
df_comercio_base_proyecto = pd.read_excel(path_comercio, sheet_name=sheets_comercio[0])

# %%
df_comercio_base_inmuebles = pd.read_excel(path_comercio, sheet_name=sheets_comercio[1])
df_comercio_base_inmuebles = df_comercio_base_inmuebles.drop([0])

# %%
df_comercio_base_historia = pd.read_excel(path_comercio, sheet_name=sheets_comercio[2])

# %%
df_def_base_proyecto = pd.read_excel(path_def, sheet_name=sheets_def[0])

# %% [markdown]
# ## Funciones

# %% [markdown]
# En esta sección se definen las funciones que se van a utilizar para el procesamiento de los datos

# %% [markdown]
# ### Función georeferenciar

# %% [markdown]
# La función georeferenciar se encarga de obtener a partir del uso de un servicio web externo las coordenadas geográficas de una dirección entregada por parámetro.

# %%
def georeferenciar(input_str:str):
    """
    Realiza la georreferenciación de una cadena de entrada utilizando una API de geocodificación.

    Args:
        input_str (str): La cadena a georreferenciar.

    Returns:
        dict: Un diccionario que contiene los datos de georreferenciación si la operación fue exitosa.
              En caso contrario, devuelve un diccionario que indica un estado de falla o un estado de error.

    """
    direc = unicodedata.normalize("NFKD", input_str).encode("ascii","ignore").decode("ascii").lower()
    val = [True for t in direc.replace('.','').split() if t in ['km','chia','cota','tocancipa','tenjo','madrid','tabio,','cajica,','mosquera','zipaquira']]
    if sum(val)>=1:
        return {'estado': 'outside_bogota'}
    else:
        try:
            params = {
                'cmd': 'geocodificar',
                'apikey': '1c025f92-4520-49c1-90a7-a24b3d9d374c',
                'query': input_str
            }

            response = requests.get(url, params=params)
            res = response.json()
            success = res['response']['success']
            if success:
                data = res['response']['data']
                return data
            else:
                return {'estado': 'failed'}
        except:
            return {'estado': 'error_ws'}

# %%
def distance(p1: Point, p2: Point):
     """
    Calcula la distancia entre dos puntos geográficos.

    Args:
        p1 (Point): El primer punto geográfico en formato `Point`.
        p2 (Point): El segundo punto geográfico en formato `Point`.

    Returns:
        Series: Una serie que contiene la distancia entre los dos puntos en la proyección UTM.

    """
    gdf_1 = gpd.GeoDataFrame(geometry=[shapely.wkt.loads(str(p1))], crs="EPSG:4326")
    gdf_2 = gpd.GeoDataFrame(geometry=[shapely.wkt.loads(str(p2))], crs="EPSG:4326")
    utm = gdf_1.estimate_utm_crs()
    return gdf_1.to_crs(utm).distance(gdf_2.to_crs(utm))

# %% [markdown]
# ## Exploración

# %% [markdown]
# Para utilizar la función de georeferenciación se va a realizar un muestreo aleatorio de direcciones con el fin de evaluar la calidad de el API geográfico. Esta exploración va a permitir identificar que tipo de ajustes se deben realizar a las direcciones de las bases de datos a georeferenciar.

# %%
sample_1 = df_vivienda_usada_venta.sample(n=150, random_state=1)[vivienda_usada_dir].reset_index()
sample_1['addr'] = sample_1[vivienda_usada_dir]
sample_1['source']='df_vivienda_usada_venta'
del sample_1[vivienda_usada_dir]
del sample_1['index']
sample_1['geocode_result'] = sample_1['addr'].swifter.apply(georeferenciar)
# Out:
# Pandas Apply:   0%|          | 0/150 [00:00<?, ?it/s]

# %%
sample_1['estado'] = sample_1.apply(lambda x: json.loads(x['geocode_result'])['estado'] if type(x['geocode_result']) is str else x['geocode_result']['estado'], axis=1)
sample_1['tipo_direccion'] = sample_1.apply(lambda x: None if type(x['geocode_result']) is str else x['geocode_result']['tipo_direccion'], axis=1)
sample_1['lat'] = sample_1.apply(lambda x: None if type(x['geocode_result']) is str else x['geocode_result']['yinput'], axis=1)
sample_1['lng'] = sample_1.apply(lambda x: None if type(x['geocode_result']) is str else x['geocode_result']['xinput'], axis=1)

# %%
pd.set_option('display.max_rows', None)

# %%
sample_1
# Out:
#                                     addr                   source  \
# 0                         Cr. 37 # 57-44  df_vivienda_usada_venta
# 1                     Cr. 51 # 102A - 49  df_vivienda_usada_venta
# 2                          Cr. 6 # 80-23  df_vivienda_usada_venta
# 3                     Av. Cr. 9 # 104-07  df_vivienda_usada_venta
# 4                        Cr. 14 # 127-30  df_vivienda_usada_venta
# 5                       Cr. 14B # 119-71  df_vivienda_usada_venta
# 6                       Cr. 14A # 117-05  df_vivienda_usada_venta
# 7                      Cl. 134A # 19A-44  df_vivienda_usada_venta
# 8                    Av. Cl. 116 # 20-16  df_vivienda_usada_venta
# 9                          Cl. 78 # 7-79  df_vivienda_usada_venta
# 10                      Cr. 17a # 113-83  df_vivienda_usada_venta
# 11                       Cr. 9A # 119-30  df_vivienda_usada_venta
# 12                     Cl. 127A # 18B-37  df_vivienda_usada_venta
# 13                       Cl. 105 # 15-85  df_vivienda_usada_venta
# 14                   Av. Cr. 15 # 144-34  df_vivienda_usada_venta
# 15                      Cr. 23 # 104A-63  df_vivienda_usada_venta
# 16                     Cr. 11B # 134B-31  df_vivienda_usada_venta
# 17                   Cl. 127BBis # 19-65  df_vivienda_usada_venta
# 18                      Cr. 18C # 122-28  df_vivienda_usada_venta
# 19                       Cr. 9A # 113-87  df_vivienda_usada_venta
# 20                     Av. Cali # 23D-32  df_vivienda_usada_venta
# 21   Av. Cr.72 # 152 costado occidental   df_vivienda_usada_venta
# 22                       Cl. 144 # 12-19  df_vivienda_usada_venta
# 23                       Cr. 8A # 151-49  df_vivienda_usada_venta
# 24                     Cr. 52 # 106 - 67  df_vivienda_usada_venta
# 25                        Cr. 45 # 56-20  df_vivienda_usada_venta
# 26                       Cl. 159 # 17-94  df_vivienda_usada_venta
# 27                    Cr. 8 # 127C-56/60  df_vivienda_usada_venta
# 28                      Cl. 134A # 17-92  df_vivienda_usada_venta
# 29                 Av. Cl. 116 # 48 - 29  df_vivienda_usada_venta
# 30                       Cr. 14 # 149-30  df_vivienda_usada_venta
# 31                       Cl. 118 # 11-48  df_vivienda_usada_venta
# 32                   Cl. 123 # 10A-12/30  df_vivienda_usada_venta
# 33                   Av. Cl. 147 # 7F-74  df_vivienda_usada_venta
# 34                        Cr. 19 # 90-67  df_vivienda_usada_venta
# 35                     Tr. 59 # 104 - 65  df_vivienda_usada_venta
# 36                       Cl. 128 # 7A-05  df_vivienda_usada_venta
# 37                    Av. Cl. 147 # 9-60  df_vivienda_usada_venta
# 38                   Av. Cr. 72 # 24B-34  df_vivienda_usada_venta
# 39                   Av. Cl. 134 # 9A-96  df_vivienda_usada_venta
# 40                      Cl. 127B # 19-39  df_vivienda_usada_venta
# 41                      Cr. 56A # 148-87  df_vivienda_usada_venta
# 42                     Av. Cl. 116 #9-46  df_vivienda_usada_venta
# 43                       Cl. 145 # 21-76  df_vivienda_usada_venta
# 44                    Av. Cr. 19 # 98-21  df_vivienda_usada_venta
# 45                       Cr. 57 # 22B-70  df_vivienda_usada_venta
# 46                       Cl. 132 # 20-31  df_vivienda_usada_venta
# 47                       Cl. 142 # 13-30  df_vivienda_usada_venta
# 48                       Cl. 109 # 11-55  df_vivienda_usada_venta
# 49                     Cl. 115 # 54 - 88  df_vivienda_usada_venta
# 50                      Cr. 7C # 130A-69  df_vivienda_usada_venta
# 51                       Cl. 109 # 21-57  df_vivienda_usada_venta
# 52                      Cl. 135C # 9A-71  df_vivienda_usada_venta
# 53                         Cr. 3 # 76-80  df_vivienda_usada_venta
# 54                  Av. Cl. 116 # 14A-64  df_vivienda_usada_venta
# 55                      Cr. 12C # 151-35  df_vivienda_usada_venta
# 56                      Cl. 127D # 19-88  df_vivienda_usada_venta
# 57                        Tr. 20 # 94-25  df_vivienda_usada_venta
# 58                        Cl. 55 # 4A-24  df_vivienda_usada_venta
# 59                       Cr. 19C # 85-34  df_vivienda_usada_venta
# 60                       Cl. 144 # 13-35  df_vivienda_usada_venta
# 61                         Cr. 8 # 89-16  df_vivienda_usada_venta
# 62                       Cr. 8 # 127C-94  df_vivienda_usada_venta
# 63                       Cr. 14 # 151-60  df_vivienda_usada_venta
# 64                        Cl. 60 # 45-33  df_vivienda_usada_venta
# 65                      Cl. 118A # 14-20  df_vivienda_usada_venta
# 66                      Cl. 128A # 18-48  df_vivienda_usada_venta
# 67                       Cl. 149 # 45-84  df_vivienda_usada_venta
# 68                         Cr. 6 # 55-52  df_vivienda_usada_venta
# 69                       Cl. 146 # 19-69  df_vivienda_usada_venta
# 70                      Cl. 120 # 15a-44  df_vivienda_usada_venta
# 71                       Cl. 102 # 15-58  df_vivienda_usada_venta
# 72                      Cr. 59A # 136-50  df_vivienda_usada_venta
# 73              Cr. 17 # 145A-16/ 24/ 38  df_vivienda_usada_venta
# 74                        Cl. 80 # 10-23  df_vivienda_usada_venta
# 75                       Cl. 81 # 19A-51  df_vivienda_usada_venta
# 76                       Cr. 11B # 98-48  df_vivienda_usada_venta
# 77                       Dg. 17B # 90-53  df_vivienda_usada_venta
# 78                       Cr. 11 # 146-91  df_vivienda_usada_venta
# 79                     Cr. 52 # 106 - 33  df_vivienda_usada_venta
# 80                        Cr. 9A # 96-21  df_vivienda_usada_venta
# 81                       Cr. 7A # 148-59  df_vivienda_usada_venta
# 82                      Cl. 147A # 50-50  df_vivienda_usada_venta
# 83                      Cr. 7D # 127D-05  df_vivienda_usada_venta
# 84                      Cr. 17A # 137-34  df_vivienda_usada_venta
# 85                    Cr. 50 # 104B - 68  df_vivienda_usada_venta
# 86                   Av. Cr. 19 # 160-05  df_vivienda_usada_venta
# 87                       Cl. 148 # 13-15  df_vivienda_usada_venta
# 88                     Cl. 93Bis # 19-65  df_vivienda_usada_venta
# 89                     Cl. 136A # 58C-23  df_vivienda_usada_venta
# 90                      Cl. 145 # 13A-97  df_vivienda_usada_venta
# 91                      Cr. 12B # 137-27  df_vivienda_usada_venta
# 92                       Cr. 7B # 145-81  df_vivienda_usada_venta
# 93                       Cl. 145 # 13-60  df_vivienda_usada_venta
# 94                        Cr. 17 # 96-52  df_vivienda_usada_venta
# 95                       Cr. 18 # 137-24  df_vivienda_usada_venta
# 96                   Av. Cr. 15 # 127-66  df_vivienda_usada_venta
# 97                   Cr. 12 # 158A-16/50  df_vivienda_usada_venta
# 98                       Cl. 146 # 58-12  df_vivienda_usada_venta
# 99                       Cl. 22D # 72-41  df_vivienda_usada_venta
# 100                      Cr. 12 # 116-59  df_vivienda_usada_venta
# 101                       Cr. 7a # 90-33  df_vivienda_usada_venta
# 102                     Cl. 127B # 19-60  df_vivienda_usada_venta
# 103                      Cl. 145 # 17-75  df_vivienda_usada_venta
# 104                     Cr. 18B # 145-28  df_vivienda_usada_venta
# 105                      Cr. 55 # 153-15  df_vivienda_usada_venta
# 106                      Cl. 57B # 45-44  df_vivienda_usada_venta
# 107                      Cl. 130A #7B-44  df_vivienda_usada_venta
# 108                        Cr. 8 # 95-60  df_vivienda_usada_venta
# 109                      Cr. 21 # 102-35  df_vivienda_usada_venta
# 110                      Cr. 21 # 118-75  df_vivienda_usada_venta
# 111                     Cr. 54D # 134-21  df_vivienda_usada_venta
# 112                      Cr. 25 # 45C-35  df_vivienda_usada_venta
# 113                       Cl. 128 # 7-28  df_vivienda_usada_venta
# 114                    Cl. 145A # 13A-10  df_vivienda_usada_venta
# 115                     Cr. 48 # 150A-31  df_vivienda_usada_venta
# 116                       Cr. 16 # 88-22  df_vivienda_usada_venta
# 117                      Cl. 24A # 59-59  df_vivienda_usada_venta
# 118                  Cl. 140 # 13-66/ 72  df_vivienda_usada_venta
# 119                        Cr. 5 # 54-04  df_vivienda_usada_venta
# 120                       Cl. 151 # 8-84  df_vivienda_usada_venta
# 121                    Cl. 151 # 54A-41   df_vivienda_usada_venta
# 122                   Cr. 50 # 103B - 33  df_vivienda_usada_venta
# 123                   Cr. 51 # 104B - 22  df_vivienda_usada_venta
# 124                       Cr. 17 # 95-50  df_vivienda_usada_venta
# 125                     Cl. 101 # 11B-04  df_vivienda_usada_venta
# 126                      Cl. 118 # 12-25  df_vivienda_usada_venta
# 127                       Cr. 38 # 55-21  df_vivienda_usada_venta
# 128                      Cr. 57 # 159-11  df_vivienda_usada_venta
# 129                      Tr. 20 # 94A-49  df_vivienda_usada_venta
# 130                    Cl. 127A # 13A-50  df_vivienda_usada_venta
# 131                      Cl. 21 # 81B-30  df_vivienda_usada_venta
# 132                      Cr. 69B # 24-39  df_vivienda_usada_venta
# 133                      Cr. 16 # 110-20  df_vivienda_usada_venta
# 134                     Cl. 152A # 7H-11  df_vivienda_usada_venta
# 135                      Cl. 141 # 7B-19  df_vivienda_usada_venta
# 136                     Cl. 104 # 17a-65  df_vivienda_usada_venta
# 137                      Cl. 160 # 57-50  df_vivienda_usada_venta
# 138                  Av. Cl. 138 # 58-38  df_vivienda_usada_venta
# 139                        Cr. 9 # 85-75  df_vivienda_usada_venta
# 140                      Cl. 149 # 54-29  df_vivienda_usada_venta
# 141                      Cl. 150 # 53-28  df_vivienda_usada_venta
# 142                     Cr. 11a # 115-06  df_vivienda_usada_venta
# 143                     Cl. 123 # 11B-41  df_vivienda_usada_venta
# 144                    Cr. 58C # 134A-51  df_vivienda_usada_venta
# 145                     Cl. 120 # 11B-67  df_vivienda_usada_venta
# 146                       Cr. 8 # 151-03  df_vivienda_usada_venta
# 147                     Cl. 57A # 37A-27  df_vivienda_usada_venta
# 148                      Cl. 19A # 88-24  df_vivienda_usada_venta
# 149                Cr. 12A # 145A-22/ 32  df_vivienda_usada_venta
#
#                                         geocode_result   estado       lat  \
# 0    {'estado': 'success', 'yinput': 4.647198757000...  success  4.647199
# 1    {'estado': 'success', 'yinput': 4.690782262000...  success  4.690782
# 2    {'estado': 'success', 'yinput': 4.661167180000...  success  4.661167
# 3    {'estado': 'success', 'yinput': 4.687574692, '...  success  4.687575
# 4    {'estado': 'success', 'yinput': 4.704591983, '...  success  4.704592
# 5    {'estado': 'success', 'yinput': 4.700073057999...  success  4.700073
# 6    {'estado': 'success', 'yinput': 4.696824782000...  success  4.696825
# 7    {'estado': 'success', 'yinput': 4.719385480000...  success  4.719385
# 8    {'estado': 'success', 'yinput': 4.699111399, '...  success  4.699111
# 9    {'estado': 'success', 'yinput': 4.660600176999...  success  4.660600
# 10   {'estado': 'success', 'yinput': 4.697268000000...  success  4.697268
# 11   {'estado': 'success', 'yinput': 4.697365513000...  success  4.697366
# 12   {'estado': 'success', 'yinput': 4.707161273, '...  success  4.707161
# 13   {'estado': 'success', 'yinput': 4.690237735999...  success  4.690238
# 14   {'estado': 'success', 'yinput': 4.725617888999...  success  4.725618
# 15   {'estado': 'success', 'yinput': 4.692579706999...  success  4.692580
# 16   {'estado': 'success', 'yinput': 4.716190520999...  success  4.716191
# 17   {'estado': 'success', 'yinput': 4.709290135, '...  success  4.709290
# 18   {'estado': 'success', 'yinput': 4.701967067, '...  success  4.701967
# 19   {'estado': 'success', 'yinput': 4.693365423999...  success  4.693365
# 20   {'estado': 'success', 'yinput': 4.671235554000...  success  4.671236
# 21                                {"estado": "failed"}   failed       NaN
# 22   {'estado': 'success', 'yinput': 4.723209325000...  success  4.723209
# 23   {'estado': 'success', 'yinput': 4.728884064, '...  success  4.728884
# 24   {'estado': 'success', 'yinput': 4.695740709000...  success  4.695741
# 25   {'estado': 'success', 'yinput': 4.646413997000...  success  4.646414
# 26   {'estado': 'success', 'yinput': 4.738490661000...  success  4.738491
# 27   {'estado': 'success', 'yinput': 4.705277947000...  success  4.705278
# 28   {'estado': 'success', 'yinput': 4.718693902999...  success  4.718694
# 29   {'estado': 'success', 'yinput': 4.699985250999...  success  4.699985
# 30   {'estado': 'success', 'yinput': 4.729955233999...  success  4.729955
# 31   {'estado': 'success', 'yinput': 4.696680103000...  success  4.696680
# 32   {'estado': 'success', 'yinput': 4.700256846999...  success  4.700257
# 33   {'estado': 'success', 'yinput': 4.724913510000...  success  4.724914
# 34   {'estado': 'success', 'yinput': 4.676600929000...  success  4.676601
# 35   {'estado': 'success', 'yinput': 4.692529778999...  success  4.692530
# 36   {'estado': 'success', 'yinput': 4.707136911000...  success  4.707137
# 37   {'estado': 'success', 'yinput': 4.725767650000...  success  4.725768
# 38   {'estado': 'success', 'yinput': 4.662426326999...  success  4.662426
# 39   {'estado': 'success', 'yinput': 4.713628755999...  success  4.713629
# 40   {'estado': 'success', 'yinput': 4.708294371000...  success  4.708294
# 41   {'estado': 'success', 'yinput': 4.734399280999...  success  4.734399
# 42   {'estado': 'success', 'yinput': 4.694862597, '...  success  4.694863
# 43   {'estado': 'success', 'yinput': 4.727060830000...  success  4.727061
# 44   {'estado': 'success', 'yinput': 4.685130900999...  success  4.685131
# 45   {'estado': 'success', 'yinput': 4.642096417, '...  success  4.642096
# 46   {'estado': 'success', 'yinput': 4.716070484, '...  success  4.716070
# 47   {'estado': 'success', 'yinput': 4.722976475, '...  success  4.722976
# 48   {'estado': 'success', 'yinput': 4.690250408999...  success  4.690250
# 49   {'estado': 'success', 'yinput': 4.700553207999...  success  4.700553
# 50   {'estado': 'success', 'yinput': 4.70956938, 'l...  success  4.709569
# 51   {'estado': 'success', 'yinput': 4.696123412000...  success  4.696123
# 52   {'estado': 'success', 'yinput': 4.716097176999...  success  4.716097
# 53   {'estado': 'success', 'yinput': 4.657739363000...  success  4.657739
# 54   {'estado': 'success', 'yinput': 4.696392934000...  success  4.696393
# 55   {'estado': 'success', 'yinput': 4.729996965, '...  success  4.729997
# 56   {'estado': 'success', 'yinput': 4.711122634999...  success  4.711123
# 57   {'estado': 'success', 'yinput': 4.681896205999...  success  4.681896
# 58   {'estado': 'success', 'yinput': 4.640968754000...  success  4.640969
# 59   {'estado': 'success', 'yinput': 4.672392783000...  success  4.672393
# 60   {'estado': 'success', 'yinput': 4.724547744000...  success  4.724548
# 61   {'estado': 'success', 'yinput': 4.670127924999...  success  4.670128
# 62   {'estado': 'success', 'yinput': 4.707459438, '...  success  4.707459
# 63   {'estado': 'success', 'yinput': 4.731345003999...  success  4.731345
# 64   {'estado': 'success', 'yinput': 4.651322897999...  success  4.651323
# 65   {'estado': 'success', 'yinput': 4.697984878999...  success  4.697985
# 66   {'estado': 'success', 'yinput': 4.712104103, '...  success  4.712104
# 67   {'estado': 'success', 'yinput': 4.731448383999...  success  4.731448
# 68   {'estado': 'success', 'yinput': 4.641515055000...  success  4.641515
# 69   {'estado': 'success', 'yinput': 4.728482781000...  success  4.728483
# 70   {'estado': 'success', 'yinput': 4.699434804000...  success  4.699435
# 71   {'estado': 'success', 'yinput': 4.687216959000...  success  4.687217
# 72   {'estado': 'success', 'yinput': 4.727660715000...  success  4.727661
# 73   {'estado': 'success', 'yinput': 4.727662994000...  success  4.727663
# 74   {'estado': 'success', 'yinput': 4.663802162000...  success  4.663802
# 75   {'estado': 'success', 'yinput': 4.668511325, '...  success  4.668511
# 76   {'estado': 'success', 'yinput': 4.682076306999...  success  4.682076
# 77   {'estado': 'success', 'yinput': 4.665090013, '...  success  4.665090
# 78   {'estado': 'success', 'yinput': 4.725411844000...  success  4.725412
# 79   {'estado': 'success', 'yinput': 4.695312603999...  success  4.695313
# 80   {'estado': 'success', 'yinput': 4.678795439999...  success  4.678795
# 81   {'estado': 'success', 'yinput': 4.724661141000...  success  4.724661
# 82   {'estado': 'success', 'yinput': 4.731370938, '...  success  4.731371
# 83   {'estado': 'success', 'yinput': 4.707169979000...  success  4.707170
# 84   {'estado': 'success', 'yinput': 4.721684256999...  success  4.721684
# 85   {'estado': 'success', 'yinput': 4.694371712000...  success  4.694372
# 86   {'estado': 'success', 'yinput': 4.740341160000...  success  4.740341
# 87   {'estado': 'success', 'yinput': 4.728396350000...  success  4.728396
# 88   {'estado': 'success', 'yinput': 4.679343572999...  success  4.679344
# 89   {'estado': 'success', 'yinput': 4.727035398, '...  success  4.727035
# 90   {'estado': 'success', 'yinput': 4.725506298000...  success  4.725506
# 91   {'estado': 'success', 'yinput': 4.719341353999...  success  4.719341
# 92   {'estado': 'success', 'yinput': 4.721718665000...  success  4.721719
# 93   {'estado': 'success', 'yinput': 4.725369694999...  success  4.725370
# 94   {'estado': 'success', 'yinput': 4.682698906999...  success  4.682699
# 95   {'estado': 'success', 'yinput': 4.721595760000...  success  4.721596
# 96   {'estado': 'success', 'yinput': 4.705409735999...  success  4.705410
# 97   {'estado': 'success', 'yinput': 4.736024711000...  success  4.736025
# 98   {'estado': 'success', 'yinput': 4.731602785000...  success  4.731603
# 99   {'estado': 'success', 'yinput': 4.658462176, '...  success  4.658462
# 100  {'estado': 'success', 'yinput': 4.695852065, '...  success  4.695852
# 101  {'estado': 'success', 'yinput': 4.670751526999...  success  4.670752
# 102  {'estado': 'success', 'yinput': 4.708518577000...  success  4.708519
# 103  {'estado': 'success', 'yinput': 4.726607890000...  success  4.726608
# 104  {'estado': 'success', 'yinput': 4.727023836, '...  success  4.727024
# 105  {'estado': 'success', 'yinput': 4.740202042000...  success  4.740202
# 106  {'estado': 'success', 'yinput': 4.648394596999...  success  4.648395
# 107  {'estado': 'success', 'yinput': 4.708930601000...  success  4.708931
# 108  {'estado': 'success', 'yinput': 4.677174915000...  success  4.677175
# 109  {'estado': 'success', 'yinput': 4.688466897000...  success  4.688467
# 110  {'estado': 'success', 'yinput': 4.700692066999...  success  4.700692
# 111  {'estado': 'success', 'yinput': 4.722478955999...  success  4.722479
# 112  {'estado': 'success', 'yinput': 4.636440918000...  success  4.636441
# 113  {'estado': 'success', 'yinput': 4.707224096, '...  success  4.707224
# 114  {'estado': 'success', 'yinput': 4.726181227999...  success  4.726181
# 115  {'estado': 'success', 'yinput': 4.733994909999...  success  4.733995
# 116  {'estado': 'success', 'yinput': 4.673861379000...  success  4.673861
# 117  {'estado': 'success', 'yinput': 4.644755879, '...  success  4.644756
# 118  {'estado': 'success', 'yinput': 4.721226506999...  success  4.721227
# 119  {'estado': 'success', 'yinput': 4.640041816000...  success  4.640042
# 120  {'estado': 'success', 'yinput': 4.728176714000...  success  4.728177
# 121  {'estado': 'success', 'yinput': 4.734107191000...  success  4.734107
# 122  {'estado': 'success', 'yinput': 4.692144117, '...  success  4.692144
# 123  {'estado': 'success', 'yinput': 4.693682001000...  success  4.693682
# 124  {'estado': 'success', 'yinput': 4.682051772000...  success  4.682052
# 125  {'estado': 'success', 'yinput': 4.684103257999...  success  4.684103
# 126  {'estado': 'success', 'yinput': 4.697006693999...  success  4.697007
# 127  {'estado': 'success', 'yinput': 4.645625309000...  success  4.645625
# 128  {'estado': 'success', 'yinput': 4.742352333999...  success  4.742352
# 129  {'estado': 'success', 'yinput': 4.682527935999...  success  4.682528
# 130  {'estado': 'success', 'yinput': 4.705711445000...  success  4.705711
# 131  {'estado': 'success', 'yinput': 4.662504980999...  success  4.662505
# 132  {'estado': 'success', 'yinput': 4.656625259000...  success  4.656625
# 133  {'estado': 'success', 'yinput': 4.694310572000...  success  4.694311
# 134  {'estado': 'success', 'yinput': 4.728867363000...  success  4.728867
# 135  {'estado': 'success', 'yinput': 4.717752963000...  success  4.717753
# 136  {'estado': 'success', 'yinput': 4.690330026000...  success  4.690330
# 137  {'estado': 'success', 'yinput': 4.743192213999...  success  4.743192
# 138  {'estado': 'success', 'yinput': 4.728691379, '...  success  4.728691
# 139  {'estado': 'success', 'yinput': 4.667393216999...  success  4.667393
# 140  {'estado': 'success', 'yinput': 4.732190951000...  success  4.732191
# 141  {'estado': 'success', 'yinput': 4.732869532, '...  success  4.732870
# 142  {'estado': 'success', 'yinput': 4.694542432999...  success  4.694542
# 143  {'estado': 'success', 'yinput': 4.701078571999...  success  4.701079
# 144  {'estado': 'success', 'yinput': 4.725641783000...  success  4.725642
# 145  {'estado': 'success', 'yinput': 4.699480001999...  success  4.699480
# 146  {'estado': 'success', 'yinput': 4.727855902999...  success  4.727856
# 147  {'estado': 'success', 'yinput': 4.64741576, 'l...  success  4.647416
# 148  {'estado': 'success', 'yinput': 4.664124770999...  success  4.664125
# 149  {'estado': 'success', 'yinput': 4.725314803999...  success  4.725315
#
#            lng              tipo_direccion
# 0   -74.081780       Asignada por Catastro
# 1   -74.062103       Asignada por Catastro
# 2   -74.049579       Asignada por Catastro
# 3   -74.044010       Asignada por Catastro
# 4   -74.040797       Asignada por Catastro
# 5   -74.042178       Asignada por Catastro
# 6   -74.041578       Asignada por Catastro
# 7   -74.048449       Asignada por Catastro
# 8   -74.051802       Asignada por Catastro
# 9   -74.052385       Asignada por Catastro
# 10  -74.047010       Asignada por Catastro
# 11  -74.033761       Asignada por Catastro
# 12  -74.047685       Asignada por Catastro
# 13  -74.048015       Asignada por Catastro
# 14  -74.041035       Asignada por Catastro
# 15  -74.055130       Asignada por Catastro
# 16  -74.037540       Asignada por Catastro
# 17  -74.049319       Asignada por Catastro
# 18  -74.048468       Asignada por Catastro
# 19  -74.035827       Asignada por Catastro
# 20  -74.125769       Asignada por Catastro
# 21         NaN                        None
# 22  -74.036719       Asignada por Catastro
# 23  -74.031511       Asignada por Catastro
# 24  -74.061996       Asignada por Catastro
# 25  -74.083575       Asignada por Catastro
# 26  -74.042708       Asignada por Catastro
# 27  -74.032171  Dirección por aproximación
# 28  -74.045355       Asignada por Catastro
# 29  -74.058703       Asignada por Catastro
# 30  -74.038318       Asignada por Catastro
# 31  -74.036827       Asignada por Catastro
# 32  -74.033892       Asignada por Catastro
# 33  -74.030790       Asignada por Catastro
# 34  -74.055811       Asignada por Catastro
# 35  -74.066086       Asignada por Catastro
# 36  -74.029303       Asignada por Catastro
# 37  -74.032722       Asignada por Catastro
# 38  -74.114735       Asignada por Catastro
# 39  -74.034811       Asignada por Catastro
# 40  -74.049058       Asignada por Catastro
# 41  -74.060611       Asignada por Catastro
# 42  -74.035745       Asignada por Catastro
# 43  -74.049275       Asignada por Catastro
# 44  -74.052363       Asignada por Catastro
# 45  -74.101058           Dirección antigua
# 46  -74.049133       Asignada por Catastro
# 47  -74.039346       Asignada por Catastro
# 48  -74.040445       Asignada por Catastro
# 49  -74.065060       Asignada por Catastro
# 50  -74.030847       Asignada por Catastro
# 51  -74.054366       Asignada por Catastro
# 52  -74.033591       Asignada por Catastro
# 53  -74.050056           Dirección antigua
# 54  -74.042201       Asignada por Catastro
# 55  -74.035298       Asignada por Catastro
# 56  -74.049795       Asignada por Catastro
# 57  -74.054588       Asignada por Catastro
# 58  -74.061192       Asignada por Catastro
# 59  -74.058731       Asignada por Catastro
# 60  -74.039714       Asignada por Catastro
# 61  -74.045914       Asignada por Catastro
# 62  -74.031963       Asignada por Catastro
# 63  -74.037490       Asignada por Catastro
# 64  -74.083273       Asignada por Catastro
# 65  -74.040923       Asignada por Catastro
# 66  -74.047428       Asignada por Catastro
# 67  -74.051509       Asignada por Catastro
# 68  -74.061685       Asignada por Catastro
# 69  -74.046976       Asignada por Catastro
# 70  -74.044258       Asignada por Catastro
# 71  -74.048269       Asignada por Catastro
# 72  -74.068408       Asignada por Catastro
# 73  -74.043556       Asignada por Catastro
# 74  -74.053350       Asignada por Catastro
# 75  -74.059720       Asignada por Catastro
# 76  -74.045267       Asignada por Catastro
# 77  -74.137773       Asignada por Catastro
# 78  -74.033103       Asignada por Catastro
# 79  -74.062064       Asignada por Catastro
# 80  -74.043624       Asignada por Catastro
# 81  -74.026463       Asignada por Catastro
# 82  -74.053934       Asignada por Catastro
# 83  -74.031295       Asignada por Catastro
# 84  -74.044322       Asignada por Catastro
# 85  -74.060680       Asignada por Catastro
# 86  -74.044267       Asignada por Catastro
# 87  -74.036945       Asignada por Catastro
# 88  -74.055502       Asignada por Catastro
# 89  -74.067302       Asignada por Catastro
# 90  -74.038990  Dirección por aproximación
# 91  -74.039221       Asignada por Catastro
# 92  -74.028323       Asignada por Catastro
# 93  -74.038737       Asignada por Catastro
# 94  -74.050506       Asignada por Catastro
# 95  -74.044984       Asignada por Catastro
# 96  -74.042556       Asignada por Catastro
# 97  -74.032947       Asignada por Catastro
# 98  -74.063629       Asignada por Catastro
# 99  -74.119653       Asignada por Catastro
# 100 -74.038483       Asignada por Catastro
# 101 -74.044806       Asignada por Catastro
# 102 -74.049513       Asignada por Catastro
# 103 -74.044951       Asignada por Catastro
# 104 -74.045204       Asignada por Catastro
# 105 -74.057552       Asignada por Catastro
# 106 -74.084108       Asignada por Catastro
# 107 -74.030682       Asignada por Catastro
# 108 -74.041326       Asignada por Catastro
# 109 -74.054210       Asignada por Catastro
# 110 -74.052166       Asignada por Catastro
# 111 -74.060978       Asignada por Catastro
# 112 -74.075655       Asignada por Catastro
# 113 -74.029080       Asignada por Catastro
# 114 -74.038638       Asignada por Catastro
# 115 -74.051350       Asignada por Catastro
# 116 -74.054314       Asignada por Catastro
# 117 -74.101051       Asignada por Catastro
# 118 -74.040784       Asignada por Catastro
# 119 -74.061629       Asignada por Catastro
# 120 -74.031514       Asignada por Catastro
# 121 -74.056891       Asignada por Catastro
# 122 -74.061170       Asignada por Catastro
# 123 -74.061504       Asignada por Catastro
# 124 -74.050842       Asignada por Catastro
# 125 -74.044322       Asignada por Catastro
# 126 -74.039372       Asignada por Catastro
# 127 -74.083123       Asignada por Catastro
# 128 -74.060420       Asignada por Catastro
# 129 -74.054483       Asignada por Catastro
# 130 -74.040626       Asignada por Catastro
# 131 -74.128939       Asignada por Catastro
# 132 -74.111972       Asignada por Catastro
# 133 -74.045856       Asignada por Catastro
# 134 -74.029163       Asignada por Catastro
# 135 -74.030298       Asignada por Catastro
# 136 -74.050233       Asignada por Catastro
# 137 -74.061230           Dirección antigua
# 138 -74.065338       Asignada por Catastro
# 139 -74.048784       Asignada por Catastro
# 140 -74.056129  Dirección por aproximación
# 141 -74.054519       Asignada por Catastro
# 142 -74.038021       Asignada por Catastro
# 143 -74.036371  Dirección por aproximación
# 144 -74.067954       Asignada por Catastro
# 145 -74.037822       Asignada por Catastro
# 146 -74.030452       Asignada por Catastro
# 147 -74.082714       Asignada por Catastro
# 148 -74.134919  Dirección por aproximación
# 149 -74.036224       Asignada por Catastro

# %%
pd.set_option('display.max_rows', 10)

# %% [markdown]
# El 0.6% de la muestra aleatoria del primer dataframe (df_vivienda_usada_venta) no pudo ser georeferenciado por la existencia de detalles en la dirección utilizada como insumo.

# %%
sample_2 = df_vivienda_usada_arriendo.sample(n=150, random_state=1)[vivienda_usada_dir].reset_index()
sample_2['addr'] = sample_2[vivienda_usada_dir]
sample_2['source']='df_vivienda_usada_arriendo'
del sample_2[vivienda_usada_dir]
del sample_2['index']
sample_2['geocode_result'] = sample_2['addr'].swifter.apply(georeferenciar)
# Out:
# Pandas Apply:   0%|          | 0/150 [00:00<?, ?it/s]

# %%
sample_2['estado'] = sample_2.apply(lambda x: json.loads(x['geocode_result'])['estado'] if type(x['geocode_result']) is str else x['geocode_result']['estado'], axis=1)
sample_2['tipo_direccion'] = sample_2.apply(lambda x: None if type(x['geocode_result']) is str else x['geocode_result']['tipo_direccion'], axis=1)
sample_2['lat'] = sample_2.apply(lambda x: None if type(x['geocode_result']) is str else x['geocode_result']['yinput'], axis=1)
sample_2['lng'] = sample_2.apply(lambda x: None if type(x['geocode_result']) is str else x['geocode_result']['xinput'], axis=1)

# %%
pd.set_option('display.max_rows', None)

# %%
sample_2
# Out:
#                             addr                      source  \
# 0                  Cr. 5 # 72-38  df_vivienda_usada_arriendo
# 1              Av. Cr. 7 # 82-62  df_vivienda_usada_arriendo
# 2                 Cr. 2A # 72-12  df_vivienda_usada_arriendo
# 3              Tr. 56 # 108 - 05  df_vivienda_usada_arriendo
# 4                Cl. 146 # 19-93  df_vivienda_usada_arriendo
# 5              Cl. 107a # 11a-87  df_vivienda_usada_arriendo
# 6              Cr. 58C # 152B-66  df_vivienda_usada_arriendo
# 7              Cr. 54C # 143A-90  df_vivienda_usada_arriendo
# 8                Cl. 23A # 58-40  df_vivienda_usada_arriendo
# 9             Cr. 23 # 137-48/45  df_vivienda_usada_arriendo
# 10              Cr. 14 # 127B-46  df_vivienda_usada_arriendo
# 11                Cr. 9a # 96-76  df_vivienda_usada_arriendo
# 12              Cr. 19A # 106-52  df_vivienda_usada_arriendo
# 13             Cl. 103A # 11B-49  df_vivienda_usada_arriendo
# 14              Cr. 54D # 134-21  df_vivienda_usada_arriendo
# 15          Av. Cr. 72 # 152B-89  df_vivienda_usada_arriendo
# 16             Cr. 56A # 137B-60  df_vivienda_usada_arriendo
# 17              Cr. 7A # 127C-63  df_vivienda_usada_arriendo
# 18            Av. Cr. 9 # 146-10  df_vivienda_usada_arriendo
# 19               Cl. 24A # 59-59  df_vivienda_usada_arriendo
# 20              Cl. 145A # 15-31  df_vivienda_usada_arriendo
# 21                Cl. 129 # 7-77  df_vivienda_usada_arriendo
# 22                 Cl. 64 # 1-15  df_vivienda_usada_arriendo
# 23           Cl. 23ABis # 85A-62  df_vivienda_usada_arriendo
# 24           Av. Cl. 116 # 50-12  df_vivienda_usada_arriendo
# 25              Cr. 7C # 130A-21  df_vivienda_usada_arriendo
# 26           Cl. 134A # 17-50/56  df_vivienda_usada_arriendo
# 27                Dg. 76 # 1A-70  df_vivienda_usada_arriendo
# 28           Cl. 142 # 15-36/ 54  df_vivienda_usada_arriendo
# 29              Cr. 14A # 119-83  df_vivienda_usada_arriendo
# 30                Cl. 91 # 17-50  df_vivienda_usada_arriendo
# 31             Cl. 115 # 53 - 54  df_vivienda_usada_arriendo
# 32                Cr. 8a # 95-33  df_vivienda_usada_arriendo
# 33               Cl. 152 # 54-39  df_vivienda_usada_arriendo
# 34                 Cr. 5 # 54-40  df_vivienda_usada_arriendo
# 35              Cl. 145A # 15-69  df_vivienda_usada_arriendo
# 36                 Cl. 79 # 8-21  df_vivienda_usada_arriendo
# 37              Cr. 57A # 145-61  df_vivienda_usada_arriendo
# 38               Cl. 142 # 13-57  df_vivienda_usada_arriendo
# 39             Cr. 54 # 115 - 35  df_vivienda_usada_arriendo
# 40                 Cl. 53 # 4-34  df_vivienda_usada_arriendo
# 41             Cr. 89 # 17B-57    df_vivienda_usada_arriendo
# 42              Cr. 11C # 116-20  df_vivienda_usada_arriendo
# 43            Av. Cl. 63 # 45-51  df_vivienda_usada_arriendo
# 44              Cl. 47A # 27A-09  df_vivienda_usada_arriendo
# 45               Cl. 142 # 11-14  df_vivienda_usada_arriendo
# 46                Cr. 16 # 88-67  df_vivienda_usada_arriendo
# 47                Cl. 59 # 3A-24  df_vivienda_usada_arriendo
# 48                 Cr. 9 # 65-76  df_vivienda_usada_arriendo
# 49              Cl. 123 # 15A-46  df_vivienda_usada_arriendo
# 50           Av. Cl. 116 # 12-20  df_vivienda_usada_arriendo
# 51             Cl. 66Bis # 28-28  df_vivienda_usada_arriendo
# 52              Cl. 107A # 7C-50  df_vivienda_usada_arriendo
# 53               Cr. 54 # 150-27  df_vivienda_usada_arriendo
# 54               Cl. 145 # 7F-57  df_vivienda_usada_arriendo
# 55                Cl. 66 # 11-29  df_vivienda_usada_arriendo
# 56              Cr. 14B # 146-33  df_vivienda_usada_arriendo
# 57                 Cl. 80 # 8-07  df_vivienda_usada_arriendo
# 58               Cr. 21 # 103-51  df_vivienda_usada_arriendo
# 59                Cl. 65 # 3B-30  df_vivienda_usada_arriendo
# 60               Cl. 57 # 37A-23  df_vivienda_usada_arriendo
# 61               Cr. 23 # 137-41  df_vivienda_usada_arriendo
# 62               Cr. 7B # 145-25  df_vivienda_usada_arriendo
# 63              Cr. 19A # 86A-67  df_vivienda_usada_arriendo
# 64                 Cr. 6 # 55-45  df_vivienda_usada_arriendo
# 65              Cr. 12 # 127B-39  df_vivienda_usada_arriendo
# 66              Cr. 12 # 101 -29  df_vivienda_usada_arriendo
# 67             Cr. 53 # 106 - 60  df_vivienda_usada_arriendo
# 68              Cl. 130 # 56A-18  df_vivienda_usada_arriendo
# 69             Cl. 113 # 55 - 49  df_vivienda_usada_arriendo
# 70                Cl. 132 # 7-17  df_vivienda_usada_arriendo
# 71       Cl. 108 # 17a- 17/21/45  df_vivienda_usada_arriendo
# 72           Av. Cr. 19 # 127-26  df_vivienda_usada_arriendo
# 73             Cr. 9a # 96-22/36  df_vivienda_usada_arriendo
# 74          Av. Cr. 72 # 152B-89  df_vivienda_usada_arriendo
# 75                Cr. 19 # 90-56  df_vivienda_usada_arriendo
# 76              Cl. 135A # 10-26  df_vivienda_usada_arriendo
# 77            Cr. 51 # 106 - 70   df_vivienda_usada_arriendo
# 78               Cr. 18 # 122-43  df_vivienda_usada_arriendo
# 79           Cl. 88 # 19A-30/ 48  df_vivienda_usada_arriendo
# 80               Cr. 7a # 124-29  df_vivienda_usada_arriendo
# 81               Cl. 22D # 72-38  df_vivienda_usada_arriendo
# 82               Cl. 151 # 7H-60  df_vivienda_usada_arriendo
# 83              Cl. 127B # 19-39  df_vivienda_usada_arriendo
# 84              Cr. 13 # 134C-17  df_vivienda_usada_arriendo
# 85              Cl. 22B # 68C-41  df_vivienda_usada_arriendo
# 86           Av. Cr. 11 # 119-31  df_vivienda_usada_arriendo
# 87              Cr. 12B # 137-27  df_vivienda_usada_arriendo
# 88               Cr. 13 # 113-89  df_vivienda_usada_arriendo
# 89           Av. Cr. 30 # 39B-14  df_vivienda_usada_arriendo
# 90               Cl. 96 # 19A-83  df_vivienda_usada_arriendo
# 91               Cr. 19C # 85-44  df_vivienda_usada_arriendo
# 92              Cr. 15B # 112-49  df_vivienda_usada_arriendo
# 93              Cr. 6 # 58-16/22  df_vivienda_usada_arriendo
# 94              Cr. 21 # 106A-31  df_vivienda_usada_arriendo
# 95             Cl. 59ABis # 5-13  df_vivienda_usada_arriendo
# 96              Cr. 17A # 122-80  df_vivienda_usada_arriendo
# 97            Cr. 51 # 104B - 38  df_vivienda_usada_arriendo
# 98                Cr. 19 # 85-93  df_vivienda_usada_arriendo
# 99                Cr. 45 # 62-41  df_vivienda_usada_arriendo
# 100             Cl. 108 # 17a-65  df_vivienda_usada_arriendo
# 101          Av. Cl. 147 # 11-41  df_vivienda_usada_arriendo
# 102             Cr. 69B # 23C-36  df_vivienda_usada_arriendo
# 103              Cr. 56 # 151-51  df_vivienda_usada_arriendo
# 104                Cl. 62 # 5-31  df_vivienda_usada_arriendo
# 105              Cr. 23 # 122-96  df_vivienda_usada_arriendo
# 106               Cl. 77 # 11-41  df_vivienda_usada_arriendo
# 107             Cr. 13a # 104-91  df_vivienda_usada_arriendo
# 108             Cr. 72C # 22D-27  df_vivienda_usada_arriendo
# 109                Cl. 65 # 2-40  df_vivienda_usada_arriendo
# 110             Cr. 85A # 23B-88  df_vivienda_usada_arriendo
# 111               Cl. 97 # 21-42  df_vivienda_usada_arriendo
# 112            Cl. 107A # 7C- 49  df_vivienda_usada_arriendo
# 113               Cl. 42 # 28-31  df_vivienda_usada_arriendo
# 114             Cl. 145 # 13A-58  df_vivienda_usada_arriendo
# 115                Cl. 61 # 4-38  df_vivienda_usada_arriendo
# 116              Cl. 18A # 78-35  df_vivienda_usada_arriendo
# 117              Cl. 145 # 21-36  df_vivienda_usada_arriendo
# 118             Cr. 13a # 104-22  df_vivienda_usada_arriendo
# 119              Cr. 16 # 143-62  df_vivienda_usada_arriendo
# 120              Cr. 79 # 19A-56  df_vivienda_usada_arriendo
# 121            Cl. 107A # 7C- 49  df_vivienda_usada_arriendo
# 122               Cl. 59 # 37-49  df_vivienda_usada_arriendo
# 123              Cr. 80A # 17-85  df_vivienda_usada_arriendo
# 124               Cr. 63 # 22-45  df_vivienda_usada_arriendo
# 125             Cr. 56 # 152B-60  df_vivienda_usada_arriendo
# 126          Av. Cl. 147 # 12-81  df_vivienda_usada_arriendo
# 127              Cl. 144 # 12-09  df_vivienda_usada_arriendo
# 128              Cl. 108 # 15-22  df_vivienda_usada_arriendo
# 129              Cl. 109 # 15-08  df_vivienda_usada_arriendo
# 130             Cr 50 # 106 - 72  df_vivienda_usada_arriendo
# 131          Av. Cr. 11 # 114-32  df_vivienda_usada_arriendo
# 132            Cr. 17a # 119a-65  df_vivienda_usada_arriendo
# 133             Cr. 7A # 127B-23  df_vivienda_usada_arriendo
# 134                Cr. 6 # 53-26  df_vivienda_usada_arriendo
# 135            Cl. 134A # 12B-15  df_vivienda_usada_arriendo
# 136              Cl. 125 # 16-45  df_vivienda_usada_arriendo
# 137  Av. Cl. 147 # 7B-58/ 70/ 84  df_vivienda_usada_arriendo
# 138          Av. Cr. 15 # 143-51  df_vivienda_usada_arriendo
# 139              Cr. 79 # 19A-56  df_vivienda_usada_arriendo
# 140              Cl. 86 # 19C-31  df_vivienda_usada_arriendo
# 141               Cr. 10 # 92-41  df_vivienda_usada_arriendo
# 142            Cl. 134A # 10A-51  df_vivienda_usada_arriendo
# 143                Cl. 82 # 9-22  df_vivienda_usada_arriendo
# 144           Av. Cr. 9 # 145-56  df_vivienda_usada_arriendo
# 145          Dg. 23CBIS # 88B-10  df_vivienda_usada_arriendo
# 146             Cr. 59 # 136A-65  df_vivienda_usada_arriendo
# 147              Cr. 12 # 142-30  df_vivienda_usada_arriendo
# 148               Cr. 21 # 37-64  df_vivienda_usada_arriendo
# 149             Cr. 16A # 145-42  df_vivienda_usada_arriendo
#
#                                         geocode_result   estado       lat  \
# 0    {'estado': 'success', 'yinput': 4.654720348000...  success  4.654720
# 1    {'estado': 'success', 'yinput': 4.663197007000...  success  4.663197
# 2    {'estado': 'success', 'yinput': 4.653672495000...  success  4.653672
# 3    {'estado': 'success', 'yinput': 4.696132332999...  success  4.696132
# 4    {'estado': 'success', 'yinput': 4.728528428, '...  success  4.728528
# 5    {'estado': 'success', 'yinput': 4.689785589, '...  success  4.689786
# 6    {'estado': 'success', 'yinput': 4.740506326, '...  success  4.740506
# 7    {'estado': 'success', 'yinput': 4.728877289000...  success  4.728877
# 8    {'estado': 'success', 'yinput': 4.642932936000...  success  4.642933
# 9    {'estado': 'success', 'yinput': 4.722911628000...  success  4.722912
# 10   {'estado': 'success', 'yinput': 4.707803363999...  success  4.707803
# 11   {'estado': 'success', 'yinput': 4.679167790000...  success  4.679168
# 12   {'estado': 'success', 'yinput': 4.693476058999...  success  4.693476
# 13   {'estado': 'success', 'yinput': 4.686861904000...  success  4.686862
# 14   {'estado': 'success', 'yinput': 4.722478955999...  success  4.722479
# 15   {'estado': 'success', 'yinput': 4.742350158000...  success  4.742350
# 16   {'estado': 'success', 'yinput': 4.726992956999...  success  4.726993
# 17   {'estado': 'success', 'yinput': 4.706719238999...  success  4.706719
# 18   {'estado': 'success', 'yinput': 4.724007723, '...  success  4.724008
# 19   {'estado': 'success', 'yinput': 4.644755879, '...  success  4.644756
# 20   {'estado': 'success', 'yinput': 4.727221692999...  success  4.727222
# 21   {'estado': 'success', 'yinput': 4.707871665000...  success  4.707872
# 22   {'estado': 'success', 'yinput': 4.645513887999...  success  4.645514
# 23   {'estado': 'success', 'yinput': 4.668569251000...  success  4.668569
# 24   {'estado': 'success', 'yinput': 4.700395714000...  success  4.700396
# 25   {'estado': 'success', 'yinput': 4.709083297000...  success  4.709083
# 26   {'estado': 'success', 'yinput': 4.718548446999...  success  4.718548
# 27   {'estado': 'success', 'yinput': 4.65639073, 'l...  success  4.656391
# 28   {'estado': 'success', 'yinput': 4.723827600999...  success  4.723828
# 29   {'estado': 'success', 'yinput': 4.700096922999...  success  4.700097
# 30   {'estado': 'success', 'yinput': 4.676145996, '...  success  4.676146
# 31   {'estado': 'success', 'yinput': 4.700233034000...  success  4.700233
# 32   {'estado': 'success', 'yinput': 4.677316392000...  success  4.677316
# 33   {'estado': 'success', 'yinput': 4.735648831999...  success  4.735649
# 34   {'estado': 'success', 'yinput': 4.640294306999...  success  4.640294
# 35   {'estado': 'success', 'yinput': 4.727265386999...  success  4.727265
# 36   {'estado': 'success', 'yinput': 4.661613596, '...  success  4.661614
# 37   {'estado': 'success', 'yinput': 4.731269667999...  success  4.731270
# 38   {'estado': 'success', 'yinput': 4.723202716999...  success  4.723203
# 39   {'estado': 'success', 'yinput': 4.700634459000...  success  4.700634
# 40   {'estado': 'success', 'yinput': 4.639030484999...  success  4.639030
# 41   {'estado': 'success', 'yinput': 4.664039209000...  success  4.664039
# 42   {'estado': 'success', 'yinput': 4.695646695999...  success  4.695647
# 43   {'estado': 'success', 'yinput': 4.652934980999...  success  4.652935
# 44   {'estado': 'success', 'yinput': 4.636909084000...  success  4.636909
# 45   {'estado': 'success', 'yinput': 4.720991266, '...  success  4.720991
# 46   {'estado': 'success', 'yinput': 4.674387215000...  success  4.674387
# 47   {'estado': 'success', 'yinput': 4.643466857000...  success  4.643467
# 48   {'estado': 'success', 'yinput': 4.650772467000...  success  4.650772
# 49   {'estado': 'success', 'yinput': 4.701905021000...  success  4.701905
# 50   {'estado': 'success', 'yinput': 4.695687689000...  success  4.695688
# 51   {'estado': 'success', 'yinput': 4.659901468999...  success  4.659901
# 52   {'estado': 'success', 'yinput': 4.687520068000...  success  4.687520
# 53   {'estado': 'success', 'yinput': 4.733078003999...  success  4.733078
# 54   {'estado': 'success', 'yinput': 4.722032031000...  success  4.722032
# 55   {'estado': 'success', 'yinput': 4.652081899, '...  success  4.652082
# 56   {'estado': 'success', 'yinput': 4.728399744999...  success  4.728400
# 57   {'estado': 'success', 'yinput': 4.662592479000...  success  4.662592
# 58   {'estado': 'success', 'yinput': 4.689744632999...  success  4.689745
# 59   {'estado': 'success', 'yinput': 4.647695133000...  success  4.647695
# 60   {'estado': 'success', 'yinput': 4.646687000999...  success  4.646687
# 61   {'estado': 'success', 'yinput': 4.722793063999...  success  4.722793
# 62   {'estado': 'success', 'yinput': 4.721222721, '...  success  4.721223
# 63   {'estado': 'success', 'yinput': 4.673447228999...  success  4.673447
# 64   {'estado': 'success', 'yinput': 4.641435014000...  success  4.641435
# 65   {'estado': 'success', 'yinput': 4.707605161999...  success  4.707605
# 66   {'estado': 'success', 'yinput': 4.684632029, '...  success  4.684632
# 67   {'estado': 'success', 'yinput': 4.695723047, '...  success  4.695723
# 68   {'estado': 'success', 'yinput': 4.719282334000...  success  4.719282
# 69   {'estado': 'success', 'yinput': 4.697508178000...  success  4.697508
# 70   {'estado': 'success', 'yinput': 4.710082316000...  success  4.710082
# 71   {'estado': 'success', 'yinput': 4.693455332999...  success  4.693455
# 72   {'estado': 'success', 'yinput': 4.705921559999...  success  4.705922
# 73   {'estado': 'success', 'yinput': 4.678675871999...  success  4.678676
# 74   {'estado': 'success', 'yinput': 4.742350158000...  success  4.742350
# 75   {'estado': 'success', 'yinput': 4.676450647000...  success  4.676451
# 76   {'estado': 'success', 'yinput': 4.715830948000...  success  4.715831
# 77   {'estado': 'success', 'yinput': 4.695692173, '...  success  4.695692
# 78   {'estado': 'success', 'yinput': 4.701898669, '...  success  4.701899
# 79   {'estado': 'success', 'yinput': 4.675349545000...  success  4.675350
# 80   {'estado': 'success', 'yinput': 4.700355664000...  success  4.700356
# 81   {'estado': 'success', 'yinput': 4.65853367, 'l...  success  4.658534
# 82   {'estado': 'success', 'yinput': 4.727610597000...  success  4.727611
# 83   {'estado': 'success', 'yinput': 4.708294371000...  success  4.708294
# 84   {'estado': 'success', 'yinput': 4.717194477000...  success  4.717194
# 85   {'estado': 'success', 'yinput': 4.650723920000...  success  4.650724
# 86   {'estado': 'success', 'yinput': 4.698180886999...  success  4.698181
# 87   {'estado': 'success', 'yinput': 4.719341353999...  success  4.719341
# 88   {'estado': 'success', 'yinput': 4.695069371999...  success  4.695069
# 89   {'estado': 'success', 'yinput': 4.630048080999...  success  4.630048
# 90   {'estado': 'success', 'yinput': 4.683578727999...  success  4.683579
# 91   {'estado': 'success', 'yinput': 4.672530110000...  success  4.672530
# 92   {'estado': 'success', 'yinput': 4.695487276999...  success  4.695487
# 93   {'estado': 'success', 'yinput': 4.643540454, '...  success  4.643540
# 94   {'estado': 'success', 'yinput': 4.694181808, '...  success  4.694182
# 95   {'estado': 'success', 'yinput': 4.644616204999...  success  4.644616
# 96   {'estado': 'success', 'yinput': 4.701479080000...  success  4.701479
# 97   {'estado': 'success', 'yinput': 4.693896187000...  success  4.693896
# 98   {'estado': 'success', 'yinput': 4.672256489000...  success  4.672256
# 99   {'estado': 'success', 'yinput': 4.652631203999...  success  4.652631
# 100  {'estado': 'success', 'yinput': 4.693505260999...  success  4.693505
# 101  {'estado': 'success', 'yinput': 4.726015212999...  success  4.726015
# 102  {'estado': 'success', 'yinput': 4.655701936000...  success  4.655702
# 103  {'estado': 'success', 'yinput': 4.734933988000...  success  4.734934
# 104  {'estado': 'success', 'yinput': 4.646471366000...  success  4.646471
# 105  {'estado': 'success', 'yinput': 4.703947701, '...  success  4.703948
# 106  {'estado': 'success', 'yinput': 4.661860236999...  success  4.661860
# 107  {'estado': 'success', 'yinput': 4.688902676, '...  success  4.688903
# 108  {'estado': 'success', 'yinput': 4.660727181000...  success  4.660727
# 109  {'estado': 'success', 'yinput': 4.647201994, '...  success  4.647202
# 110  {'estado': 'success', 'yinput': 4.664433047999...  success  4.664433
# 111  {'estado': 'success', 'yinput': 4.684657577, '...  success  4.684658
# 112  {'estado': 'success', 'yinput': 4.687363629999...  success  4.687364
# 113  {'estado': 'success', 'yinput': 4.633006433999...  success  4.633006
# 114  {'estado': 'success', 'yinput': 4.725834830999...  success  4.725835
# 115  {'estado': 'success', 'yinput': 4.645441520000...  success  4.645442
# 116  {'estado': 'success', 'yinput': 4.655552624999...  success  4.655553
# 117  {'estado': 'success', 'yinput': 4.72700813, 'l...  success  4.727008
# 118  {'estado': 'success', 'yinput': 4.687990935000...  success  4.687991
# 119  {'estado': 'success', 'yinput': 4.725210907000...  success  4.725211
# 120  {'estado': 'success', 'yinput': 4.658322693999...  success  4.658323
# 121  {'estado': 'success', 'yinput': 4.687363629999...  success  4.687364
# 122  {'estado': 'success', 'yinput': 4.650098343000...  success  4.650098
# 123  {'estado': 'success', 'yinput': 4.657993784999...  success  4.657994
# 124  {'estado': 'success', 'yinput': 4.642808349000...  success  4.642808
# 125  {'estado': 'success', 'yinput': 4.739676377000...  success  4.739676
# 126  {'estado': 'success', 'yinput': 4.727019445999...  success  4.727019
# 127  {'estado': 'success', 'yinput': 4.723092915, '...  success  4.723093
# 128  {'estado': 'success', 'yinput': 4.692179758000...  success  4.692180
# 129  {'estado': 'success', 'yinput': 4.692735395, '...  success  4.692735
# 130  {'estado': 'success', 'yinput': 4.695582253999...  success  4.695582
# 131  {'estado': 'success', 'yinput': 4.693941417000...  success  4.693941
# 132  {'estado': 'success', 'yinput': 4.700504819, '...  success  4.700505
# 133  {'estado': 'success', 'yinput': 4.705049614000...  success  4.705050
# 134  {'estado': 'success', 'yinput': 4.639667471, '...  success  4.639667
# 135  {'estado': 'success', 'yinput': 4.716047010000...  success  4.716047
# 136  {'estado': 'success', 'yinput': 4.70342438, 'l...  success  4.703424
# 137  {'estado': 'success', 'yinput': 4.723738390999...  success  4.723738
# 138  {'estado': 'success', 'yinput': 4.725115598, '...  success  4.725116
# 139  {'estado': 'success', 'yinput': 4.658322693999...  success  4.658323
# 140  {'estado': 'success', 'yinput': 4.673064646999...  success  4.673065
# 141  {'estado': 'success', 'yinput': 4.673792857000...  success  4.673793
# 142  {'estado': 'success', 'yinput': 4.714514843000...  success  4.714515
# 143  {'estado': 'success', 'yinput': 4.664831041000...  success  4.664831
# 144  {'estado': 'success', 'yinput': 4.723167822999...  success  4.723168
# 145                               {"estado": "failed"}   failed       NaN
# 146  {'estado': 'success', 'yinput': 4.727920772, '...  success  4.727921
# 147  {'estado': 'success', 'yinput': 4.722139685, '...  success  4.722140
# 148  {'estado': 'success', 'yinput': 4.627175346, '...  success  4.627175
# 149  {'estado': 'success', 'yinput': 4.726929980000...  success  4.726930
#
#            lng              tipo_direccion
# 0   -74.053364           Dirección antigua
# 1   -74.048255       Asignada por Catastro
# 2   -74.051925           Dirección antigua
# 3   -74.065863       Asignada por Catastro
# 4   -74.047574       Asignada por Catastro
# 5   -74.041800       Asignada por Catastro
# 6   -74.062684       Asignada por Catastro
# 7   -74.057771       Asignada por Catastro
# 8   -74.102133       Asignada por Catastro
# 9   -74.050022       Asignada por Catastro
# 10  -74.040644       Asignada por Catastro
# 11  -74.043294       Asignada por Catastro
# 12  -74.051470       Asignada por Catastro
# 13  -74.043659       Asignada por Catastro
# 14  -74.060978       Asignada por Catastro
# 15  -74.065798       Asignada por Catastro
# 16  -74.062186       Asignada por Catastro
# 17  -74.029282       Asignada por Catastro
# 18  -74.032147       Asignada por Catastro
# 19  -74.101051       Asignada por Catastro
# 20  -74.041877       Asignada por Catastro
# 21  -74.029891       Asignada por Catastro
# 22  -74.054747       Asignada por Catastro
# 23  -74.126803  Dirección por aproximación
# 24  -74.059607       Asignada por Catastro
# 25  -74.030845       Asignada por Catastro
# 26  -74.045104  Dirección por aproximación
# 27  -74.050031           Dirección antigua
# 28  -74.041863       Asignada por Catastro
# 29  -74.041408       Asignada por Catastro
# 30  -74.054677       Asignada por Catastro
# 31  -74.063160       Asignada por Catastro
# 32  -74.042136       Asignada por Catastro
# 33  -74.056403       Asignada por Catastro
# 34  -74.061558       Asignada por Catastro
# 35  -74.042428       Asignada por Catastro
# 36  -74.052363       Asignada por Catastro
# 37  -74.062659       Asignada por Catastro
# 38  -74.040183       Asignada por Catastro
# 39  -74.063993       Asignada por Catastro
# 40  -74.061187       Asignada por Catastro
# 41  -74.136712       Asignada por Catastro
# 42  -74.038377       Asignada por Catastro
# 43  -74.082988       Asignada por Catastro
# 44  -74.077638       Asignada por Catastro
# 45  -74.034893       Asignada por Catastro
# 46  -74.054166       Asignada por Catastro
# 47  -74.059040           Dirección antigua
# 48  -74.060214       Asignada por Catastro
# 49  -74.044121       Asignada por Catastro
# 50  -74.039439       Asignada por Catastro
# 51  -74.074287  Dirección por aproximación
# 52  -74.038216       Asignada por Catastro
# 53  -74.055632  Dirección por aproximación
# 54  -74.031508       Asignada por Catastro
# 55  -74.062074       Asignada por Catastro
# 56  -74.040457       Asignada por Catastro
# 57  -74.051163       Asignada por Catastro
# 58  -74.053994       Asignada por Catastro
# 59  -74.056747           Dirección antigua
# 60  -74.082483       Asignada por Catastro
# 61  -74.050187       Asignada por Catastro
# 62  -74.028509       Asignada por Catastro
# 63  -74.057040       Asignada por Catastro
# 64  -74.061823       Asignada por Catastro
# 65  -74.039376       Asignada por Catastro
# 66  -74.044586       Asignada por Catastro
# 67  -74.062560       Asignada por Catastro
# 68  -74.065534       Asignada por Catastro
# 69  -74.065673       Asignada por Catastro
# 70  -74.029167       Asignada por Catastro
# 71  -74.048444  Dirección por aproximación
# 72  -74.048518       Asignada por Catastro
# 73  -74.043547       Asignada por Catastro
# 74  -74.065798       Asignada por Catastro
# 75  -74.055673       Asignada por Catastro
# 76  -74.034521       Asignada por Catastro
# 77  -74.061169       Asignada por Catastro
# 78  -74.046968       Asignada por Catastro
# 79  -74.057637       Asignada por Catastro
# 80  -74.030595       Asignada por Catastro
# 81  -74.119521       Asignada por Catastro
# 82  -74.030256       Asignada por Catastro
# 83  -74.049058       Asignada por Catastro
# 84  -74.041340       Asignada por Catastro
# 85  -74.112587       Asignada por Catastro
# 86  -74.035669       Asignada por Catastro
# 87  -74.039221       Asignada por Catastro
# 88  -74.040013       Asignada por Catastro
# 89  -74.079674       Asignada por Catastro
# 90  -74.054697       Asignada por Catastro
# 91  -74.058663       Asignada por Catastro
# 92  -74.045042       Asignada por Catastro
# 93  -74.061101       Asignada por Catastro
# 94  -74.053472       Asignada por Catastro
# 95  -74.060661       Asignada por Catastro
# 96  -74.046309  Dirección por aproximación
# 97  -74.061469       Asignada por Catastro
# 98  -74.056965       Asignada por Catastro
# 99  -74.082451       Asignada por Catastro
# 100 -74.048856       Asignada por Catastro
# 101 -74.033751       Asignada por Catastro
# 102 -74.112870       Asignada por Catastro
# 103 -74.060146       Asignada por Catastro
# 104 -74.059640       Asignada por Catastro
# 105 -74.053089       Asignada por Catastro
# 106 -74.056162       Asignada por Catastro
# 107 -74.043829       Asignada por Catastro
# 108 -74.121345       Asignada por Catastro
# 109 -74.056028       Asignada por Catastro
# 110 -74.121564  Dirección por aproximación
# 111 -74.055314       Asignada por Catastro
# 112 -74.038143       Asignada por Catastro
# 113 -74.079254       Asignada por Catastro
# 114 -74.039690       Asignada por Catastro
# 115 -74.058806       Asignada por Catastro
# 116 -74.129943       Asignada por Catastro
# 117 -74.048516       Asignada por Catastro
# 118 -74.044104       Asignada por Catastro
# 119 -74.042010       Asignada por Catastro
# 120 -74.127952       Asignada por Catastro
# 121 -74.038143       Asignada por Catastro
# 122 -74.081837       Asignada por Catastro
# 123 -74.130908       Asignada por Catastro
# 124 -74.106424       Asignada por Catastro
# 125 -74.059495       Asignada por Catastro
# 126 -74.036070       Asignada por Catastro
# 127 -74.036477       Asignada por Catastro
# 128 -74.045573       Asignada por Catastro
# 129 -74.044920       Asignada por Catastro
# 130 -74.060485       Asignada por Catastro
# 131 -74.037468       Asignada por Catastro
# 132 -74.046471       Asignada por Catastro
# 133 -74.029427       Asignada por Catastro
# 134 -74.062228       Asignada por Catastro
# 135 -74.040677       Asignada por Catastro
# 136 -74.044726       Asignada por Catastro
# 137 -74.028133       Asignada por Catastro
# 138 -74.041476       Asignada por Catastro
# 139 -74.127952       Asignada por Catastro
# 140 -74.058480  Dirección por aproximación
# 141 -74.046971       Asignada por Catastro
# 142 -74.035859       Asignada por Catastro
# 143 -74.051430       Asignada por Catastro
# 144 -74.032181       Asignada por Catastro
# 145        NaN                        None
# 146 -74.067790       Asignada por Catastro
# 147 -74.036555       Asignada por Catastro
# 148 -74.074407       Asignada por Catastro
# 149 -74.042913       Asignada por Catastro

# %%
pd.set_option('display.max_rows', 10)

# %% [markdown]
# El 0.6% de la muestra aleatoria del segundo dataframe (df_vivienda_usada_arriendo)  no se pudo georeferenciar debido a que el API de geocodificación no encontro coincidencias para la dirección.

# %%
sample_3 = df_comercio_base_proyecto[df_comercio_base_proyecto['Ciudad']=='Bogota'].sample(n=150, random_state=1)[comercio_dir].reset_index()
sample_3['addr'] = sample_3[comercio_dir]
sample_3['source']='df_comercio_base_proyecto'
del sample_3[comercio_dir]
del sample_3['index']
sample_3['geocode_result'] = sample_3['addr'].swifter.apply(georeferenciar)
# Out:
# Pandas Apply:   0%|          | 0/150 [00:00<?, ?it/s]

# %%
sample_3['estado'] = sample_3.apply(lambda x: x['geocode_result']['estado'], axis=1)
sample_3['tipo_direccion'] = sample_3.apply(lambda x: None if x['geocode_result']['estado']!='success' else x['geocode_result']['tipo_direccion'], axis=1)
sample_3['lat'] = sample_3.apply(lambda x: None if x['geocode_result']['estado']!='success' else x['geocode_result']['yinput'], axis=1)
sample_3['lng'] = sample_3.apply(lambda x: None if x['geocode_result']['estado']!='success' else x['geocode_result']['xinput'], axis=1)

# %%
pd.set_option('display.max_rows', None)

# %%
sample_3
# Out:
#                                                   addr  \
# 0                                       Cl. 13 # 65-71
# 1                                 Autonorte # 106 - 71
# 2                                       Cr. 14 # 96-35
# 3                            Vereda Canavita Tocancipa
# 4                                     Cl 134a # 19 -15
# 5                              Av Caracas # 49- 51 Sur
# 6                                     Tr. 59 # 104B-86
# 7                                      Cr. 11B # 96-79
# 8                                      Cr. 11 # 93A-53
# 9                                  Vía Siberia Km. 9,5
# 10               Cl. 83 con paralela. Costado Oriental
# 11                                      Cl. 73 # 11-12
# 12                                      Cr. 15 # 80-13
# 13                                     Av. 19 # 104-05
# 14                                     Av. 19 # 114-09
# 15                                 Cl 22 Sur # 24b -60
# 16                       Km 3 Vía Gachancipá  Sesquile
# 17                                    Cl. 100 # 49 -19
# 18                                  Cl. 71 Con Caracas
# 19                                         Vía Sibería
# 20                                Av. Cr. 45 # 123-14
# 21                                  Av Boyaca # 67 -75
# 22                                        Cl. 97 Cr. 8
# 23                                Av Cr. 30 # 25a - 23
# 24                   Vía Troncal de Occidente Calle 13
# 25                                Av. Esperanza Cr. 50
# 26                                     Cra. 7 # 120-20
# 27                                      Cl. 114 # 9-02
# 28                     Entrada Parque Florida 700 mts
# 29                                    Cr. 55 # 152B-58
# 30                                     Cr. 67 # 167-61
# 31          Autopista Medellin . Bogotá Medellín  Km 7
# 32                                   Cl. 99 # 10-08/20
# 33                                    Clle. 90 Cra. 11
# 34                         Av. Suba con Av. C. de Cali
# 35                                      Cl 90 # 16 -09
# 36                                       Cl 21 #  5-44
# 37                                Av. Esperanza Cr. 50
# 38                                     Cl. 53B # 28-85
# 39                                Km 1.4 Vía Chía Cota
# 40                                Cr. 1A # 11-130 Chía
# 41                                      Cl. 26 # 69-63
# 42                                  Av. Cr. 13 # 95-45
# 43                                 Cl. Av. 100 # 13-76
# 44                        Cl. 90 Cra. 19 Costado Norte
# 45                                      Cl. 114 # 9-02
# 46                                   Vía Funza Siberia
# 47                                       Cl. 75 # 7-25
# 48                                      Cr. 11 # 98-35
# 49                      Km. 1.5 Vía Parque Jaime Duque
# 50                                      Cr. 13 # 41-28
# 51                               Cr 38 Con Cl 12y 12 a
# 52                                   Cr. 18a # 127-53
# 53                                      Cra 22 # 10-70
# 54                           Calle 1 # 10-04 Zipaquirá
# 55                                      Cl. 93 # 17-45
# 56                                     Cl. 161 # 17-19
# 57                                    Cl. 25g # 73b-90
# 58                                      Cr 14 # 97 -62
# 59                  Cr. 7 con Cl. 153 costado Oriental
# 60                                     Cr 7 # 180 - 30
# 61                                       Cl. 67 # 7-85
# 62                                    Cl. 102 # 14A-70
# 63                        Av. Pradilla # 6  - 59E Chía
# 64                                    Cra. 96 # 25g-40
# 65                         Av Cl 4 # 21 -33, Zipaquirá
# 66                                    Cr 21 # 13a - 04
# 67                Variante Chia-Cota - Cerca Hard Body
# 68                                 Av. NQS con Cl. 102
# 69                                         Vía Siberia
# 70                                    Calle 93 # 15-27
# 71                                Tr. 93 Av. El Dorado
# 72                                      Cr 7 # 116 -50
# 73                       Av. Ciudad Cali con Esperanza
# 74                       Cl. 80 Contiguo Parq. Florida
# 75                                  Cr 4 # 5a -18 Chía
# 76                                      Cl. 20 # 82-52
# 77                             Av.2 # 9a -29 La Calera
# 78   Vereda Portoachuelo Finca la Fagüita- vía Zipa...
# 79                                     Av. 19 # 103-41
# 80                                    Cra. 54 # 105-46
# 81                           Km 7.5 Autopista Medellin
# 82                            Km 1,6 vía Siberia Ténjo
# 83                                     Cl. 17 # 65B-99
# 84                                  Transv. 23 # 95-35
# 85                                   Vía Funza Siberia
# 86                                      Cr. 14 # 81-19
# 87                         Av. Pradilla # 1a - 90 Chía
# 88                 Autop. Medellín Costado vía Siberia
# 89                                    Cl 104 # 23 - 36
# 90                                 Cr. 15 # 19-60 Chía
# 91                    Av. Cl. 24 con Av.Ciudad de Cali
# 92                    Cl. 100 - 101 entre Cras. 7 a 8B
# 93                   Vìa Bogotà Siberia- Frente Spring
# 94                                      Cl. 98 # 10-07
# 95                                     Cr. 116 # 23-31
# 96                                   Calle 94A # 13-54
# 97                                      Cr. 7 # 156-60
# 98                Km.1 del Peaje de La Troncal de Occ.
# 99                 Km 1 Siberia Funza Costado Oriental
# 100                                   Cra. 7A # 123-27
# 101                                     Cl. 93 # 17-23
# 102                                   Cr. 53 # 104B-35
# 103              Cl.153 Entre Autop Norte y Av. Boyacá
# 104          Km 1.2 Via Siberia Funza Costado Oriental
# 105                                    Cll. 93 # 16-46
# 106             Paralela Autopista Norte con calle 100
# 107                                     Cl. 113 # 7-80
# 108                                    Cr. 106 # 15-25
# 109                                           Mosquera
# 110                                  Cra. 106 # 15A-25
# 111                                  Diag. 24C # 96-25
# 112                    Autopista Sur Con Cr 63 (Makro)
# 113                  Vía Troncal de Occidente Calle 13
# 114                                     Av. 19 # 95-55
# 115                        Cra 11 con calle 85 esquina
# 116                     Av. 19 Cl.103 Costado Oriental
# 117                              Av. Esperanza # 62-49
# 118                                    Cl. 98 # 21-36
# 119                                    Cl 19 con Cr 33
# 120                          Km 7.5 Autopista Medellin
# 121                                    Cr. 7 Con Cl.82
# 122                                   Cll. 22 # 44C-90
# 123           Salida peaje cl. 13, 200 mts costado sur
# 124     Km 2.3 via Cerrito Frente al Parque la Florida
# 125                                     Cl. 99 # 9A-31
# 126                                      Cl. 80 # 9-12
# 127                                     Av. 19 # 97-51
# 128                                    Cr. 11B # 96-36
# 129                      Cl. 103 paralela Autop. Norte
# 130                                   Cl. 127 # 22c-18
# 131                                    Cra. 7 # 120-20
# 132                                  Km. 22 Aut. Norte
# 133                                 Cr 2 # 2-62 Cajicá
# 134                                      Cr. 7 # 75-65
# 135              Km 2 Vía Chia Cajicá Costado Oriental
# 136                                       Cl 56 # 6-23
# 137                        Av. 26 Al lado Puente áereo
# 138                                 Vía Sibería Bogotá
# 139                                     Cr. 82A # 6-16
# 140                             Av. Pradilla 2 Este-71
# 141                              Autop. Norte # 118-86
# 142                                      Cr. 7 # 59-14
# 143                                      Cl. 98 # 8-28
# 144                              Av. Chilacos # 1 - 22
# 145                                  Cra. 47 A # 95-54
# 146                             Via Siberia Funza Km 1
# 147                  Vía Troncal de Occidente Calle 13
# 148              Av Villavicencio con Av Gaitán Cortés
# 149                                  Cl. 69 con Cra. 7
#
#                         source  \
# 0    df_comercio_base_proyecto
# 1    df_comercio_base_proyecto
# 2    df_comercio_base_proyecto
# 3    df_comercio_base_proyecto
# 4    df_comercio_base_proyecto
# 5    df_comercio_base_proyecto
# 6    df_comercio_base_proyecto
# 7    df_comercio_base_proyecto
# 8    df_comercio_base_proyecto
# 9    df_comercio_base_proyecto
# 10   df_comercio_base_proyecto
# 11   df_comercio_base_proyecto
# 12   df_comercio_base_proyecto
# 13   df_comercio_base_proyecto
# 14   df_comercio_base_proyecto
# 15   df_comercio_base_proyecto
# 16   df_comercio_base_proyecto
# 17   df_comercio_base_proyecto
# 18   df_comercio_base_proyecto
# 19   df_comercio_base_proyecto
# 20   df_comercio_base_proyecto
# 21   df_comercio_base_proyecto
# 22   df_comercio_base_proyecto
# 23   df_comercio_base_proyecto
# 24   df_comercio_base_proyecto
# 25   df_comercio_base_proyecto
# 26   df_comercio_base_proyecto
# 27   df_comercio_base_proyecto
# 28   df_comercio_base_proyecto
# 29   df_comercio_base_proyecto
# 30   df_comercio_base_proyecto
# 31   df_comercio_base_proyecto
# 32   df_comercio_base_proyecto
# 33   df_comercio_base_proyecto
# 34   df_comercio_base_proyecto
# 35   df_comercio_base_proyecto
# 36   df_comercio_base_proyecto
# 37   df_comercio_base_proyecto
# 38   df_comercio_base_proyecto
# 39   df_comercio_base_proyecto
# 40   df_comercio_base_proyecto
# 41   df_comercio_base_proyecto
# 42   df_comercio_base_proyecto
# 43   df_comercio_base_proyecto
# 44   df_comercio_base_proyecto
# 45   df_comercio_base_proyecto
# 46   df_comercio_base_proyecto
# 47   df_comercio_base_proyecto
# 48   df_comercio_base_proyecto
# 49   df_comercio_base_proyecto
# 50   df_comercio_base_proyecto
# 51   df_comercio_base_proyecto
# 52   df_comercio_base_proyecto
# 53   df_comercio_base_proyecto
# 54   df_comercio_base_proyecto
# 55   df_comercio_base_proyecto
# 56   df_comercio_base_proyecto
# 57   df_comercio_base_proyecto
# 58   df_comercio_base_proyecto
# 59   df_comercio_base_proyecto
# 60   df_comercio_base_proyecto
# 61   df_comercio_base_proyecto
# 62   df_comercio_base_proyecto
# 63   df_comercio_base_proyecto
# 64   df_comercio_base_proyecto
# 65   df_comercio_base_proyecto
# 66   df_comercio_base_proyecto
# 67   df_comercio_base_proyecto
# 68   df_comercio_base_proyecto
# 69   df_comercio_base_proyecto
# 70   df_comercio_base_proyecto
# 71   df_comercio_base_proyecto
# 72   df_comercio_base_proyecto
# 73   df_comercio_base_proyecto
# 74   df_comercio_base_proyecto
# 75   df_comercio_base_proyecto
# 76   df_comercio_base_proyecto
# 77   df_comercio_base_proyecto
# 78   df_comercio_base_proyecto
# 79   df_comercio_base_proyecto
# 80   df_comercio_base_proyecto
# 81   df_comercio_base_proyecto
# 82   df_comercio_base_proyecto
# 83   df_comercio_base_proyecto
# 84   df_comercio_base_proyecto
# 85   df_comercio_base_proyecto
# 86   df_comercio_base_proyecto
# 87   df_comercio_base_proyecto
# 88   df_comercio_base_proyecto
# 89   df_comercio_base_proyecto
# 90   df_comercio_base_proyecto
# 91   df_comercio_base_proyecto
# 92   df_comercio_base_proyecto
# 93   df_comercio_base_proyecto
# 94   df_comercio_base_proyecto
# 95   df_comercio_base_proyecto
# 96   df_comercio_base_proyecto
# 97   df_comercio_base_proyecto
# 98   df_comercio_base_proyecto
# 99   df_comercio_base_proyecto
# 100  df_comercio_base_proyecto
# 101  df_comercio_base_proyecto
# 102  df_comercio_base_proyecto
# 103  df_comercio_base_proyecto
# 104  df_comercio_base_proyecto
# 105  df_comercio_base_proyecto
# 106  df_comercio_base_proyecto
# 107  df_comercio_base_proyecto
# 108  df_comercio_base_proyecto
# 109  df_comercio_base_proyecto
# 110  df_comercio_base_proyecto
# 111  df_comercio_base_proyecto
# 112  df_comercio_base_proyecto
# 113  df_comercio_base_proyecto
# 114  df_comercio_base_proyecto
# 115  df_comercio_base_proyecto
# 116  df_comercio_base_proyecto
# 117  df_comercio_base_proyecto
# 118  df_comercio_base_proyecto
# 119  df_comercio_base_proyecto
# 120  df_comercio_base_proyecto
# 121  df_comercio_base_proyecto
# 122  df_comercio_base_proyecto
# 123  df_comercio_base_proyecto
# 124  df_comercio_base_proyecto
# 125  df_comercio_base_proyecto
# 126  df_comercio_base_proyecto
# 127  df_comercio_base_proyecto
# 128  df_comercio_base_proyecto
# 129  df_comercio_base_proyecto
# 130  df_comercio_base_proyecto
# 131  df_comercio_base_proyecto
# 132  df_comercio_base_proyecto
# 133  df_comercio_base_proyecto
# 134  df_comercio_base_proyecto
# 135  df_comercio_base_proyecto
# 136  df_comercio_base_proyecto
# 137  df_comercio_base_proyecto
# 138  df_comercio_base_proyecto
# 139  df_comercio_base_proyecto
# 140  df_comercio_base_proyecto
# 141  df_comercio_base_proyecto
# 142  df_comercio_base_proyecto
# 143  df_comercio_base_proyecto
# 144  df_comercio_base_proyecto
# 145  df_comercio_base_proyecto
# 146  df_comercio_base_proyecto
# 147  df_comercio_base_proyecto
# 148  df_comercio_base_proyecto
# 149  df_comercio_base_proyecto
#
#                                         geocode_result          estado  \
# 0    {'estado': 'success', 'yinput': 4.634684462999...         success
# 1                                 {'estado': 'failed'}          failed
# 2    {'estado': 'success', 'yinput': 4.681524895999...         success
# 3                         {'estado': 'outside_bogota'}  outside_bogota
# 4    {'estado': 'success', 'yinput': 4.719060010000...         success
# 5                                 {'estado': 'failed'}          failed
# 6    {'estado': 'success', 'yinput': 4.693365862000...         success
# 7    {'estado': 'success', 'yinput': 4.680622310999...         success
# 8    {'estado': 'success', 'yinput': 4.676545655999...         success
# 9                         {'estado': 'outside_bogota'}  outside_bogota
# 10                                {'estado': 'failed'}          failed
# 11   {'estado': 'success', 'yinput': 4.658505047999...         success
# 12   {'estado': 'success', 'yinput': 4.666689911999...         success
# 13   {'estado': 'success', 'yinput': 4.69052976, 'l...         success
# 14   {'estado': 'success', 'yinput': 4.697053741999...         success
# 15   {'estado': 'success', 'yinput': 4.585349355000...         success
# 16                        {'estado': 'outside_bogota'}  outside_bogota
# 17   {'estado': 'success', 'yinput': 4.687642052, '...         success
# 18                                {'estado': 'failed'}          failed
# 19                                {'estado': 'failed'}          failed
# 20   {'estado': 'success', 'yinput': 4.704323892999...         success
# 21   {'estado': 'success', 'yinput': 4.681344011000...         success
# 22                                {'estado': 'failed'}          failed
# 23   {'estado': 'success', 'yinput': 4.625718996999...         success
# 24                                {'estado': 'failed'}          failed
# 25                                {'estado': 'failed'}          failed
# 26   {'estado': 'success', 'yinput': 4.696976139000...         success
# 27   {'estado': 'success', 'yinput': 4.692716659999...         success
# 28                                {'estado': 'failed'}          failed
# 29   {'estado': 'success', 'yinput': 4.738778936000...         success
# 30   {'estado': 'success', 'yinput': 4.751921741999...         success
# 31                        {'estado': 'outside_bogota'}  outside_bogota
# 32   {'estado': 'success', 'yinput': 4.681477513, '...         success
# 33   {'estado': 'success', 'yinput': 4.672317482999...         success
# 34                                {'estado': 'failed'}          failed
# 35   {'estado': 'success', 'yinput': 4.674845720000...         success
# 36   {'estado': 'success', 'yinput': 4.606328275000...         success
# 37                                {'estado': 'failed'}          failed
# 38   {'estado': 'success', 'yinput': 4.643859357, '...         success
# 39                        {'estado': 'outside_bogota'}  outside_bogota
# 40                        {'estado': 'outside_bogota'}  outside_bogota
# 41   {'estado': 'success', 'yinput': 4.658241493999...         success
# 42   {'estado': 'success', 'yinput': 4.684063868000...         success
# 43                                {'estado': 'failed'}          failed
# 44   {'estado': 'success', 'yinput': 4.676135402999...         success
# 45   {'estado': 'success', 'yinput': 4.692716659999...         success
# 46                                {'estado': 'failed'}          failed
# 47   {'estado': 'success', 'yinput': 4.653772561999...         success
# 48   {'estado': 'success', 'yinput': 4.681288834999...         success
# 49                        {'estado': 'outside_bogota'}  outside_bogota
# 50   {'estado': 'success', 'yinput': 4.629314647999...         success
# 51                                {'estado': 'failed'}          failed
# 52   {'estado': 'success', 'yinput': 4.706780945999...         success
# 53   {'estado': 'success', 'yinput': 4.606777502, '...         success
# 54                        {'estado': 'outside_bogota'}  outside_bogota
# 55   {'estado': 'success', 'yinput': 4.677725678999...         success
# 56   {'estado': 'success', 'yinput': 4.736538716999...         success
# 57   {'estado': 'success', 'yinput': 4.667475638999...         success
# 58   {'estado': 'success', 'yinput': 4.682012896, '...         success
# 59   {'estado': 'success', 'yinput': 4.727738419999...         success
# 60   {'estado': 'success', 'yinput': 4.756784704999...         success
# 61   {'estado': 'success', 'yinput': 4.651077953000...         success
# 62   {'estado': 'success', 'yinput': 4.687119399999...         success
# 63                        {'estado': 'outside_bogota'}  outside_bogota
# 64   {'estado': 'success', 'yinput': 4.683048128, '...         success
# 65                        {'estado': 'outside_bogota'}  outside_bogota
# 66   {'estado': 'success', 'yinput': 4.609631990000...         success
# 67                                {'estado': 'failed'}          failed
# 68                                {'estado': 'failed'}          failed
# 69                                {'estado': 'failed'}          failed
# 70   {'estado': 'success', 'yinput': 4.676910888000...         success
# 71                                {'estado': 'failed'}          failed
# 72   {'estado': 'success', 'yinput': 4.694312947000...         success
# 73                                {'estado': 'failed'}          failed
# 74                                {'estado': 'failed'}          failed
# 75                        {'estado': 'outside_bogota'}  outside_bogota
# 76   {'estado': 'success', 'yinput': 4.664512483000...         success
# 77                                {'estado': 'failed'}          failed
# 78                        {'estado': 'outside_bogota'}  outside_bogota
# 79   {'estado': 'success', 'yinput': 4.689355475000...         success
# 80   {'estado': 'success', 'yinput': 4.694519555999...         success
# 81                        {'estado': 'outside_bogota'}  outside_bogota
# 82                        {'estado': 'outside_bogota'}  outside_bogota
# 83   {'estado': 'success', 'yinput': 4.639505094000...         success
# 84   {'estado': 'success', 'yinput': 4.683530096000...         success
# 85                                {'estado': 'failed'}          failed
# 86   {'estado': 'success', 'yinput': 4.666920018999...         success
# 87                        {'estado': 'outside_bogota'}  outside_bogota
# 88                                {'estado': 'failed'}          failed
# 89   {'estado': 'success', 'yinput': 4.691243101, '...         success
# 90                        {'estado': 'outside_bogota'}  outside_bogota
# 91                                {'estado': 'failed'}          failed
# 92                                {'estado': 'failed'}          failed
# 93                                {'estado': 'failed'}          failed
# 94   {'estado': 'success', 'yinput': 4.680824165999...         success
# 95   {'estado': 'success', 'yinput': 4.689587496, '...         success
# 96   {'estado': 'success', 'yinput': 4.679570608000...         success
# 97   {'estado': 'success', 'yinput': 4.732702152999...         success
# 98                                {'estado': 'failed'}          failed
# 99                        {'estado': 'outside_bogota'}  outside_bogota
# 100  {'estado': 'success', 'yinput': 4.699017670999...         success
# 101  {'estado': 'success', 'yinput': 4.677569031000...         success
# 102  {'estado': 'success', 'yinput': 4.693783155000...         success
# 103                               {'estado': 'failed'}          failed
# 104                       {'estado': 'outside_bogota'}  outside_bogota
# 105  {'estado': 'success', 'yinput': 4.677442312999...         success
# 106                               {'estado': 'failed'}          failed
# 107  {'estado': 'success', 'yinput': 4.692223936, '...         success
# 108  {'estado': 'success', 'yinput': 4.671194141, '...         success
# 109                       {'estado': 'outside_bogota'}  outside_bogota
# 110  {'estado': 'success', 'yinput': 4.671194141, '...         success
# 111  {'estado': 'success', 'yinput': 4.680951282000...         success
# 112                               {'estado': 'failed'}          failed
# 113                               {'estado': 'failed'}          failed
# 114  {'estado': 'success', 'yinput': 4.683038183000...         success
# 115  {'estado': 'success', 'yinput': 4.668027279, '...         success
# 116                               {'estado': 'failed'}          failed
# 117  {'estado': 'success', 'yinput': 4.637741731999...         success
# 118  {'estado': 'success', 'yinput': 4.685421999000...         success
# 119  {'estado': 'success', 'yinput': 4.620847039000...         success
# 120                       {'estado': 'outside_bogota'}  outside_bogota
# 121                               {'estado': 'failed'}          failed
# 122                               {'estado': 'failed'}          failed
# 123                               {'estado': 'failed'}          failed
# 124                       {'estado': 'outside_bogota'}  outside_bogota
# 125  {'estado': 'success', 'yinput': 4.681031157000...         success
# 126  {'estado': 'success', 'yinput': 4.663361056999...         success
# 127  {'estado': 'success', 'yinput': 4.684095921999...         success
# 128  {'estado': 'success', 'yinput': 4.680095129999...         success
# 129                               {'estado': 'failed'}          failed
# 130                               {'estado': 'failed'}          failed
# 131  {'estado': 'success', 'yinput': 4.696976139000...         success
# 132                       {'estado': 'outside_bogota'}  outside_bogota
# 133  {'estado': 'success', 'yinput': 4.586941642999...         success
# 134  {'estado': 'success', 'yinput': 4.658391785999...         success
# 135                       {'estado': 'outside_bogota'}  outside_bogota
# 136  {'estado': 'success', 'yinput': 4.641840086, '...         success
# 137                               {'estado': 'failed'}          failed
# 138                               {'estado': 'failed'}          failed
# 139  {'estado': 'success', 'yinput': 4.638806838999...         success
# 140                               {'estado': 'failed'}          failed
# 141                               {'estado': 'failed'}          failed
# 142  {'estado': 'success', 'yinput': 4.644370229999...         success
# 143  {'estado': 'success', 'yinput': 4.679408202999...         success
# 144  {'estado': 'success', 'yinput': 4.593959701000...         success
# 145  {'estado': 'success', 'yinput': 4.684523463999...         success
# 146                       {'estado': 'outside_bogota'}  outside_bogota
# 147                               {'estado': 'failed'}          failed
# 148                               {'estado': 'failed'}          failed
# 149  {'estado': 'success', 'yinput': 4.651460830000...         success
#
#                  tipo_direccion       lat        lng
# 0             Dirección antigua  4.634684 -74.115410
# 1                          None       NaN        NaN
# 2    Dirección por aproximación  4.681525 -74.048591
# 3                          None       NaN        NaN
# 4         Asignada por Catastro  4.719060 -74.047144
# 5                          None       NaN        NaN
# 6         Asignada por Catastro  4.693366 -74.066374
# 7         Asignada por Catastro  4.680622 -74.046154
# 8         Asignada por Catastro  4.676546 -74.046677
# 9                          None       NaN        NaN
# 10                         None       NaN        NaN
# 11        Asignada por Catastro  4.658505 -74.058124
# 12        Asignada por Catastro  4.666690 -74.057076
# 13   Dirección por aproximación  4.690530 -74.051136
# 14        Asignada por Catastro  4.697054 -74.050356
# 15        Asignada por Catastro  4.585349 -74.105661
# 16                         None       NaN        NaN
# 17        Asignada por Catastro  4.687642 -74.061206
# 18                         None       NaN        NaN
# 19                         None       NaN        NaN
# 20        Asignada por Catastro  4.704324 -74.053828
# 21   Dirección por aproximación  4.681344 -74.098792
# 22                         None       NaN        NaN
# 23        Asignada por Catastro  4.625719 -74.082629
# 24                         None       NaN        NaN
# 25                         None       NaN        NaN
# 26        Asignada por Catastro  4.696976 -74.031093
# 27            Dirección antigua  4.692717 -74.034414
# 28                         None       NaN        NaN
# 29   Dirección por aproximación  4.738779 -74.057490
# 30        Asignada por Catastro  4.751922 -74.064199
# 31                         None       NaN        NaN
# 32        Asignada por Catastro  4.681478 -74.043033
# 33   Dirección por aproximación  4.672317 -74.048880
# 34                         None       NaN        NaN
# 35        Asignada por Catastro  4.674846 -74.054029
# 36        Asignada por Catastro  4.606328 -74.069791
# 37                         None       NaN        NaN
# 38        Asignada por Catastro  4.643859 -74.078002
# 39                         None       NaN        NaN
# 40                         None       NaN        NaN
# 41        Asignada por Catastro  4.658241 -74.107223
# 42            Dirección antigua  4.684064 -74.058136
# 43                         None       NaN        NaN
# 44   Dirección por aproximación  4.676135 -74.056208
# 45            Dirección antigua  4.692717 -74.034414
# 46                         None       NaN        NaN
# 47   Dirección por aproximación  4.653773 -74.056537
# 48   Dirección por aproximación  4.681289 -74.043909
# 49                         None       NaN        NaN
# 50   Dirección por aproximación  4.629315 -74.066796
# 51                         None       NaN        NaN
# 52   Dirección por aproximación  4.706781 -74.048805
# 53   Dirección por aproximación  4.606778 -74.088931
# 54                         None       NaN        NaN
# 55        Asignada por Catastro  4.677726 -74.053886
# 56            Dirección antigua  4.736539 -74.025943
# 57        Asignada por Catastro  4.667476 -74.113750
# 58   Dirección por aproximación  4.682013 -74.048340
# 59   Dirección por aproximación  4.727738 -74.024480
# 60        Asignada por Catastro  4.756785 -74.024663
# 61        Asignada por Catastro  4.651078 -74.058962
# 62        Asignada por Catastro  4.687119 -74.047350
# 63                         None       NaN        NaN
# 64        Asignada por Catastro  4.683048 -74.124799
# 65                         None       NaN        NaN
# 66        Asignada por Catastro  4.609632 -74.085867
# 67                         None       NaN        NaN
# 68                         None       NaN        NaN
# 69                         None       NaN        NaN
# 70        Asignada por Catastro  4.676911 -74.052323
# 71                         None       NaN        NaN
# 72        Asignada por Catastro  4.694313 -74.032726
# 73                         None       NaN        NaN
# 74                         None       NaN        NaN
# 75                         None       NaN        NaN
# 76   Dirección por aproximación  4.664512 -74.128782
# 77                         None       NaN        NaN
# 78                         None       NaN        NaN
# 79   Dirección por aproximación  4.689355 -74.051653
# 80        Asignada por Catastro  4.694520 -74.063392
# 81                         None       NaN        NaN
# 82                         None       NaN        NaN
# 83        Asignada por Catastro  4.639505 -74.115600
# 84        Asignada por Catastro  4.683530 -74.056640
# 85                         None       NaN        NaN
# 86        Asignada por Catastro  4.666920 -74.055947
# 87                         None       NaN        NaN
# 88                         None       NaN        NaN
# 89        Asignada por Catastro  4.691243 -74.055691
# 90                         None       NaN        NaN
# 91                         None       NaN        NaN
# 92                         None       NaN        NaN
# 93                         None       NaN        NaN
# 94        Asignada por Catastro  4.680824 -74.043367
# 95   Dirección por aproximación  4.689587 -74.147083
# 96        Asignada por Catastro  4.679571 -74.048817
# 97        Asignada por Catastro  4.732702 -74.023865
# 98                         None       NaN        NaN
# 99                         None       NaN        NaN
# 100  Dirección por aproximación  4.699018 -74.030925
# 101       Asignada por Catastro  4.677569 -74.053584
# 102       Asignada por Catastro  4.693783 -74.062809
# 103                        None       NaN        NaN
# 104                        None       NaN        NaN
# 105       Asignada por Catastro  4.677442 -74.053109
# 106                        None       NaN        NaN
# 107       Asignada por Catastro  4.692224 -74.035104
# 108           Dirección antigua  4.671194 -74.155867
# 109                        None       NaN        NaN
# 110       Asignada por Catastro  4.671194 -74.155867
# 111       Asignada por Catastro  4.680951 -74.128779
# 112                        None       NaN        NaN
# 113                        None       NaN        NaN
# 114       Asignada por Catastro  4.683038 -74.052718
# 115  Dirección por aproximación  4.668027 -74.051502
# 116                        None       NaN        NaN
# 117  Dirección por aproximación  4.637742 -74.109751
# 118       Asignada por Catastro  4.685422 -74.055079
# 119  Dirección por aproximación  4.620847 -74.090772
# 120                        None       NaN        NaN
# 121                        None       NaN        NaN
# 122                        None       NaN        NaN
# 123                        None       NaN        NaN
# 124                        None       NaN        NaN
# 125  Dirección por aproximación  4.681031 -74.042169
# 126       Asignada por Catastro  4.663361 -74.052481
# 127  Dirección por aproximación  4.684096 -74.052213
# 128  Dirección por aproximación  4.680095 -74.046428
# 129                        None       NaN        NaN
# 130                        None       NaN        NaN
# 131       Asignada por Catastro  4.696976 -74.031093
# 132                        None       NaN        NaN
# 133  Dirección por aproximación  4.586942 -74.075407
# 134       Asignada por Catastro  4.658392 -74.053393
# 135                        None       NaN        NaN
# 136       Asignada por Catastro  4.641840 -74.061960
# 137                        None       NaN        NaN
# 138                        None       NaN        NaN
# 139       Asignada por Catastro  4.638807 -74.154661
# 140                        None       NaN        NaN
# 141                        None       NaN        NaN
# 142       Asignada por Catastro  4.644370 -74.061457
# 143  Dirección por aproximación  4.679408 -74.040425
# 144  Dirección por aproximación  4.593960 -74.096297
# 145       Asignada por Catastro  4.684523 -74.060228
# 146                        None       NaN        NaN
# 147                        None       NaN        NaN
# 148                        None       NaN        NaN
# 149  Dirección por aproximación  4.651461 -74.057858

# %%
pd.set_option('display.max_rows', 10)

# %%
sample_3['estado'].value_counts(normalize=True)
# Out:
# estado
# success           0.553333
# failed            0.286667
# outside_bogota    0.160000
# Name: proportion, dtype: float64

# %% [markdown]
# El 28% de la muestra aleatoria del tercer dataframe (df_comercio_base_proyecto)  no pudo ser georeferenciada por las siguientes razones:
# * Nombres de vías que no son aceptados por el API
# * Detalles de texto en la dirección
# * Referencia a lugares especificos (no direcciones)
#
# Hay un 16% adicional que hace referencia a direcciones fuera de Bogotá (en otras ciudades o en vías nacionales)

# %%
sample_4 = df_comercio_base_inmuebles[df_comercio_base_inmuebles['Ciudad']=='Bogota'].sample(n=150, random_state=1)[comercio_dir].reset_index()
sample_4['addr'] = sample_4[comercio_dir]
sample_4['source']='df_comercio_base_inmuebles'
del sample_4[comercio_dir]
del sample_4['index']
sample_4['geocode_result'] = sample_4['addr'].swifter.apply(georeferenciar)
# Out:
# Pandas Apply:   0%|          | 0/150 [00:00<?, ?it/s]

# %%
sample_4['estado'] = sample_4.apply(lambda x: x['geocode_result']['estado'], axis=1)
sample_4['tipo_direccion'] = sample_4.apply(lambda x: None if x['geocode_result']['estado']!='success' else x['geocode_result']['tipo_direccion'], axis=1)
sample_4['lat'] = sample_4.apply(lambda x: None if x['geocode_result']['estado']!='success' else x['geocode_result']['yinput'], axis=1)
sample_4['lng'] = sample_4.apply(lambda x: None if x['geocode_result']['estado']!='success' else x['geocode_result']['xinput'], axis=1)

# %%
pd.set_option('display.max_rows', None)

# %%
sample_4
# Out:
#                                                   addr  \
# 0        Km 28 Vía Cajicá 50 mts antes de San Jeronimo
# 1                                    Av. Cl. 26-96J-90
# 2                                      Av. 19 # 116-71
# 3                                   Calle 140 # 10A-48
# 4                                       Cl 90 # 16 -09
# 5                                    Av. Cl. 26-96J-90
# 6                                      Cl. 18 # 77- 51
# 7                            Km 19 Vía Bogotá Mosquera
# 8                                  Vía Mosquera Bogotá
# 9                                  Av. Cl. 24 # 95A-80
# 10                    Cl. 100 - 101 entre Cras. 7 a 8B
# 11                                     Cl. 28 # 13A-24
# 12                                      Cra 13 # 35-37
# 13                                     Cr. 19A # 90-13
# 14                                     Cra. 14 # 76-10
# 15                                  Cra. 9 con Cl. 115
# 16                                    Av. 19 Cl. 95-12
# 17                                Cll 80 Cr 28 Esquina
# 18                                  Cra. 70C # 96 - 95
# 19                                       Cl 67 # 11-98
# 20                                 Av. Cra. 7 # 127-87
# 21                           Vereda Canavita Tocancipa
# 22                                  Calle 140 # 10A-48
# 23                        Av. Cl. 72 con Av. Cdad Cali
# 24                                 Vía Funza a Siberia
# 25                                     Cl. 90 # 13A-93
# 26                           Km 19 Vía Bogotá Mosquera
# 27                                            Mosquera
# 28                                 Dig 77b # 120a - 40
# 29                                     Cl. 90 # 13A-43
# 30                                      Cl. 20 # 82-52
# 31                                  Av. Boyacá # 83-50
# 32                        Av. Cl. 72 con Av. Cdad Cali
# 33                                      Cr. 13 # 96-67
# 34                                         Vía Siberia
# 35                                     Cr. 11A # 94-45
# 36                                    Av. 19 Cl. 95-12
# 37                                     Cl. 17 # 65B-99
# 38                                     Cr. 19C   89-20
# 39           C.C. Bima Autop. Norte Costado Occidental
# 40           C.C. Bima Autop. Norte Costado Occidental
# 41                             Av.2 # 9a -29 La Calera
# 42                                      Cr 14 # 127-45
# 43                                      Cr. 13 # 96-67
# 44                                     Tr. 30 # 124-91
# 45                                      Cl. 98 # 9A-46
# 46                                   Vía Funza Siberia
# 47                                     Cr. 47A # 95-91
# 48            Autopista Norte. Cra 7, Costado Oriental
# 49                           Vereda Canavita Tocancipa
# 50                                 Cr. 15 # 19-60 Chía
# 51                                       Cr. 7 # 23-85
# 52                                 Av. NQS con Cl. 102
# 53                     Entrada Parque Florida 700 mts
# 54                                      Cr 18 # 93 -15
# 55                                      Cl. 13 # 65-71
# 56                                      Cr 14 # 127-45
# 57                               Cl. 18 con Cr. 29 Sur
# 58   Troncal de Occidente Vía Funza Bogotá 200 mts ...
# 59               Cl.153 Entre Autop Norte y Av. Boyacá
# 60                                      Cr 14 # 127-45
# 61                                    Cr. 55 # 152B-58
# 62                Variante Chia-Cota frente a Parmalat
# 63                           Vereda Canavita Tocancipa
# 64                                     Cra 11B # 96-70
# 65                             Av.2 # 9a -29 La Calera
# 66                                     Calle 93 con 12
# 67                           Km 19 Vía Bogotá Mosquera
# 68                                     Cr. 18 # 93B-31
# 69                                   Vía Funza Siberia
# 70                           Vereda Canavita Tocancipa
# 71                                      Cr 14 # 127-45
# 72                                      Cra 13 # 35-37
# 73   Troncal de Occidente Vía Funza Bogotá 200 mts ...
# 74                                      Cr. 11 # 98-35
# 75                      Eje Chia Cajicá vereda Canelon
# 76                                      Cl. 98 # 9A-46
# 77            Av. El Dorado con Ciudad de Cali # 51-66
# 78                               Cr. 13 Cl. 3 Mosquera
# 79                                      Cra 16 # 93-08
# 80                                      Cr. 13 # 96-67
# 81                                  Av 19 Con 127 Bis
# 82                         Vereda Pueblo Vía Cota Chia
# 83                                     Cl. 26 # 69D-91
# 84                                     Cr 18 # 14 - 04
# 85                                      Cra 13 # 35-37
# 86                                  Calle 140 # 10A-48
# 87                           Km 1.5 Vía Siberia - Cota
# 88                                      Cra 13 # 35-37
# 89                                     Cra. 14 # 76-10
# 90                                      Cl. 26 # 69-63
# 91                                     Av. 19 # 108-11
# 92                                      Cra 15 # 93-84
# 93                                         Centro Chía
# 94                                      Cra. 7 # 63-44
# 95                                       Cr. 7 # 23-85
# 96                                  Cra. 68 con Cl. 95
# 97                                      Cr. 11 # 98-75
# 98               Km 2 Vía Chia Cajicá Costado Oriental
# 99                                     Av. 9 # 103A-36
# 100                                     Cra. 7 # 59-54
# 101                                     Cra 13 # 35-37
# 102                                     Cra 22 # 10-69
# 103                                    Cl.139 # 96A-35
# 104                                 Cra. 70C # 96 - 95
# 105                                 Vía Sibería Bogotá
# 106                                    Av. 19 # 120-33
# 107                                   Cl 128c # 47 -62
# 108                             Km. 15 Vía Chia-Cajicá
# 109                                   Cra. 96 # 25g-40
# 110                                    Cl. 140 # 11 45
# 111                                     Cra. 7 # 59-54
# 112                                     Cl. 96 Cra. 11
# 113                                Clle 116 # 17a - 20
# 114                                    Cl. 28 # 13A-24
# 115                                 Av 19 Con 127 Bis
# 116             Entrada Jaime Duque Entrada Ind.Crown
# 117                                     Cr. 11 # 84-50
# 118                                   Cr. 53 # 104B-35
# 119                                     Cra. 7 # 59-55
# 120                             Km. 15 Vía Chia-Cajicá
# 121               Variante Chia-Cota frente a Parmalat
# 122                                 Cra. 9 con Cl. 115
# 123                                      Cr. 7 # 75-65
# 124                  Km. 2 Autop. Medellín Costado Sur
# 125                                    Cr. 19A # 90-13
# 126                                     Cra. 7 # 59-54
# 127  Autop. Norte 630 mts antes de la planta Bavari...
# 128                                   Cr. 11A # 97A-19
# 129                                     Cl. 20 # 82-52
# 130                                     Cr. 16 # 93-86
# 131                      Km 3 Vía Gachancipá  Sesquile
# 132                                    Cll. 93 # 16-46
# 133                                    Cl. 106 # 54-14
# 134                          Autop. Medellín- Km. 8,5
# 135                                   Tr. Suba Cr. 101
# 136                                  Cr 21 # 24 51 Sur
# 137                                 Cr 4 # 5a -18 Chía
# 138                                  Vía Funza Siberia
# 139                                      Cr. 4 # 16-03
# 140  Av. La Esperanza con futura Av. Longitudinal d...
# 141                                    Cl. 106 # 57-11
# 142                            Km 55 vía Bogotá Tunja
# 143                                     Cra 7 # 119-45
# 144                           Km 2.5 Vía Cajicá- Tabio
# 145                                     Cr. 15 # 80-13
# 146                                     Cr. 11 # 98-75
# 147                      Cl. 80 Contiguo Parq. Florida
# 148                  K.m. 2 Vía Chia-Cajicá -Farmatodo
# 149                                    Cra. 15 # 88-21
#
#                          source  \
# 0    df_comercio_base_inmuebles
# 1    df_comercio_base_inmuebles
# 2    df_comercio_base_inmuebles
# 3    df_comercio_base_inmuebles
# 4    df_comercio_base_inmuebles
# 5    df_comercio_base_inmuebles
# 6    df_comercio_base_inmuebles
# 7    df_comercio_base_inmuebles
# 8    df_comercio_base_inmuebles
# 9    df_comercio_base_inmuebles
# 10   df_comercio_base_inmuebles
# 11   df_comercio_base_inmuebles
# 12   df_comercio_base_inmuebles
# 13   df_comercio_base_inmuebles
# 14   df_comercio_base_inmuebles
# 15   df_comercio_base_inmuebles
# 16   df_comercio_base_inmuebles
# 17   df_comercio_base_inmuebles
# 18   df_comercio_base_inmuebles
# 19   df_comercio_base_inmuebles
# 20   df_comercio_base_inmuebles
# 21   df_comercio_base_inmuebles
# 22   df_comercio_base_inmuebles
# 23   df_comercio_base_inmuebles
# 24   df_comercio_base_inmuebles
# 25   df_comercio_base_inmuebles
# 26   df_comercio_base_inmuebles
# 27   df_comercio_base_inmuebles
# 28   df_comercio_base_inmuebles
# 29   df_comercio_base_inmuebles
# 30   df_comercio_base_inmuebles
# 31   df_comercio_base_inmuebles
# 32   df_comercio_base_inmuebles
# 33   df_comercio_base_inmuebles
# 34   df_comercio_base_inmuebles
# 35   df_comercio_base_inmuebles
# 36   df_comercio_base_inmuebles
# 37   df_comercio_base_inmuebles
# 38   df_comercio_base_inmuebles
# 39   df_comercio_base_inmuebles
# 40   df_comercio_base_inmuebles
# 41   df_comercio_base_inmuebles
# 42   df_comercio_base_inmuebles
# 43   df_comercio_base_inmuebles
# 44   df_comercio_base_inmuebles
# 45   df_comercio_base_inmuebles
# 46   df_comercio_base_inmuebles
# 47   df_comercio_base_inmuebles
# 48   df_comercio_base_inmuebles
# 49   df_comercio_base_inmuebles
# 50   df_comercio_base_inmuebles
# 51   df_comercio_base_inmuebles
# 52   df_comercio_base_inmuebles
# 53   df_comercio_base_inmuebles
# 54   df_comercio_base_inmuebles
# 55   df_comercio_base_inmuebles
# 56   df_comercio_base_inmuebles
# 57   df_comercio_base_inmuebles
# 58   df_comercio_base_inmuebles
# 59   df_comercio_base_inmuebles
# 60   df_comercio_base_inmuebles
# 61   df_comercio_base_inmuebles
# 62   df_comercio_base_inmuebles
# 63   df_comercio_base_inmuebles
# 64   df_comercio_base_inmuebles
# 65   df_comercio_base_inmuebles
# 66   df_comercio_base_inmuebles
# 67   df_comercio_base_inmuebles
# 68   df_comercio_base_inmuebles
# 69   df_comercio_base_inmuebles
# 70   df_comercio_base_inmuebles
# 71   df_comercio_base_inmuebles
# 72   df_comercio_base_inmuebles
# 73   df_comercio_base_inmuebles
# 74   df_comercio_base_inmuebles
# 75   df_comercio_base_inmuebles
# 76   df_comercio_base_inmuebles
# 77   df_comercio_base_inmuebles
# 78   df_comercio_base_inmuebles
# 79   df_comercio_base_inmuebles
# 80   df_comercio_base_inmuebles
# 81   df_comercio_base_inmuebles
# 82   df_comercio_base_inmuebles
# 83   df_comercio_base_inmuebles
# 84   df_comercio_base_inmuebles
# 85   df_comercio_base_inmuebles
# 86   df_comercio_base_inmuebles
# 87   df_comercio_base_inmuebles
# 88   df_comercio_base_inmuebles
# 89   df_comercio_base_inmuebles
# 90   df_comercio_base_inmuebles
# 91   df_comercio_base_inmuebles
# 92   df_comercio_base_inmuebles
# 93   df_comercio_base_inmuebles
# 94   df_comercio_base_inmuebles
# 95   df_comercio_base_inmuebles
# 96   df_comercio_base_inmuebles
# 97   df_comercio_base_inmuebles
# 98   df_comercio_base_inmuebles
# 99   df_comercio_base_inmuebles
# 100  df_comercio_base_inmuebles
# 101  df_comercio_base_inmuebles
# 102  df_comercio_base_inmuebles
# 103  df_comercio_base_inmuebles
# 104  df_comercio_base_inmuebles
# 105  df_comercio_base_inmuebles
# 106  df_comercio_base_inmuebles
# 107  df_comercio_base_inmuebles
# 108  df_comercio_base_inmuebles
# 109  df_comercio_base_inmuebles
# 110  df_comercio_base_inmuebles
# 111  df_comercio_base_inmuebles
# 112  df_comercio_base_inmuebles
# 113  df_comercio_base_inmuebles
# 114  df_comercio_base_inmuebles
# 115  df_comercio_base_inmuebles
# 116  df_comercio_base_inmuebles
# 117  df_comercio_base_inmuebles
# 118  df_comercio_base_inmuebles
# 119  df_comercio_base_inmuebles
# 120  df_comercio_base_inmuebles
# 121  df_comercio_base_inmuebles
# 122  df_comercio_base_inmuebles
# 123  df_comercio_base_inmuebles
# 124  df_comercio_base_inmuebles
# 125  df_comercio_base_inmuebles
# 126  df_comercio_base_inmuebles
# 127  df_comercio_base_inmuebles
# 128  df_comercio_base_inmuebles
# 129  df_comercio_base_inmuebles
# 130  df_comercio_base_inmuebles
# 131  df_comercio_base_inmuebles
# 132  df_comercio_base_inmuebles
# 133  df_comercio_base_inmuebles
# 134  df_comercio_base_inmuebles
# 135  df_comercio_base_inmuebles
# 136  df_comercio_base_inmuebles
# 137  df_comercio_base_inmuebles
# 138  df_comercio_base_inmuebles
# 139  df_comercio_base_inmuebles
# 140  df_comercio_base_inmuebles
# 141  df_comercio_base_inmuebles
# 142  df_comercio_base_inmuebles
# 143  df_comercio_base_inmuebles
# 144  df_comercio_base_inmuebles
# 145  df_comercio_base_inmuebles
# 146  df_comercio_base_inmuebles
# 147  df_comercio_base_inmuebles
# 148  df_comercio_base_inmuebles
# 149  df_comercio_base_inmuebles
#
#                                         geocode_result          estado  \
# 0                         {'estado': 'outside_bogota'}  outside_bogota
# 1    {'estado': 'success', 'yinput': 4.687553716000...         success
# 2    {'estado': 'success', 'yinput': 4.698798936999...         success
# 3    {'estado': 'success', 'yinput': 4.718609199000...         success
# 4    {'estado': 'success', 'yinput': 4.674845720000...         success
# 5    {'estado': 'success', 'yinput': 4.687553716000...         success
# 6    {'estado': 'success', 'yinput': 4.654305454999...         success
# 7                         {'estado': 'outside_bogota'}  outside_bogota
# 8                         {'estado': 'outside_bogota'}  outside_bogota
# 9    {'estado': 'success', 'yinput': 4.680582147999...         success
# 10                                {'estado': 'failed'}          failed
# 11   {'estado': 'success', 'yinput': 4.616364152000...         success
# 12   {'estado': 'success', 'yinput': 4.623597277999...         success
# 13   {'estado': 'success', 'yinput': 4.676583640999...         success
# 14   {'estado': 'success', 'yinput': 4.662634496000...         success
# 15   {'estado': 'success', 'yinput': 4.693008580000...         success
# 16                                {'estado': 'failed'}          failed
# 17   {'estado': 'success', 'yinput': 4.671357086999...         success
# 18   {'estado': 'success', 'yinput': 4.692805865000...         success
# 19   {'estado': 'success', 'yinput': 4.653367844999...         success
# 20   {'estado': 'success', 'yinput': 4.702397951000...         success
# 21                        {'estado': 'outside_bogota'}  outside_bogota
# 22   {'estado': 'success', 'yinput': 4.718609199000...         success
# 23                                {'estado': 'failed'}          failed
# 24                                {'estado': 'failed'}          failed
# 25   {'estado': 'success', 'yinput': 4.673790870999...         success
# 26                        {'estado': 'outside_bogota'}  outside_bogota
# 27                        {'estado': 'outside_bogota'}  outside_bogota
# 28   {'estado': 'success', 'yinput': 4.722853470000...         success
# 29   {'estado': 'success', 'yinput': 4.673790870999...         success
# 30   {'estado': 'success', 'yinput': 4.664512483000...         success
# 31                                {'estado': 'failed'}          failed
# 32                                {'estado': 'failed'}          failed
# 33   {'estado': 'success', 'yinput': 4.681090598000...         success
# 34                                {'estado': 'failed'}          failed
# 35   {'estado': 'success', 'yinput': 4.678170584999...         success
# 36                                {'estado': 'failed'}          failed
# 37   {'estado': 'success', 'yinput': 4.639505094000...         success
# 38   {'estado': 'success', 'yinput': 4.676269355999...         success
# 39                                {'estado': 'failed'}          failed
# 40                                {'estado': 'failed'}          failed
# 41                                {'estado': 'failed'}          failed
# 42   {'estado': 'success', 'yinput': 4.705100947000...         success
# 43   {'estado': 'success', 'yinput': 4.681090598000...         success
# 44                                {'estado': 'failed'}          failed
# 45   {'estado': 'success', 'yinput': 4.68070229, 'l...         success
# 46                                {'estado': 'failed'}          failed
# 47   {'estado': 'success', 'yinput': 4.684117480999...         success
# 48                                {'estado': 'failed'}          failed
# 49                        {'estado': 'outside_bogota'}  outside_bogota
# 50                        {'estado': 'outside_bogota'}  outside_bogota
# 51   {'estado': 'success', 'yinput': 4.609981952, '...         success
# 52                                {'estado': 'failed'}          failed
# 53                                {'estado': 'failed'}          failed
# 54   {'estado': 'success', 'yinput': 4.678167675999...         success
# 55   {'estado': 'success', 'yinput': 4.634684462999...         success
# 56   {'estado': 'success', 'yinput': 4.705100947000...         success
# 57   {'estado': 'success', 'yinput': 4.592278759000...         success
# 58                                {'estado': 'failed'}          failed
# 59                                {'estado': 'failed'}          failed
# 60   {'estado': 'success', 'yinput': 4.705100947000...         success
# 61   {'estado': 'success', 'yinput': 4.738778936000...         success
# 62                                {'estado': 'failed'}          failed
# 63                        {'estado': 'outside_bogota'}  outside_bogota
# 64   {'estado': 'success', 'yinput': 4.680376326999...         success
# 65                                {'estado': 'failed'}          failed
# 66   {'estado': 'success', 'yinput': 4.675184461000...         success
# 67                        {'estado': 'outside_bogota'}  outside_bogota
# 68   {'estado': 'success', 'yinput': 4.680038361000...         success
# 69                                {'estado': 'failed'}          failed
# 70                        {'estado': 'outside_bogota'}  outside_bogota
# 71   {'estado': 'success', 'yinput': 4.705100947000...         success
# 72   {'estado': 'success', 'yinput': 4.623597277999...         success
# 73                                {'estado': 'failed'}          failed
# 74   {'estado': 'success', 'yinput': 4.681288834999...         success
# 75                        {'estado': 'outside_bogota'}  outside_bogota
# 76   {'estado': 'success', 'yinput': 4.68070229, 'l...         success
# 77                                {'estado': 'failed'}          failed
# 78                        {'estado': 'outside_bogota'}  outside_bogota
# 79   {'estado': 'success', 'yinput': 4.677318988000...         success
# 80   {'estado': 'success', 'yinput': 4.681090598000...         success
# 81                                {'estado': 'failed'}          failed
# 82                        {'estado': 'outside_bogota'}  outside_bogota
# 83   {'estado': 'success', 'yinput': 4.661847078999...         success
# 84   {'estado': 'success', 'yinput': 4.607482844999...         success
# 85   {'estado': 'success', 'yinput': 4.623597277999...         success
# 86   {'estado': 'success', 'yinput': 4.718609199000...         success
# 87                        {'estado': 'outside_bogota'}  outside_bogota
# 88   {'estado': 'success', 'yinput': 4.623597277999...         success
# 89   {'estado': 'success', 'yinput': 4.662634496000...         success
# 90   {'estado': 'success', 'yinput': 4.658241493999...         success
# 91   {'estado': 'success', 'yinput': 4.694440611, '...         success
# 92   {'estado': 'success', 'yinput': 4.677485134999...         success
# 93                        {'estado': 'outside_bogota'}  outside_bogota
# 94   {'estado': 'success', 'yinput': 4.648157078999...         success
# 95   {'estado': 'success', 'yinput': 4.609981952, '...         success
# 96   {'estado': 'success', 'yinput': 4.686965333999...         success
# 97   {'estado': 'success', 'yinput': 4.681288834999...         success
# 98                        {'estado': 'outside_bogota'}  outside_bogota
# 99   {'estado': 'success', 'yinput': 4.687266022000...         success
# 100  {'estado': 'success', 'yinput': 4.644601755, '...         success
# 101  {'estado': 'success', 'yinput': 4.623597277999...         success
# 102  {'estado': 'success', 'yinput': 4.606277251999...         success
# 103  {'estado': 'success', 'yinput': 4.738871945000...         success
# 104  {'estado': 'success', 'yinput': 4.692805865000...         success
# 105                               {'estado': 'failed'}          failed
# 106  {'estado': 'success', 'yinput': 4.700861551, '...         success
# 107  {'estado': 'success', 'yinput': 4.714903927000...         success
# 108                       {'estado': 'outside_bogota'}  outside_bogota
# 109  {'estado': 'success', 'yinput': 4.683048128, '...         success
# 110  {'estado': 'success', 'yinput': 4.719039396000...         success
# 111  {'estado': 'success', 'yinput': 4.644601755, '...         success
# 112                               {'estado': 'failed'}          failed
# 113  {'estado': 'success', 'yinput': 4.697485723, '...         success
# 114  {'estado': 'success', 'yinput': 4.616364152000...         success
# 115                               {'estado': 'failed'}          failed
# 116                               {'estado': 'failed'}          failed
# 117  {'estado': 'success', 'yinput': 4.670190236, '...         success
# 118  {'estado': 'success', 'yinput': 4.693783155000...         success
# 119  {'estado': 'success', 'yinput': 4.644300989999...         success
# 120                       {'estado': 'outside_bogota'}  outside_bogota
# 121                               {'estado': 'failed'}          failed
# 122  {'estado': 'success', 'yinput': 4.693008580000...         success
# 123  {'estado': 'success', 'yinput': 4.658391785999...         success
# 124                       {'estado': 'outside_bogota'}  outside_bogota
# 125  {'estado': 'success', 'yinput': 4.676583640999...         success
# 126  {'estado': 'success', 'yinput': 4.644601755, '...         success
# 127                               {'estado': 'failed'}          failed
# 128  {'estado': 'success', 'yinput': 4.681332581999...         success
# 129  {'estado': 'success', 'yinput': 4.664512483000...         success
# 130  {'estado': 'success', 'yinput': 4.677993449999...         success
# 131                       {'estado': 'outside_bogota'}  outside_bogota
# 132  {'estado': 'success', 'yinput': 4.677442312999...         success
# 133  {'estado': 'success', 'yinput': 4.694812367999...         success
# 134                       {'estado': 'outside_bogota'}  outside_bogota
# 135                               {'estado': 'failed'}          failed
# 136  {'estado': 'success', 'yinput': 4.583362522000...         success
# 137                       {'estado': 'outside_bogota'}  outside_bogota
# 138                               {'estado': 'failed'}          failed
# 139  {'estado': 'success', 'yinput': 4.601121324000...         success
# 140                               {'estado': 'failed'}          failed
# 141  {'estado': 'success', 'yinput': 4.694146788000...         success
# 142                       {'estado': 'outside_bogota'}  outside_bogota
# 143  {'estado': 'success', 'yinput': 4.695931938, '...         success
# 144                       {'estado': 'outside_bogota'}  outside_bogota
# 145  {'estado': 'success', 'yinput': 4.666689911999...         success
# 146  {'estado': 'success', 'yinput': 4.681288834999...         success
# 147                               {'estado': 'failed'}          failed
# 148                       {'estado': 'outside_bogota'}  outside_bogota
# 149  {'estado': 'success', 'yinput': 4.673586240000...         success
#
#                  tipo_direccion       lat        lng
# 0                          None       NaN        NaN
# 1         Asignada por Catastro  4.687554 -74.127484
# 2    Dirección por aproximación  4.698799 -74.049744
# 3         Asignada por Catastro  4.718609 -74.034503
# 4         Asignada por Catastro  4.674846 -74.054029
# 5         Asignada por Catastro  4.687554 -74.127484
# 6         Asignada por Catastro  4.654305 -74.130101
# 7                          None       NaN        NaN
# 8                          None       NaN        NaN
# 9    Dirección por aproximación  4.680582 -74.125189
# 10                         None       NaN        NaN
# 11        Asignada por Catastro  4.616364 -74.071057
# 12   Dirección por aproximación  4.623597 -74.067932
# 13        Asignada por Catastro  4.676584 -74.056707
# 14        Asignada por Catastro  4.662634 -74.058450
# 15   Dirección por aproximación  4.693009 -74.034769
# 16                         None       NaN        NaN
# 17   Dirección por aproximación  4.671357 -74.065021
# 18   Dirección por aproximación  4.692806 -74.077406
# 19        Asignada por Catastro  4.653368 -74.062246
# 20   Dirección por aproximación  4.702398 -74.028459
# 21                         None       NaN        NaN
# 22        Asignada por Catastro  4.718609 -74.034503
# 23                         None       NaN        NaN
# 24                         None       NaN        NaN
# 25   Dirección por aproximación  4.673791 -74.051709
# 26                         None       NaN        NaN
# 27                         None       NaN        NaN
# 28        Asignada por Catastro  4.722853 -74.132891
# 29   Dirección por aproximación  4.673791 -74.051709
# 30   Dirección por aproximación  4.664512 -74.128782
# 31                         None       NaN        NaN
# 32                         None       NaN        NaN
# 33        Asignada por Catastro  4.681091 -74.047364
# 34                         None       NaN        NaN
# 35        Asignada por Catastro  4.678171 -74.046853
# 36                         None       NaN        NaN
# 37        Asignada por Catastro  4.639505 -74.115600
# 38   Dirección por aproximación  4.676269 -74.057759
# 39                         None       NaN        NaN
# 40                         None       NaN        NaN
# 41                         None       NaN        NaN
# 42   Dirección por aproximación  4.705101 -74.040954
# 43        Asignada por Catastro  4.681091 -74.047364
# 44                         None       NaN        NaN
# 45        Asignada por Catastro  4.680702 -74.042948
# 46                         None       NaN        NaN
# 47   Dirección por aproximación  4.684117 -74.060296
# 48                         None       NaN        NaN
# 49                         None       NaN        NaN
# 50                         None       NaN        NaN
# 51   Dirección por aproximación  4.609982 -74.070332
# 52                         None       NaN        NaN
# 53                         None       NaN        NaN
# 54        Asignada por Catastro  4.678168 -74.054089
# 55            Dirección antigua  4.634684 -74.115410
# 56   Dirección por aproximación  4.705101 -74.040954
# 57   Dirección por aproximación  4.592279 -74.108422
# 58                         None       NaN        NaN
# 59                         None       NaN        NaN
# 60   Dirección por aproximación  4.705101 -74.040954
# 61   Dirección por aproximación  4.738779 -74.057490
# 62                         None       NaN        NaN
# 63                         None       NaN        NaN
# 64        Asignada por Catastro  4.680376 -74.046094
# 65                         None       NaN        NaN
# 66   Dirección por aproximación  4.675184 -74.049096
# 67                         None       NaN        NaN
# 68        Asignada por Catastro  4.680038 -74.053115
# 69                         None       NaN        NaN
# 70                         None       NaN        NaN
# 71   Dirección por aproximación  4.705101 -74.040954
# 72   Dirección por aproximación  4.623597 -74.067932
# 73                         None       NaN        NaN
# 74   Dirección por aproximación  4.681289 -74.043909
# 75                         None       NaN        NaN
# 76        Asignada por Catastro  4.680702 -74.042948
# 77                         None       NaN        NaN
# 78                         None       NaN        NaN
# 79        Asignada por Catastro  4.677319 -74.052546
# 80        Asignada por Catastro  4.681091 -74.047364
# 81                         None       NaN        NaN
# 82                         None       NaN        NaN
# 83        Asignada por Catastro  4.661847 -74.109531
# 84        Asignada por Catastro  4.607483 -74.082535
# 85   Dirección por aproximación  4.623597 -74.067932
# 86        Asignada por Catastro  4.718609 -74.034503
# 87                         None       NaN        NaN
# 88   Dirección por aproximación  4.623597 -74.067932
# 89        Asignada por Catastro  4.662634 -74.058450
# 90        Asignada por Catastro  4.658241 -74.107223
# 91        Asignada por Catastro  4.694441 -74.050808
# 92        Asignada por Catastro  4.677485 -74.051437
# 93                         None       NaN        NaN
# 94        Asignada por Catastro  4.648157 -74.059511
# 95   Dirección por aproximación  4.609982 -74.070332
# 96   Dirección por aproximación  4.686965 -74.075729
# 97   Dirección por aproximación  4.681289 -74.043909
# 98                         None       NaN        NaN
# 99        Asignada por Catastro  4.687266 -74.043705
# 100  Dirección por aproximación  4.644602 -74.061330
# 101  Dirección por aproximación  4.623597 -74.067932
# 102  Dirección por aproximación  4.606277 -74.089274
# 103       Asignada por Catastro  4.738872 -74.090540
# 104  Dirección por aproximación  4.692806 -74.077406
# 105                        None       NaN        NaN
# 106       Asignada por Catastro  4.700862 -74.049723
# 107  Dirección por aproximación  4.714904 -74.055399
# 108                        None       NaN        NaN
# 109       Asignada por Catastro  4.683048 -74.124799
# 110       Asignada por Catastro  4.719039 -74.035913
# 111  Dirección por aproximación  4.644602 -74.061330
# 112                        None       NaN        NaN
# 113  Dirección por aproximación  4.697486 -74.046910
# 114       Asignada por Catastro  4.616364 -74.071057
# 115                        None       NaN        NaN
# 116                        None       NaN        NaN
# 117  Dirección por aproximación  4.670190 -74.057196
# 118       Asignada por Catastro  4.693783 -74.062809
# 119  Dirección por aproximación  4.644301 -74.061480
# 120                        None       NaN        NaN
# 121                        None       NaN        NaN
# 122  Dirección por aproximación  4.693009 -74.034769
# 123       Asignada por Catastro  4.658392 -74.053393
# 124                        None       NaN        NaN
# 125       Asignada por Catastro  4.676584 -74.056707
# 126  Dirección por aproximación  4.644602 -74.061330
# 127                        None       NaN        NaN
# 128       Asignada por Catastro  4.681333 -74.045066
# 129  Dirección por aproximación  4.664512 -74.128782
# 130       Asignada por Catastro  4.677993 -74.052197
# 131                        None       NaN        NaN
# 132       Asignada por Catastro  4.677442 -74.053109
# 133       Asignada por Catastro  4.694812 -74.063641
# 134                        None       NaN        NaN
# 135                        None       NaN        NaN
# 136  Dirección por aproximación  4.583363 -74.106228
# 137                        None       NaN        NaN
# 138                        None       NaN        NaN
# 139       Asignada por Catastro  4.601121 -74.070042
# 140                        None       NaN        NaN
# 141  Dirección por aproximación  4.694147 -74.065625
# 142                        None       NaN        NaN
# 143  Dirección por aproximación  4.695932 -74.031895
# 144                        None       NaN        NaN
# 145       Asignada por Catastro  4.666690 -74.057076
# 146  Dirección por aproximación  4.681289 -74.043909
# 147                        None       NaN        NaN
# 148                        None       NaN        NaN
# 149       Asignada por Catastro  4.673586 -74.053684

# %%
pd.set_option('display.max_rows', 10)

# %%
sample_4['estado'].value_counts(normalize=True)
# Out:
# estado
# success           0.600000
# failed            0.226667
# outside_bogota    0.173333
# Name: proportion, dtype: float64

# %% [markdown]
# El 22% de la muestra aleatoria del cuarto dataframe (df_comercio_base_inmuebles) no pudo ser georeferenciada por las siguientes razones:
#
# * Nombres de vías que no son aceptados por el API
# * Detalles de texto en la dirección
# * Referencia a lugares especificos (no direcciones)
#
# Hay un 17% adicional que hace referencia a direcciones fuera de Bogotá (en otras ciudades o en vías nacionales)

# %%
sample_5 = df_comercio_base_historia[df_comercio_base_historia['Ciudad']=='Bogota'].sample(n=150, random_state=1)[comercio_dir].reset_index()
sample_5['addr'] = sample_5[comercio_dir]
sample_5['source']='df_comercio_base_inmuebles'
del sample_5[comercio_dir]
del sample_5['index']
sample_5['geocode_result'] = sample_5['addr'].swifter.apply(georeferenciar)
# Out:
# Pandas Apply:   0%|          | 0/150 [00:00<?, ?it/s]

# %%
sample_5['estado'] = sample_5.apply(lambda x: x['geocode_result']['estado'], axis=1)
sample_5['tipo_direccion'] = sample_5.apply(lambda x: None if x['geocode_result']['estado']!='success' else x['geocode_result']['tipo_direccion'], axis=1)
sample_5['lat'] = sample_5.apply(lambda x: None if x['geocode_result']['estado']!='success' else x['geocode_result']['yinput'], axis=1)
sample_5['lng'] = sample_5.apply(lambda x: None if x['geocode_result']['estado']!='success' else x['geocode_result']['xinput'], axis=1)

# %%
pd.set_option('display.max_rows', None)

# %%
sample_5
# Out:
#                                                   addr  \
# 0                                       Cr. 7 # 127-48
# 1                                        Cr 5 # 20- 39
# 2                                       Cl. 114 # 9-02
# 3                                  Cl. 127 # 19A-14/20
# 4                                 Km 1.4 Vía Chía Cota
# 5                                      Cr 15 # 77 -50
# 6                                       Av. 19 # 97-51
# 7                                      Cr. 13A # 30-21
# 8                                      Cr. 91 # 135-56
# 9                                     Cl. 15B # 116-21
# 10                                 Av. NQS con Cl. 102
# 11                                   Vía Funza Siberia
# 12                                      Cl. 122 # 9-35
# 13                                         Vía Siberia
# 14                                  Vía Siberia Bogotá
# 15                                    Cr 21 # 13a - 04
# 16                                    Cr 7 # 127b - 15
# 17                                   Cl. 106 # 23 - 61
# 18                                     Cl. 93B # 19-21
# 19                                     Cr. 15 # 102-44
# 20                                       Cl 188 # 7-60
# 21                                     Cr 11 # 98 - 45
# 22                                 Vía Siberia Km. 9,5
# 23                              Via Siberia Funza Km 1
# 24   Vía Guaymaral 200 mts antes de la Variante Chi...
# 25                              Km 2 Vía Funza Siberia
# 26                          Vía Siberia- Entrada Festo
# 27                                   Aut. Norte Cl. 97
# 28             Cl. 26 Occidente 68 (lote Actual Xerox)
# 29                                     Cr. 7 # 127-48
# 30                             Av. C. Cali Cl. 42A Sur
# 31                                     Tr.23 #100 - 17
# 32                                      Cl. 98 # 9A-46
# 33                       Cra. 68B con Av. La Esperanza
# 34                 Autop. Medellín Costado vía Siberia
# 35                                     Cr 11 # 98 - 45
# 36                                     Cl 125 # 19 -67
# 37                                 Cr. 15 # 19-60 Chía
# 38                                     Cl. 93 # 11A-11
# 39                                      Cr 13 # 9 - 48
# 40                                      Cr. 15 # 80-05
# 41                                         Vía Sibería
# 42                                     Cr. 11A # 98-50
# 43                                    Cl. 12C # 79A-26
# 44                           Av. El Dorado con Cra. 92
# 45                                      Cl. 114 # 9-02
# 46                                    Av Boyaca Cl. 13
# 47      Autop. Medellín Km. 2.5 -vía parcelas 1800 mts
# 48                                    Cr. 53 # 104B-35
# 49                                     Cra. 12 # 97-32
# 50                         Km. 2.5 Fontibón - Mosquera
# 51                     Km 22 vía Tunja Vereda Canavíta
# 52       Km 28 Vía Cajicá 50 mts antes de San Jeronimo
# 53                          Km. 17 Vía Bogotá-Mosquera
# 54                                   Km 1.5 vía Bogotá
# 55                               Cr. 13 # 17A-11 Funza
# 56                                     Tr. 19A # 98-12
# 57                    Cr 93 # 54- 28 Sur Bosa Porvenir
# 58                                      Cl 6 # 38 - 74
# 59                                    Cl. 102 # 14A-70
# 60                                    Av. 68 # 75a -50
# 61                                      Cl. 20 # 82-52
# 62                                      Cr. 12 # 93-08
# 63                                       Cl 93 # 15-73
# 64                        Cl. 90 Cra. 19 Costado Norte
# 65                                      Cl 79 # 76 -31
# 66                                    Cr 8c # 188 - 95
# 67                   Vía Troncal de Occidente Calle 13
# 68            K.m 1.5 vía Chia-Cajicá Costado Oriental
# 69                                 Cr. 10 # 1A-50 Chía
# 70                                      Av. 9 # 123-36
# 71                                   Aut. Norte Cl. 97
# 72                       Autp. Medellín Km 20 El Rosal
# 73                                Av. Américas # 62-84
# 74                                     Tr. 30 # 124-91
# 75                                   Cr 100 con Cll 26
# 76                                      Cr. 15 # 98-42
# 77   Variante Cota Chía 100 mts al norte de la glor...
# 78                          Autopista Norte Con Cl 201
# 79                                     Av. 19 # 104-05
# 80                                      Cra 15 # 93-84
# 81                                     Cl. 79a # 18-57
# 82                           Km 7.5 Autopista Medellin
# 83                                     Cl. 26 # 69D-91
# 84                                   Cl. 98 con Cr. 12
# 85                                      Cr. 13 # 96-67
# 86                                         Vía Siberia
# 87                     Bogotá Siberia Km 2 costado sur
# 88                                    Cra. 13A # 98-75
# 89                                      Cr 3 con Cl 20
# 90                                      Cr. 11 # 98-35
# 91                                 Av. Cl. 24 # 95A-80
# 92                                     Cl. 63 # 83 -34
# 93   Vía Cota-Siberia, 1,5 kms antes del round poin...
# 94                                   Cr. 14 # 94-34/44
# 95                                      Cl. 110 # 9-25
# 96                    Autop.Norte con 164 Costado Occ.
# 97                                  Cr. 13A # 98-45/63
# 98                                             Mazurén
# 99                                Autonorte # 106 - 71
# 100                                  Cra. 47 A # 95-54
# 101                             Aut. Norte Av. Central
# 102                                   Av. Suba Cl. 100
# 103                             Vía Parque Jaime Duque
# 104             Cl.13 con Av Boyacá Costado Occidental
# 105                                 Calle 116 # 18- 96
# 106                  Vía Troncal de Occidente Calle 13
# 107                            Km. 3 Vía Funza Sibería
# 108                                    Cl. 101 # 66-11
# 109                                   Cr. 21 # 128D-10
# 110                               Vía Zipaquirá Cajicá
# 111                                     Cr. 18 # 84-03
# 112                     Anillo Víal Canavíta Tocancípa
# 113                                     Cra 13 # 35-37
# 114                                     Av. 7 # 166-04
# 115                                   Calle 93 # 19-66
# 116                            Km. 3 Vía Chia - Cajicá
# 117                                Km. 14 Vía Mosquera
# 118                                      Cl. 67 # 7-85
# 119                                    Cl 92 # 15 - 78
# 120                             Via Siberia Funza Km 1
# 121                          Km 19 Vía Bogotá Mosquera
# 122                                      Cr. 7 # 59-14
# 123                           Cra 36 # 8-442 Zipaquirá
# 124                                     Cr. 78 # 17-55
# 125                                      Cl. 67 # 7-85
# 126                                      Cl. 71 # 6-11
# 127                                   Cl. 22C # 132-27
# 128                             Km. 29 Vía Chia-Cajicá
# 129                              Av. Boyacá con Cl. 80
# 130                                      Cl. 98 # 8-28
# 131                  K.m. 2 Vía Chia-Cajicá -Farmatodo
# 132                          Vía Siberia Bogotá 1,5 Km
# 133                                      Cl 126 # 7-52
# 134                                Av. Cr. 45 # 114-68
# 135                Km 1 Siberia Funza Costado Oriental
# 136                                       Cl 56 # 6-23
# 137                                    Calle 93 con 12
# 138                                    Cl. 26A # 13-97
# 139                                      Cl. 71 # 5-97
# 140                            Av. C. Cali Cl. 42A Sur
# 141                        Av. Suba con Ciudad de Cali
# 142                              Autop. Norte # 118-86
# 143                               Av. Esperanza Cr. 50
# 144                                Cl 22 Sur # 24b -60
# 145                                  Diag. 24C # 96-25
# 146                                    Cl. 63 # 83 -34
# 147                     150 mts adelante peaje Siberia
# 148                             Km. 15 Vía Chia-Cajicá
# 149                                       Cl 96 11B-13
#
#                          source  \
# 0    df_comercio_base_inmuebles
# 1    df_comercio_base_inmuebles
# 2    df_comercio_base_inmuebles
# 3    df_comercio_base_inmuebles
# 4    df_comercio_base_inmuebles
# 5    df_comercio_base_inmuebles
# 6    df_comercio_base_inmuebles
# 7    df_comercio_base_inmuebles
# 8    df_comercio_base_inmuebles
# 9    df_comercio_base_inmuebles
# 10   df_comercio_base_inmuebles
# 11   df_comercio_base_inmuebles
# 12   df_comercio_base_inmuebles
# 13   df_comercio_base_inmuebles
# 14   df_comercio_base_inmuebles
# 15   df_comercio_base_inmuebles
# 16   df_comercio_base_inmuebles
# 17   df_comercio_base_inmuebles
# 18   df_comercio_base_inmuebles
# 19   df_comercio_base_inmuebles
# 20   df_comercio_base_inmuebles
# 21   df_comercio_base_inmuebles
# 22   df_comercio_base_inmuebles
# 23   df_comercio_base_inmuebles
# 24   df_comercio_base_inmuebles
# 25   df_comercio_base_inmuebles
# 26   df_comercio_base_inmuebles
# 27   df_comercio_base_inmuebles
# 28   df_comercio_base_inmuebles
# 29   df_comercio_base_inmuebles
# 30   df_comercio_base_inmuebles
# 31   df_comercio_base_inmuebles
# 32   df_comercio_base_inmuebles
# 33   df_comercio_base_inmuebles
# 34   df_comercio_base_inmuebles
# 35   df_comercio_base_inmuebles
# 36   df_comercio_base_inmuebles
# 37   df_comercio_base_inmuebles
# 38   df_comercio_base_inmuebles
# 39   df_comercio_base_inmuebles
# 40   df_comercio_base_inmuebles
# 41   df_comercio_base_inmuebles
# 42   df_comercio_base_inmuebles
# 43   df_comercio_base_inmuebles
# 44   df_comercio_base_inmuebles
# 45   df_comercio_base_inmuebles
# 46   df_comercio_base_inmuebles
# 47   df_comercio_base_inmuebles
# 48   df_comercio_base_inmuebles
# 49   df_comercio_base_inmuebles
# 50   df_comercio_base_inmuebles
# 51   df_comercio_base_inmuebles
# 52   df_comercio_base_inmuebles
# 53   df_comercio_base_inmuebles
# 54   df_comercio_base_inmuebles
# 55   df_comercio_base_inmuebles
# 56   df_comercio_base_inmuebles
# 57   df_comercio_base_inmuebles
# 58   df_comercio_base_inmuebles
# 59   df_comercio_base_inmuebles
# 60   df_comercio_base_inmuebles
# 61   df_comercio_base_inmuebles
# 62   df_comercio_base_inmuebles
# 63   df_comercio_base_inmuebles
# 64   df_comercio_base_inmuebles
# 65   df_comercio_base_inmuebles
# 66   df_comercio_base_inmuebles
# 67   df_comercio_base_inmuebles
# 68   df_comercio_base_inmuebles
# 69   df_comercio_base_inmuebles
# 70   df_comercio_base_inmuebles
# 71   df_comercio_base_inmuebles
# 72   df_comercio_base_inmuebles
# 73   df_comercio_base_inmuebles
# 74   df_comercio_base_inmuebles
# 75   df_comercio_base_inmuebles
# 76   df_comercio_base_inmuebles
# 77   df_comercio_base_inmuebles
# 78   df_comercio_base_inmuebles
# 79   df_comercio_base_inmuebles
# 80   df_comercio_base_inmuebles
# 81   df_comercio_base_inmuebles
# 82   df_comercio_base_inmuebles
# 83   df_comercio_base_inmuebles
# 84   df_comercio_base_inmuebles
# 85   df_comercio_base_inmuebles
# 86   df_comercio_base_inmuebles
# 87   df_comercio_base_inmuebles
# 88   df_comercio_base_inmuebles
# 89   df_comercio_base_inmuebles
# 90   df_comercio_base_inmuebles
# 91   df_comercio_base_inmuebles
# 92   df_comercio_base_inmuebles
# 93   df_comercio_base_inmuebles
# 94   df_comercio_base_inmuebles
# 95   df_comercio_base_inmuebles
# 96   df_comercio_base_inmuebles
# 97   df_comercio_base_inmuebles
# 98   df_comercio_base_inmuebles
# 99   df_comercio_base_inmuebles
# 100  df_comercio_base_inmuebles
# 101  df_comercio_base_inmuebles
# 102  df_comercio_base_inmuebles
# 103  df_comercio_base_inmuebles
# 104  df_comercio_base_inmuebles
# 105  df_comercio_base_inmuebles
# 106  df_comercio_base_inmuebles
# 107  df_comercio_base_inmuebles
# 108  df_comercio_base_inmuebles
# 109  df_comercio_base_inmuebles
# 110  df_comercio_base_inmuebles
# 111  df_comercio_base_inmuebles
# 112  df_comercio_base_inmuebles
# 113  df_comercio_base_inmuebles
# 114  df_comercio_base_inmuebles
# 115  df_comercio_base_inmuebles
# 116  df_comercio_base_inmuebles
# 117  df_comercio_base_inmuebles
# 118  df_comercio_base_inmuebles
# 119  df_comercio_base_inmuebles
# 120  df_comercio_base_inmuebles
# 121  df_comercio_base_inmuebles
# 122  df_comercio_base_inmuebles
# 123  df_comercio_base_inmuebles
# 124  df_comercio_base_inmuebles
# 125  df_comercio_base_inmuebles
# 126  df_comercio_base_inmuebles
# 127  df_comercio_base_inmuebles
# 128  df_comercio_base_inmuebles
# 129  df_comercio_base_inmuebles
# 130  df_comercio_base_inmuebles
# 131  df_comercio_base_inmuebles
# 132  df_comercio_base_inmuebles
# 133  df_comercio_base_inmuebles
# 134  df_comercio_base_inmuebles
# 135  df_comercio_base_inmuebles
# 136  df_comercio_base_inmuebles
# 137  df_comercio_base_inmuebles
# 138  df_comercio_base_inmuebles
# 139  df_comercio_base_inmuebles
# 140  df_comercio_base_inmuebles
# 141  df_comercio_base_inmuebles
# 142  df_comercio_base_inmuebles
# 143  df_comercio_base_inmuebles
# 144  df_comercio_base_inmuebles
# 145  df_comercio_base_inmuebles
# 146  df_comercio_base_inmuebles
# 147  df_comercio_base_inmuebles
# 148  df_comercio_base_inmuebles
# 149  df_comercio_base_inmuebles
#
#                                         geocode_result          estado  \
# 0    {'estado': 'success', 'yinput': 4.703301173, '...         success
# 1    {'estado': 'success', 'yinput': 4.605686901000...         success
# 2    {'estado': 'success', 'yinput': 4.692716659999...         success
# 3    {'estado': 'success', 'yinput': 4.705969243000...         success
# 4                         {'estado': 'outside_bogota'}  outside_bogota
# 5    {'estado': 'success', 'yinput': 4.664189764000...         success
# 6    {'estado': 'success', 'yinput': 4.684095921999...         success
# 7    {'estado': 'success', 'yinput': 4.619211441999...         success
# 8    {'estado': 'success', 'yinput': 4.733999166999...         success
# 9    {'estado': 'success', 'yinput': 4.683228964000...         success
# 10                                {'estado': 'failed'}          failed
# 11                                {'estado': 'failed'}          failed
# 12   {'estado': 'success', 'yinput': 4.694331589, '...         success
# 13                                {'estado': 'failed'}          failed
# 14                                {'estado': 'failed'}          failed
# 15   {'estado': 'success', 'yinput': 4.609631990000...         success
# 16   {'estado': 'success', 'yinput': 4.705244245000...         success
# 17   {'estado': 'success', 'yinput': 4.693486463, '...         success
# 18   {'estado': 'success', 'yinput': 4.680250843000...         success
# 19   {'estado': 'success', 'yinput': 4.687263540999...         success
# 20   {'estado': 'success', 'yinput': 4.764702890000...         success
# 21   {'estado': 'success', 'yinput': 4.681288834999...         success
# 22                        {'estado': 'outside_bogota'}  outside_bogota
# 23                        {'estado': 'outside_bogota'}  outside_bogota
# 24                                {'estado': 'failed'}          failed
# 25                        {'estado': 'outside_bogota'}  outside_bogota
# 26                                {'estado': 'failed'}          failed
# 27                                {'estado': 'failed'}          failed
# 28   {'estado': 'success', 'yinput': 4.653540287999...         success
# 29   {'estado': 'success', 'yinput': 4.703301173, '...         success
# 30                                {'estado': 'failed'}          failed
# 31   {'estado': 'success', 'yinput': 4.687423883000...         success
# 32   {'estado': 'success', 'yinput': 4.68070229, 'l...         success
# 33                                {'estado': 'failed'}          failed
# 34                                {'estado': 'failed'}          failed
# 35   {'estado': 'success', 'yinput': 4.681288834999...         success
# 36   {'estado': 'success', 'yinput': 4.704573779999...         success
# 37                        {'estado': 'outside_bogota'}  outside_bogota
# 38   {'estado': 'success', 'yinput': 4.674698036, '...         success
# 39   {'estado': 'success', 'yinput': 4.600382173000...         success
# 40   {'estado': 'success', 'yinput': 4.666567407, '...         success
# 41                                {'estado': 'failed'}          failed
# 42   {'estado': 'success', 'yinput': 4.681751634000...         success
# 43   {'estado': 'success', 'yinput': 4.650911453999...         success
# 44                                {'estado': 'failed'}          failed
# 45   {'estado': 'success', 'yinput': 4.692716659999...         success
# 46                                {'estado': 'failed'}          failed
# 47                        {'estado': 'outside_bogota'}  outside_bogota
# 48   {'estado': 'success', 'yinput': 4.693783155000...         success
# 49   {'estado': 'success', 'yinput': 4.681297414000...         success
# 50                        {'estado': 'outside_bogota'}  outside_bogota
# 51                        {'estado': 'outside_bogota'}  outside_bogota
# 52                        {'estado': 'outside_bogota'}  outside_bogota
# 53                        {'estado': 'outside_bogota'}  outside_bogota
# 54                        {'estado': 'outside_bogota'}  outside_bogota
# 55   {'estado': 'success', 'yinput': 4.608078257999...         success
# 56   {'estado': 'success', 'yinput': 4.685118954000...         success
# 57                                {'estado': 'failed'}          failed
# 58   {'estado': 'success', 'yinput': 4.615377573999...         success
# 59   {'estado': 'success', 'yinput': 4.687119399999...         success
# 60                                {'estado': 'failed'}          failed
# 61   {'estado': 'success', 'yinput': 4.664512483000...         success
# 62   {'estado': 'success', 'yinput': 4.675243700000...         success
# 63   {'estado': 'success', 'yinput': 4.677121543999...         success
# 64   {'estado': 'success', 'yinput': 4.676135402999...         success
# 65   {'estado': 'success', 'yinput': 4.697302562, '...         success
# 66   {'estado': 'success', 'yinput': 4.765638844000...         success
# 67                                {'estado': 'failed'}          failed
# 68                        {'estado': 'outside_bogota'}  outside_bogota
# 69                        {'estado': 'outside_bogota'}  outside_bogota
# 70   {'estado': 'success', 'yinput': 4.699871218, '...         success
# 71                                {'estado': 'failed'}          failed
# 72                        {'estado': 'outside_bogota'}  outside_bogota
# 73                                {'estado': 'failed'}          failed
# 74                                {'estado': 'failed'}          failed
# 75   {'estado': 'success', 'yinput': 4.688386843999...         success
# 76   {'estado': 'success', 'yinput': 4.683378592, '...         success
# 77                        {'estado': 'outside_bogota'}  outside_bogota
# 78                                {'estado': 'failed'}          failed
# 79   {'estado': 'success', 'yinput': 4.69052976, 'l...         success
# 80   {'estado': 'success', 'yinput': 4.677485134999...         success
# 81   {'estado': 'success', 'yinput': 4.667069891999...         success
# 82                        {'estado': 'outside_bogota'}  outside_bogota
# 83   {'estado': 'success', 'yinput': 4.661847078999...         success
# 84                                {'estado': 'failed'}          failed
# 85   {'estado': 'success', 'yinput': 4.681090598000...         success
# 86                                {'estado': 'failed'}          failed
# 87                        {'estado': 'outside_bogota'}  outside_bogota
# 88   {'estado': 'success', 'yinput': 4.683208302000...         success
# 89   {'estado': 'success', 'yinput': 4.604275341, '...         success
# 90   {'estado': 'success', 'yinput': 4.681288834999...         success
# 91   {'estado': 'success', 'yinput': 4.680582147999...         success
# 92   {'estado': 'success', 'yinput': 4.687284502000...         success
# 93                                {'estado': 'failed'}          failed
# 94   {'estado': 'success', 'yinput': 4.679331225, '...         success
# 95   {'estado': 'success', 'yinput': 4.691014573000...         success
# 96                                {'estado': 'failed'}          failed
# 97   {'estado': 'success', 'yinput': 4.682894874999...         success
# 98   {'estado': 'success', 'yinput': 4.73664396462,...         success
# 99                                {'estado': 'failed'}          failed
# 100  {'estado': 'success', 'yinput': 4.684523463999...         success
# 101                               {'estado': 'failed'}          failed
# 102                               {'estado': 'failed'}          failed
# 103                               {'estado': 'failed'}          failed
# 104                               {'estado': 'failed'}          failed
# 105  {'estado': 'success', 'yinput': 4.698488297999...         success
# 106                               {'estado': 'failed'}          failed
# 107                       {'estado': 'outside_bogota'}  outside_bogota
# 108  {'estado': 'success', 'yinput': 4.690076056000...         success
# 109  {'estado': 'success', 'yinput': 4.714781994000...         success
# 110                       {'estado': 'outside_bogota'}  outside_bogota
# 111  {'estado': 'success', 'yinput': 4.669710823, '...         success
# 112                       {'estado': 'outside_bogota'}  outside_bogota
# 113  {'estado': 'success', 'yinput': 4.623597277999...         success
# 114  {'estado': 'success', 'yinput': 4.74305038, 'l...         success
# 115  {'estado': 'success', 'yinput': 4.678740797999...         success
# 116                       {'estado': 'outside_bogota'}  outside_bogota
# 117                       {'estado': 'outside_bogota'}  outside_bogota
# 118  {'estado': 'success', 'yinput': 4.651077953000...         success
# 119  {'estado': 'success', 'yinput': 4.676433781000...         success
# 120                       {'estado': 'outside_bogota'}  outside_bogota
# 121                       {'estado': 'outside_bogota'}  outside_bogota
# 122  {'estado': 'success', 'yinput': 4.644370229999...         success
# 123                       {'estado': 'outside_bogota'}  outside_bogota
# 124  {'estado': 'success', 'yinput': 4.654623055, '...         success
# 125  {'estado': 'success', 'yinput': 4.651077953000...         success
# 126  {'estado': 'success', 'yinput': 4.653741379, '...         success
# 127  {'estado': 'success', 'yinput': 4.699519173999...         success
# 128                       {'estado': 'outside_bogota'}  outside_bogota
# 129                               {'estado': 'failed'}          failed
# 130  {'estado': 'success', 'yinput': 4.679408202999...         success
# 131                       {'estado': 'outside_bogota'}  outside_bogota
# 132                       {'estado': 'outside_bogota'}  outside_bogota
# 133  {'estado': 'success', 'yinput': 4.701043498999...         success
# 134  {'estado': 'success', 'yinput': 4.698534489999...         success
# 135                       {'estado': 'outside_bogota'}  outside_bogota
# 136  {'estado': 'success', 'yinput': 4.641840086, '...         success
# 137  {'estado': 'success', 'yinput': 4.675184461000...         success
# 138  {'estado': 'success', 'yinput': 4.614876158000...         success
# 139  {'estado': 'success', 'yinput': 4.653695219999...         success
# 140                               {'estado': 'failed'}          failed
# 141                               {'estado': 'failed'}          failed
# 142                               {'estado': 'failed'}          failed
# 143                               {'estado': 'failed'}          failed
# 144  {'estado': 'success', 'yinput': 4.585349355000...         success
# 145  {'estado': 'success', 'yinput': 4.680951282000...         success
# 146  {'estado': 'success', 'yinput': 4.687284502000...         success
# 147                               {'estado': 'failed'}          failed
# 148                       {'estado': 'outside_bogota'}  outside_bogota
# 149  {'estado': 'success', 'yinput': 4.679942348999...         success
#
#                  tipo_direccion       lat        lng
# 0         Asignada por Catastro  4.703301 -74.028527
# 1         Asignada por Catastro  4.605687 -74.069746
# 2             Dirección antigua  4.692717 -74.034414
# 3         Asignada por Catastro  4.705969 -74.049680
# 4                          None       NaN        NaN
# 5         Asignada por Catastro  4.664190 -74.058243
# 6    Dirección por aproximación  4.684096 -74.052213
# 7    Dirección por aproximación  4.619211 -74.072849
# 8         Asignada por Catastro  4.733999 -74.085664
# 9    Dirección por aproximación  4.683229 -74.155932
# 10                         None       NaN        NaN
# 11                         None       NaN        NaN
# 12   Dirección por aproximación  4.694332 -74.035755
# 13                         None       NaN        NaN
# 14                         None       NaN        NaN
# 15        Asignada por Catastro  4.609632 -74.085867
# 16   Dirección por aproximación  4.705244 -74.028759
# 17        Asignada por Catastro  4.693486 -74.055557
# 18        Asignada por Catastro  4.680251 -74.054272
# 19   Dirección por aproximación  4.687264 -74.047445
# 20        Asignada por Catastro  4.764703 -74.028128
# 21   Dirección por aproximación  4.681289 -74.043909
# 22                         None       NaN        NaN
# 23                         None       NaN        NaN
# 24                         None       NaN        NaN
# 25                         None       NaN        NaN
# 26                         None       NaN        NaN
# 27                         None       NaN        NaN
# 28   Dirección por aproximación  4.653540 -74.103871
# 29        Asignada por Catastro  4.703301 -74.028527
# 30                         None       NaN        NaN
# 31        Asignada por Catastro  4.687424 -74.055979
# 32        Asignada por Catastro  4.680702 -74.042948
# 33                         None       NaN        NaN
# 34                         None       NaN        NaN
# 35   Dirección por aproximación  4.681289 -74.043909
# 36        Asignada por Catastro  4.704574 -74.049711
# 37                         None       NaN        NaN
# 38        Asignada por Catastro  4.674698 -74.048569
# 39   Dirección por aproximación  4.600382 -74.081338
# 40        Asignada por Catastro  4.666567 -74.057146
# 41                         None       NaN        NaN
# 42        Asignada por Catastro  4.681752 -74.044715
# 43   Dirección por aproximación  4.650911 -74.134783
# 44                         None       NaN        NaN
# 45            Dirección antigua  4.692717 -74.034414
# 46                         None       NaN        NaN
# 47                         None       NaN        NaN
# 48        Asignada por Catastro  4.693783 -74.062809
# 49        Asignada por Catastro  4.681297 -74.046395
# 50                         None       NaN        NaN
# 51                         None       NaN        NaN
# 52                         None       NaN        NaN
# 53                         None       NaN        NaN
# 54                         None       NaN        NaN
# 55   Dirección por aproximación  4.608078 -74.077737
# 56        Asignada por Catastro  4.685119 -74.053041
# 57                         None       NaN        NaN
# 58        Asignada por Catastro  4.615378 -74.104910
# 59        Asignada por Catastro  4.687119 -74.047350
# 60                         None       NaN        NaN
# 61   Dirección por aproximación  4.664512 -74.128782
# 62        Asignada por Catastro  4.675244 -74.048995
# 63        Asignada por Catastro  4.677122 -74.052724
# 64   Dirección por aproximación  4.676135 -74.056208
# 65        Asignada por Catastro  4.697303 -74.094092
# 66        Asignada por Catastro  4.765639 -74.029984
# 67                         None       NaN        NaN
# 68                         None       NaN        NaN
# 69                         None       NaN        NaN
# 70        Asignada por Catastro  4.699871 -74.032782
# 71                         None       NaN        NaN
# 72                         None       NaN        NaN
# 73                         None       NaN        NaN
# 74                         None       NaN        NaN
# 75   Dirección por aproximación  4.688387 -74.128618
# 76        Asignada por Catastro  4.683379 -74.048420
# 77                         None       NaN        NaN
# 78                         None       NaN        NaN
# 79   Dirección por aproximación  4.690530 -74.051136
# 80        Asignada por Catastro  4.677485 -74.051437
# 81        Asignada por Catastro  4.667070 -74.059479
# 82                         None       NaN        NaN
# 83        Asignada por Catastro  4.661847 -74.109531
# 84                         None       NaN        NaN
# 85        Asignada por Catastro  4.681091 -74.047364
# 86                         None       NaN        NaN
# 87                         None       NaN        NaN
# 88        Asignada por Catastro  4.683208 -74.046997
# 89   Dirección por aproximación  4.604275 -74.067719
# 90   Dirección por aproximación  4.681289 -74.043909
# 91   Dirección por aproximación  4.680582 -74.125189
# 92   Dirección por aproximación  4.687285 -74.109406
# 93                         None       NaN        NaN
# 94   Dirección por aproximación  4.679331 -74.049718
# 95        Asignada por Catastro  4.691015 -74.038598
# 96                         None       NaN        NaN
# 97   Dirección por aproximación  4.682895 -74.047158
# 98             Punto de interes  4.736644 -74.055646
# 99                         None       NaN        NaN
# 100       Asignada por Catastro  4.684523 -74.060228
# 101                        None       NaN        NaN
# 102                        None       NaN        NaN
# 103                        None       NaN        NaN
# 104                        None       NaN        NaN
# 105  Dirección por aproximación  4.698488 -74.048461
# 106                        None       NaN        NaN
# 107                        None       NaN        NaN
# 108       Asignada por Catastro  4.690076 -74.070718
# 109  Dirección por aproximación  4.714782 -74.050217
# 110                        None       NaN        NaN
# 111  Dirección por aproximación  4.669711 -74.057429
# 112                        None       NaN        NaN
# 113  Dirección por aproximación  4.623597 -74.067932
# 114  Dirección por aproximación  4.743050 -74.022447
# 115       Asignada por Catastro  4.678741 -74.055600
# 116                        None       NaN        NaN
# 117                        None       NaN        NaN
# 118       Asignada por Catastro  4.651078 -74.058962
# 119       Asignada por Catastro  4.676434 -74.053122
# 120                        None       NaN        NaN
# 121                        None       NaN        NaN
# 122       Asignada por Catastro  4.644370 -74.061457
# 123                        None       NaN        NaN
# 124  Dirección por aproximación  4.654623 -74.130679
# 125       Asignada por Catastro  4.651078 -74.058962
# 126       Asignada por Catastro  4.653741 -74.055165
# 127  Dirección por aproximación  4.699519 -74.160485
# 128                        None       NaN        NaN
# 129                        None       NaN        NaN
# 130  Dirección por aproximación  4.679408 -74.040425
# 131                        None       NaN        NaN
# 132                        None       NaN        NaN
# 133       Asignada por Catastro  4.701043 -74.029556
# 134       Asignada por Catastro  4.698534 -74.054796
# 135                        None       NaN        NaN
# 136       Asignada por Catastro  4.641840 -74.061960
# 137  Dirección por aproximación  4.675184 -74.049096
# 138       Asignada por Catastro  4.614876 -74.071683
# 139       Asignada por Catastro  4.653695 -74.055081
# 140                        None       NaN        NaN
# 141                        None       NaN        NaN
# 142                        None       NaN        NaN
# 143                        None       NaN        NaN
# 144       Asignada por Catastro  4.585349 -74.105661
# 145       Asignada por Catastro  4.680951 -74.128779
# 146  Dirección por aproximación  4.687285 -74.109406
# 147                        None       NaN        NaN
# 148                        None       NaN        NaN
# 149       Asignada por Catastro  4.679942 -74.046643

# %%
pd.set_option('display.max_rows', 10)

# %%
sample_5['estado'].value_counts(normalize=True)
# Out:
# estado
# success           0.56
# failed            0.24
# outside_bogota    0.20
# Name: proportion, dtype: float64

# %% [markdown]
# El 24% de la muestra aleatoria del quinto dataframe (df_comercio_base_historia) no pudo ser georeferenciada por las siguientes razones:
#
# * Nombres de vías que no son aceptados por el API
# * Detalles de texto en la dirección
# * Referencia a lugares especificos (no direcciones)
#
# Hay un 20% adicional que hace referencia a direcciones fuera de Bogotá (en otras ciudades o en vías nacionales)

# %%
sample_6 = df_def_base_proyecto.sample(n=150, random_state=1)[['Latitud (Coordenada Real)','Longitud\n(Coordenada Real)',def_dir]].reset_index()
sample_6['addr'] = sample_6[def_dir]
sample_6['source']='df_def_base_proyecto'
del sample_6[def_dir]
del sample_6['index']
sample_6['geocode_result'] = sample_6['addr'].swifter.apply(georeferenciar)
# Out:
# Pandas Apply:   0%|          | 0/150 [00:00<?, ?it/s]

# %%
sample_6['estado'] = sample_6.apply(lambda x: x['geocode_result']['estado'], axis=1)
sample_6['tipo_direccion'] = sample_6.apply(lambda x: None if x['geocode_result']['estado']!='success' else x['geocode_result']['tipo_direccion'], axis=1)
sample_6['lat'] = sample_6.apply(lambda x: None if x['geocode_result']['estado']!='success' else x['geocode_result']['yinput'], axis=1)
sample_6['lng'] = sample_6.apply(lambda x: None if x['geocode_result']['estado']!='success' else x['geocode_result']['xinput'], axis=1)
sample_6['real_geom'] = sample_6.apply(lambda x: Point(x['Longitud\n(Coordenada Real)'],x['Latitud (Coordenada Real)']), axis=1)
sample_6['geocoded_geom'] = sample_6.apply(lambda x: Point(x['lng'],x['lat']), axis=1)
sample_6['degrees_distance'] = sample_6.apply(lambda x: x.real_geom.distance(x.geocoded_geom), axis=1)
sample_6['distance'] = sample_6.apply(lambda x: distance(x.real_geom,x.geocoded_geom), axis=1)

# %%
pd.set_option('display.max_rows', None)

# %%
sample_6.sort_values(by='distance', ascending=False)
# Out:
#      Latitud (Coordenada Real)  Longitud\n(Coordenada Real)  \
# 143                   4.928275                   -74.056134
# 111                   4.921657                   -74.030511
# 137                   4.560258                   -74.231625
# 42                    4.557297                   -74.227222
# 35                    4.611606                   -74.218326
# 129                   4.599556                   -74.218876
# 84                    4.588568                   -74.204551
# 69                    4.607616                   -74.207849
# 32                    4.612116                   -74.205741
# 149                   4.744900                   -74.072400
# 51                    4.641065                   -74.152714
# 6                     4.587086                   -74.121896
# 59                    4.589412                   -74.157157
# 91                    4.699410                   -74.116513
# 134                   4.691931                   -74.046064
# 31                    4.579696                   -74.078554
# 124                   4.723551                   -74.124458
# 3                     4.620472                   -74.180046
# 81                    4.724600                   -74.078800
# 96                    4.698071                   -74.028115
# 119                   4.646213                   -74.151862
# 123                   4.757473                   -74.106153
# 99                    4.644761                   -74.144462
# 93                    4.636988                   -74.077926
# 66                    4.706400                   -74.031900
# 19                    4.687850                   -74.052836
# 26                    4.640070                   -74.153706
# 50                    4.751816                   -74.083209
# 106                   4.735948                   -74.062305
# 14                    4.676019                   -74.056047
# 142                   4.705389                   -74.135033
# 24                    4.591471                   -74.169797
# 116                   4.629626                   -74.062723
# 71                    4.611052                   -74.205537
# 56                    4.693401                   -74.057251
# 76                    4.692300                   -74.058200
# 37                    4.722335                   -74.048180
# 10                    4.595302                   -74.166777
# 138                   4.581870                   -74.084746
# 92                    4.719540                   -74.089190
# 38                    4.738700                   -74.069600
# 4                     4.697093                   -74.068383
# 46                    4.602670                   -74.068983
# 86                    4.696549                   -74.027454
# 105                   4.683818                   -74.150768
# 13                    4.704432                   -74.055221
# 79                    4.749350                   -74.037412
# 9                     4.742400                   -74.083400
# 18                    4.679141                   -74.042556
# 60                    4.604571                   -74.070185
# 62                    4.716470                   -74.042230
# 145                   4.719315                   -74.047026
# 39                    4.720337                   -74.041400
# 125                   4.750414                   -74.057622
# 72                    4.592295                   -74.105351
# 140                   4.696100                   -74.081000
# 12                    4.752080                   -74.054423
# 55                    4.677618                   -74.055396
# 117                   4.625725                   -74.085680
# 133                   4.688115                   -74.045863
# 83                    4.641526                   -74.062631
# 21                    4.745854                   -74.084518
# 120                   4.687974                   -74.060490
# 7                     4.673300                   -74.053000
# 49                    4.683143                   -74.053737
# 8                     4.694978                   -74.063490
# 40                    4.699920                   -74.051810
# 147                   4.695400                   -74.041400
# 127                   4.691800                   -74.041600
# 28                    4.646351                   -74.082986
# 112                   4.716833                   -74.065059
# 94                    4.741443                   -74.088514
# 2                     4.695022                   -74.063294
# 113                   4.637686                   -74.061220
# 44                    4.695313                   -74.044880
# 102                   4.696358                   -74.045759
# 88                    4.700542                   -74.051334
# 141                   4.662370                   -74.049086
# 30                    4.688268                   -74.049938
# 118                   4.695497                   -74.045667
# 110                   4.682070                   -74.062784
# 101                   4.699794                   -74.045795
# 68                    4.693506                   -74.062716
# 33                    4.722622                   -74.045720
# 132                   4.692667                   -74.048662
# 53                    4.639161                   -74.076542
# 80                    4.641282                   -74.067127
# 54                    4.729199                   -74.047648
# 148                   4.686787                   -74.061932
# 23                    4.700160                   -74.045735
# 5                     4.667664                   -74.044656
# 85                    4.726730                   -74.038130
# 70                    4.701781                   -74.045444
# 115                   4.646308                   -74.060903
# 131                   4.702575                   -74.043563
# 130                   4.577536                   -74.107905
# 65                    4.646169                   -74.062897
# 20                    4.720563                   -74.121874
# 78                    4.650770                   -74.079358
# 16                    4.696700                   -74.098800
# 0                     4.701124                   -74.053536
# 25                    4.652860                   -74.065266
# 103                   4.620466                   -74.196868
# 43                    4.647236                   -74.085746
# 11                    4.688211                   -74.048051
# 15                    4.628469                   -74.066959
# 90                    4.751790                   -74.053786
# 139                   4.696133                   -74.046306
# 108                   4.644715                   -74.063412
# 1                     4.606742                   -74.223172
# 17                    4.878590                   -74.049001
# 22                    4.728154                   -74.247230
# 27                    4.651675                   -74.144847
# 29                    4.849615                   -74.052843
# 34                    4.608079                   -74.217817
# 36                    4.779150                   -74.042420
# 41                    4.712169                   -74.230824
# 45                    4.750868                   -74.100027
# 47                    5.035737                   -73.986546
# 48                    4.914895                   -74.044500
# 52                    4.589740                   -74.198253
# 57                    4.596001                   -74.218997
# 58                    4.854650                   -74.051042
# 61                    4.644637                   -74.152042
# 63                    4.855490                   -74.071184
# 64                    4.917218                   -74.014422
# 67                    4.587196                   -74.201592
# 73                    4.569777                   -74.113913
# 74                    4.588109                   -74.160993
# 75                    4.856644                   -74.077809
# 77                    4.710843                   -74.028805
# 82                    4.608127                   -74.070785
# 87                    4.923045                   -74.012794
# 89                    4.573177                   -74.190716
# 95                    4.875833                   -74.047462
# 97                    4.731429                   -74.220796
# 98                    4.849349                   -74.057244
# 100                   4.595495                   -74.184650
# 104                   4.591226                   -74.226857
# 107                   4.596069                   -74.220854
# 109                   4.895372                   -74.001846
# 114                   4.779452                   -74.046707
# 121                   4.660530                   -74.134270
# 122                   4.872338                   -74.140309
# 126                   4.569233                   -74.231472
# 128                   4.857728                   -74.057141
# 135                   4.730449                   -74.282278
# 136                   4.624731                   -74.218805
# 144                   4.623842                   -74.206606
# 146                   4.925344                   -74.026651
#
#                                                addr                source  \
# 143                                   Cl. 3 # 14-40  df_def_base_proyecto
# 111                             Cl.5 # 10-84 Cajicá  df_def_base_proyecto
# 137                                  Dg. 32 # 10-40  df_def_base_proyecto
# 42                        Cr. 1 # 30A-40 Sur Soacha  df_def_base_proyecto
# 35                    Dg. 32 # 37 - 99 Ciudad Verde  df_def_base_proyecto
# 129                    Cl. 15 # 30-78 Ciudad verde   df_def_base_proyecto
# 84                     Dg. 28 # 31-60  Ciudad Verde  df_def_base_proyecto
# 69                           Cl. 78 Sur Con Cr. 87J  df_def_base_proyecto
# 32                               Cl. 81 Sur # 80-20  df_def_base_proyecto
# 149                                 Cr. 76 # 160-15  df_def_base_proyecto
# 51                                  Cr. 87A # 6A-15  df_def_base_proyecto
# 6                               Cl. 38A Sur # 30-16  df_def_base_proyecto
# 59                              Cl. 66A Sur # 66-81  df_def_base_proyecto
# 91                                 Cr. 96B # 69A-75  df_def_base_proyecto
# 134                                 Cr. 17 # 106-29  df_def_base_proyecto
# 31                                 Cl. 4 Sur # 1-60  df_def_base_proyecto
# 124                                Cr. 116 # 77B-35  df_def_base_proyecto
# 3                               Cl. 55 Sur # 82B-91  df_def_base_proyecto
# 81                                 Cl. 131 # 78A-09  df_def_base_proyecto
# 96                                  Cl. 121 # 3A-20  df_def_base_proyecto
# 119                                  Cr. 86 # 7D-35  df_def_base_proyecto
# 123                              Dg. 151B # 136A-80  df_def_base_proyecto
# 99                                   Cl. 10 # 80-41  df_def_base_proyecto
# 93                                   Cl. 47 # 28-39  df_def_base_proyecto
# 66                                  Cr. 8 # 127C-52  df_def_base_proyecto
# 19                                 Cl. 103 # 19A-63  df_def_base_proyecto
# 26                                  Cr. 82A # 6B-78  df_def_base_proyecto
# 50                                 Cl. 154A # 94-80  df_def_base_proyecto
# 106                                 Cl. 152 # 58-51  df_def_base_proyecto
# 14                                  Cr. 19A # 90-13  df_def_base_proyecto
# 142                               Tv. 112C # 64D-15  df_def_base_proyecto
# 24                              Cl. 60A Sur # 73-81  df_def_base_proyecto
# 116                                   Tv. 4 # 43-85  df_def_base_proyecto
# 71                              Tv. 80J # 78-91 Sur  df_def_base_proyecto
# 56                                Cr. 45A # 104B-95  df_def_base_proyecto
# 76                                Cl. 104A # 45A-86  df_def_base_proyecto
# 37                                  Cr. 20 # 137-59  df_def_base_proyecto
# 10                          Av. Cl. 57R Sur # 71-93  df_def_base_proyecto
# 138                                Cr. 7 # 7-63 Sur  df_def_base_proyecto
# 92                                 Cl. 128 # 88B-10  df_def_base_proyecto
# 38                                Cl. 146F # 73A-20  df_def_base_proyecto
# 4                                  Cl. 114A # 58-14  df_def_base_proyecto
# 46                                    Cl. 18 # 4-22  df_def_base_proyecto
# 86                                  Cl. 121 # 3A-20  df_def_base_proyecto
# 105                                Cr. 113 # 19A-11  df_def_base_proyecto
# 13                                 Cr. 45A # 123-84  df_def_base_proyecto
# 79                                  Cl. 170 # 15-20  df_def_base_proyecto
# 9                                  Cl. 147B # 90-16  df_def_base_proyecto
# 18                                 Cr. 9Bis # 97-20  df_def_base_proyecto
# 60                                    Cl. 19 # 5-20  df_def_base_proyecto
# 62                                  Cl. 134 # 13-66  df_def_base_proyecto
# 145                                Cl. 134A # 19-15  df_def_base_proyecto
# 39                              Av. Cr. 15 # 136-26  df_def_base_proyecto
# 125                                Cr. 56 # 167A-03  df_def_base_proyecto
# 72                               Cl. 15 Sur # 26-57  df_def_base_proyecto
# 140                                 Cl. 97 # 71A-12  df_def_base_proyecto
# 12                                 Cr. 54D # 169-60  df_def_base_proyecto
# 55                                   Cl. 92 # 19-12  df_def_base_proyecto
# 117                                  Cl. 24 # 32-19  df_def_base_proyecto
# 133                                Cr. 14A # 103-92  df_def_base_proyecto
# 83                                    Cl. 55 # 7-38  df_def_base_proyecto
# 21                                  Cr. 92 # 150-70  df_def_base_proyecto
# 120                                Cr. 48 # 100- 17  df_def_base_proyecto
# 7                                    Cr. 14 # 88-31  df_def_base_proyecto
# 49                                  Tv. 19A # 95-61  df_def_base_proyecto
# 8                                   Cr. 54 # 106-15  df_def_base_proyecto
# 40                                  Cl. 118 # 20-51  df_def_base_proyecto
# 147                                 Cr. 14 # 112-73  df_def_base_proyecto
# 127                                 Cl. 110 # 13-21  df_def_base_proyecto
# 28                                   Cr. 38 # 56-31  df_def_base_proyecto
# 112                                 Cl. 129 # 56-13  df_def_base_proyecto
# 94                                Cl. 146A # 95B-46  df_def_base_proyecto
# 2                                   Cr. 54 # 106-34  df_def_base_proyecto
# 113                                  Cr. 3 # 51A-64  df_def_base_proyecto
# 44                                 Cr. 15B # 112-08  df_def_base_proyecto
# 102                                Cl. 114A # 16-29  df_def_base_proyecto
# 88                                  Cr. 20 # 118-83  df_def_base_proyecto
# 141                                   Cr. 7 # 81-26  df_def_base_proyecto
# 30                                 Cr. 17A # 102-78  df_def_base_proyecto
# 118                                 Cr. 16 # 112-38  df_def_base_proyecto
# 110                                 Cr. 49B # 93-88  df_def_base_proyecto
# 101                                 Cr. 17 # 120-21  df_def_base_proyecto
# 68                                 Cr. 53 # 104B-15  df_def_base_proyecto
# 33                                 Cr. 18A # 137-73  df_def_base_proyecto
# 132                               Cr. 17A # 106A-07  df_def_base_proyecto
# 53                                   Cr. 27 # 50-11  df_def_base_proyecto
# 80                                   Cr. 15 # 54-06  df_def_base_proyecto
# 54                                  Cr. 21 # 146-65  df_def_base_proyecto
# 148                                 Cl. 98A # 51-40  df_def_base_proyecto
# 23                                  Cr. 17 # 121-07  df_def_base_proyecto
# 5                                     Tv. 5 # 87-42  df_def_base_proyecto
# 85                                  Cl. 146 # 13-22  df_def_base_proyecto
# 70                                  Cr. 17 # 122-63  df_def_base_proyecto
# 115                                   Cl. 61 # 7-21  df_def_base_proyecto
# 131                                Cr. 15A # 124-22  df_def_base_proyecto
# 130                             Cl. 28C Sur # 13-22  df_def_base_proyecto
# 65                                    Cl. 60 # 9-57  df_def_base_proyecto
# 20                                 Cl. 79 # 113A-61  df_def_base_proyecto
# 78                                Cr. 35Bis # 60-45  df_def_base_proyecto
# 16                                  Cl. 75B # 78-94  df_def_base_proyecto
# 0                                   Cr. 23 # 118-70  df_def_base_proyecto
# 25                                   Cr.15 # 64B-11  df_def_base_proyecto
# 103                             Cr. 87C # 70B-30Sur  df_def_base_proyecto
# 43                                   Cl. 53 # 47-50  df_def_base_proyecto
# 11                                  Cl. 103 # 15-60  df_def_base_proyecto
# 15                                  Cr. 13 # 40B-74  df_def_base_proyecto
# 90                                 Cr. 54A # 169-45  df_def_base_proyecto
# 139                                 Cr. 17 # 113-44  df_def_base_proyecto
# 108                                Cl. 58Bis # 9-26  df_def_base_proyecto
# 1                     Km. 2 Vía  Av. Potrerogrande   df_def_base_proyecto
# 17                                Vda. Bojaca-Chía   df_def_base_proyecto
# 22                          Cl. 21 con Cr.28 Madrid  df_def_base_proyecto
# 27                              Av. C. Cali Cl. 11B  df_def_base_proyecto
# 29                              Cl. 5A # 1B-71 Chía  df_def_base_proyecto
# 34                    Tv. 34 # 24 - 42 Ciudad Verde  df_def_base_proyecto
# 36                            Cl. 201 con Aut Norte  df_def_base_proyecto
# 41                        Cl. 10 Con Cr. 7 Mosquera  df_def_base_proyecto
# 45                                 Cl. 146A Cra 111  df_def_base_proyecto
# 47                         Cr. 16 # 7D-1, Zipaquirá  df_def_base_proyecto
# 48           Vda. Canelón Sector la Florida, Cajicá  df_def_base_proyecto
# 52                         Cr. 4 Este #39-56 Soacha  df_def_base_proyecto
# 57                          Cl. 13 # 18-G-15 Soacha  df_def_base_proyecto
# 58                             Cl. 11 Cr. 1A-9 Chía  df_def_base_proyecto
# 61                               Av. Cr. 86 # 7B-35  df_def_base_proyecto
# 63                         Variante Chia-Cota, Chia  df_def_base_proyecto
# 64                      Cr. 11 Este # 4C-11, Cajica  df_def_base_proyecto
# 67                      Tv. 31 # 28-31 Ciudad Verde  df_def_base_proyecto
# 73                              Cr. 12 # 32F-80 Sur  df_def_base_proyecto
# 74                        Av Villav. Con Cl. 63 Sur  df_def_base_proyecto
# 75   Vda Cerca de Piedra, Sector Las Piscinas, Chía  df_def_base_proyecto
# 77                                  Cr. 7 # 130B-84  df_def_base_proyecto
# 82                        Dg. 22 # 7B-02, Zipaquirá  df_def_base_proyecto
# 87              Km. 4 Vte. Cajicá-Zipaquirá, Cajicá  df_def_base_proyecto
# 89            Cl. 36N # 48-89 Este San Mateo Soacha  df_def_base_proyecto
# 95                      Cr. 9 Via Chía-Cajicá, Chía  df_def_base_proyecto
# 97                             Cr. 15 # 28-99 Funza  df_def_base_proyecto
# 98                        Variante Cajica-Zipaquira  df_def_base_proyecto
# 100                Autop. Sur entre unisur y cazucá  df_def_base_proyecto
# 104                       Km. 1 Vía  Indumil Soacha  df_def_base_proyecto
# 107                     Aut. Sur Frente al Mercurio  df_def_base_proyecto
# 109              3 Km. Despues Pte. de la Caro-Chía  df_def_base_proyecto
# 114                       Cl. 201 500 mt Aut. Norte  df_def_base_proyecto
# 121            Av. Cali Cl.13 costado noroccidental  df_def_base_proyecto
# 122               Via. Colegio Departamental, Tenjo  df_def_base_proyecto
# 126                       Cr. 8a # 7c-21 Sur Soacha  df_def_base_proyecto
# 128                              Cl. 9 # 6-34, Chia  df_def_base_proyecto
# 135                 Cl. 7 # 25-95 Madrid (Glorieta)  df_def_base_proyecto
# 136                         Dg, 37A # 17-163 Soacha  df_def_base_proyecto
# 144                           Cr. 95 con Cl. 80 Sur  df_def_base_proyecto
# 146              Cajicá respaldo vía a Tabio-Cajicá  df_def_base_proyecto
#
#                                         geocode_result          estado  \
# 143  {'estado': 'success', 'yinput': 4.595197338999...         success
# 111  {'estado': 'success', 'yinput': 4.594628316000...         success
# 137  {'estado': 'success', 'yinput': 4.612888667999...         success
# 42   {'estado': 'success', 'yinput': 4.56309969, 'l...         success
# 35   {'estado': 'success', 'yinput': 4.632743917000...         success
# 129  {'estado': 'success', 'yinput': 4.615505971, '...         success
# 84   {'estado': 'success', 'yinput': 4.625439265000...         success
# 69   {'estado': 'success', 'yinput': 4.619196271000...         success
# 32   {'estado': 'success', 'yinput': 4.606117333999...         success
# 149  {'estado': 'success', 'yinput': 4.744105617, '...         success
# 51   {'estado': 'success', 'yinput': 4.644398976999...         success
# 6    {'estado': 'success', 'yinput': 4.589785839999...         success
# 59   {'estado': 'success', 'yinput': 4.592293136000...         success
# 91   {'estado': 'success', 'yinput': 4.699590168999...         success
# 134  {'estado': 'success', 'yinput': 4.692041282999...         success
# 31   {'estado': 'success', 'yinput': 4.579754283, '...         success
# 124  {'estado': 'success', 'yinput': 4.722280260999...         success
# 3    {'estado': 'success', 'yinput': 4.621662957000...         success
# 81   {'estado': 'success', 'yinput': 4.724596631, '...         success
# 96   {'estado': 'success', 'yinput': 4.696590222, '...         success
# 119  {'estado': 'success', 'yinput': 4.645117803999...         success
# 123  {'estado': 'success', 'yinput': 4.758063494999...         success
# 99   {'estado': 'success', 'yinput': 4.645189636999...         success
# 93   {'estado': 'success', 'yinput': 4.635986455000...         success
# 66   {'estado': 'success', 'yinput': 4.705277947000...         success
# 19   {'estado': 'success', 'yinput': 4.688930271, '...         success
# 26   {'estado': 'success', 'yinput': 4.640650525000...         success
# 50   {'estado': 'success', 'yinput': 4.752257466999...         success
# 106  {'estado': 'success', 'yinput': 4.736633676999...         success
# 14   {'estado': 'success', 'yinput': 4.676583640999...         success
# 142  {'estado': 'success', 'yinput': 4.706254198000...         success
# 24   {'estado': 'success', 'yinput': 4.591547693999...         success
# 116  {'estado': 'success', 'yinput': 4.630230290999...         success
# 71   {'estado': 'success', 'yinput': 4.610653663999...         success
# 56   {'estado': 'success', 'yinput': 4.692652076999...         success
# 76   {'estado': 'success', 'yinput': 4.691961149000...         success
# 37   {'estado': 'success', 'yinput': 4.722939898999...         success
# 10   {'estado': 'success', 'yinput': 4.595491354999...         success
# 138  {'estado': 'success', 'yinput': 4.581437746000...         success
# 92   {'estado': 'success', 'yinput': 4.719331403000...         success
# 38   {'estado': 'success', 'yinput': 4.738254450999...         success
# 4    {'estado': 'success', 'yinput': 4.697474883999...         success
# 46   {'estado': 'success', 'yinput': 4.602798306000...         success
# 86   {'estado': 'success', 'yinput': 4.696590222, '...         success
# 105  {'estado': 'success', 'yinput': 4.683549632999...         success
# 13   {'estado': 'success', 'yinput': 4.704776173000...         success
# 79   {'estado': 'success', 'yinput': 4.749389345, '...         success
# 9    {'estado': 'success', 'yinput': 4.742083288, '...         success
# 18   {'estado': 'success', 'yinput': 4.678943737, '...         success
# 60   {'estado': 'success', 'yinput': 4.604320232000...         success
# 62   {'estado': 'success', 'yinput': 4.716220119000...         success
# 145  {'estado': 'success', 'yinput': 4.719060010000...         success
# 39   {'estado': 'success', 'yinput': 4.720086654999...         success
# 125  {'estado': 'success', 'yinput': 4.750626899, '...         success
# 72   {'estado': 'success', 'yinput': 4.592531048000...         success
# 140  {'estado': 'success', 'yinput': 4.695932884, '...         success
# 12   {'estado': 'success', 'yinput': 4.752312526000...         success
# 55   {'estado': 'success', 'yinput': 4.677728096000...         success
# 117  {'estado': 'success', 'yinput': 4.625891638999...         success
# 133  {'estado': 'success', 'yinput': 4.688222216999...         success
# 83   {'estado': 'success', 'yinput': 4.641553257999...         success
# 21   {'estado': 'success', 'yinput': 4.746050962000...         success
# 120  {'estado': 'success', 'yinput': 4.688147822000...         success
# 7    {'estado': 'success', 'yinput': 4.673191396999...         success
# 49   {'estado': 'success', 'yinput': 4.683193158999...         success
# 8    {'estado': 'success', 'yinput': 4.694827660999...         success
# 40   {'estado': 'success', 'yinput': 4.699813834, '...         success
# 147  {'estado': 'success', 'yinput': 4.695271196000...         success
# 127  {'estado': 'success', 'yinput': 4.691961121000...         success
# 28   {'estado': 'success', 'yinput': 4.646198813000...         success
# 112  {'estado': 'success', 'yinput': 4.716777881999...         success
# 94   {'estado': 'success', 'yinput': 4.741444713000...         success
# 2    {'estado': 'success', 'yinput': 4.695144993999...         success
# 113  {'estado': 'success', 'yinput': 4.637826502999...         success
# 44   {'estado': 'success', 'yinput': 4.695199527999...         success
# 102  {'estado': 'success', 'yinput': 4.696368042000...         success
# 88   {'estado': 'success', 'yinput': 4.700669220000...         success
# 141  {'estado': 'success', 'yinput': 4.662498514999...         success
# 30   {'estado': 'success', 'yinput': 4.688139498999...         success
# 118  {'estado': 'success', 'yinput': 4.69562298, 'l...         success
# 110  {'estado': 'success', 'yinput': 4.682177910000...         success
# 101  {'estado': 'success', 'yinput': 4.699709918999...         success
# 68   {'estado': 'success', 'yinput': 4.693456990000...         success
# 33   {'estado': 'success', 'yinput': 4.722666765999...         success
# 132  {'estado': 'success', 'yinput': 4.692761987999...         success
# 53   {'estado': 'success', 'yinput': 4.639251461000...         success
# 80   {'estado': 'success', 'yinput': 4.641370591, '...         success
# 54   {'estado': 'success', 'yinput': 4.729281193000...         success
# 148  {'estado': 'success', 'yinput': 4.686758864000...         success
# 23   {'estado': 'success', 'yinput': 4.700233669999...         success
# 5    {'estado': 'success', 'yinput': 4.667695365999...         success
# 85   {'estado': 'success', 'yinput': 4.726803378999...         success
# 70   {'estado': 'success', 'yinput': 4.701824226999...         success
# 115  {'estado': 'success', 'yinput': 4.646345718000...         success
# 131  {'estado': 'success', 'yinput': 4.702524595, '...         success
# 130  {'estado': 'success', 'yinput': 4.577468841999...         success
# 65   {'estado': 'success', 'yinput': 4.646189076999...         success
# 20   {'estado': 'success', 'yinput': 4.720550461000...         success
# 78   {'estado': 'success', 'yinput': 4.650710091000...         success
# 16   {'estado': 'success', 'yinput': 4.696644946999...         success
# 0    {'estado': 'success', 'yinput': 4.701081148000...         success
# 25   {'estado': 'success', 'yinput': 4.652884734999...         success
# 103  {'estado': 'success', 'yinput': 4.620452198000...         success
# 43   {'estado': 'success', 'yinput': 4.647278798, '...         success
# 11   {'estado': 'success', 'yinput': 4.688250636000...         success
# 15   {'estado': 'success', 'yinput': 4.628450564999...         success
# 90   {'estado': 'success', 'yinput': 4.751824366999...         success
# 139  {'estado': 'success', 'yinput': 4.696117779000...         success
# 108  {'estado': 'success', 'yinput': 4.644711914000...         success
# 1                         {'estado': 'outside_bogota'}  outside_bogota
# 17                                {'estado': 'failed'}          failed
# 22                        {'estado': 'outside_bogota'}  outside_bogota
# 27                                {'estado': 'failed'}          failed
# 29                        {'estado': 'outside_bogota'}  outside_bogota
# 34                                {'estado': 'failed'}          failed
# 36                                {'estado': 'failed'}          failed
# 41                        {'estado': 'outside_bogota'}  outside_bogota
# 45                                {'estado': 'failed'}          failed
# 47                        {'estado': 'outside_bogota'}  outside_bogota
# 48                                {'estado': 'failed'}          failed
# 52                                {'estado': 'failed'}          failed
# 57                                {'estado': 'failed'}          failed
# 58                        {'estado': 'outside_bogota'}  outside_bogota
# 61                                {'estado': 'failed'}          failed
# 63                        {'estado': 'outside_bogota'}  outside_bogota
# 64                                {'estado': 'failed'}          failed
# 67                                {'estado': 'failed'}          failed
# 73                                {'estado': 'failed'}          failed
# 74                                {'estado': 'failed'}          failed
# 75                        {'estado': 'outside_bogota'}  outside_bogota
# 77                                {'estado': 'failed'}          failed
# 82                        {'estado': 'outside_bogota'}  outside_bogota
# 87                        {'estado': 'outside_bogota'}  outside_bogota
# 89                                {'estado': 'failed'}          failed
# 95                        {'estado': 'outside_bogota'}  outside_bogota
# 97                                {'estado': 'failed'}          failed
# 98                                {'estado': 'failed'}          failed
# 100                               {'estado': 'failed'}          failed
# 104                       {'estado': 'outside_bogota'}  outside_bogota
# 107                               {'estado': 'failed'}          failed
# 109                       {'estado': 'outside_bogota'}  outside_bogota
# 114                               {'estado': 'failed'}          failed
# 121                               {'estado': 'failed'}          failed
# 122                       {'estado': 'outside_bogota'}  outside_bogota
# 126                               {'estado': 'failed'}          failed
# 128                       {'estado': 'outside_bogota'}  outside_bogota
# 135                       {'estado': 'outside_bogota'}  outside_bogota
# 136                               {'estado': 'failed'}          failed
# 144                               {'estado': 'failed'}          failed
# 146                               {'estado': 'failed'}          failed
#
#                  tipo_direccion       lat        lng  \
# 143       Asignada por Catastro  4.595197 -74.086989
# 111           Dirección antigua  4.594628 -74.082311
# 137  Dirección por aproximación  4.612889 -74.070825
# 42        Asignada por Catastro  4.563100 -74.092275
# 35   Dirección por aproximación  4.632744 -74.085700
# 129  Dirección por aproximación  4.615506 -74.091262
# 84   Dirección por aproximación  4.625439 -74.084746
# 69   Dirección por aproximación  4.619196 -74.203484
# 32   Dirección por aproximación  4.606117 -74.196757
# 149  Dirección por aproximación  4.744106 -74.063928
# 51        Asignada por Catastro  4.644399 -74.155789
# 6    Dirección por aproximación  4.589786 -74.120824
# 59   Dirección por aproximación  4.592293 -74.157524
# 91   Dirección por aproximación  4.699590 -74.118394
# 134       Asignada por Catastro  4.692041 -74.047946
# 31   Dirección por aproximación  4.579754 -74.080292
# 124       Asignada por Catastro  4.722280 -74.125639
# 3         Asignada por Catastro  4.621663 -74.181165
# 81   Dirección por aproximación  4.724597 -74.077203
# 96        Asignada por Catastro  4.696590 -74.027839
# 119       Asignada por Catastro  4.645118 -74.151166
# 123       Asignada por Catastro  4.758063 -74.107305
# 99        Asignada por Catastro  4.645190 -74.143359
# 93   Dirección por aproximación  4.635986 -74.078513
# 66   Dirección por aproximación  4.705278 -74.032171
# 19   Dirección por aproximación  4.688930 -74.053097
# 26   Dirección por aproximación  4.640651 -74.152889
# 50        Asignada por Catastro  4.752257 -74.084048
# 106       Asignada por Catastro  4.736634 -74.062938
# 14        Asignada por Catastro  4.676584 -74.056707
# 142  Dirección por aproximación  4.706254 -74.134960
# 24   Dirección por aproximación  4.591548 -74.168975
# 116       Asignada por Catastro  4.630230 -74.062227
# 71   Dirección por aproximación  4.610654 -74.204868
# 56   Dirección por aproximación  4.692652 -74.057226
# 76   Dirección por aproximación  4.691961 -74.057582
# 37        Asignada por Catastro  4.722940 -74.048125
# 10        Asignada por Catastro  4.595491 -74.166235
# 138       Asignada por Catastro  4.581438 -74.085109
# 92        Asignada por Catastro  4.719331 -74.088720
# 38        Asignada por Catastro  4.738254 -74.069729
# 4         Asignada por Catastro  4.697475 -74.068132
# 46   Dirección por aproximación  4.602798 -74.069410
# 86        Asignada por Catastro  4.696590 -74.027839
# 105       Asignada por Catastro  4.683550 -74.150531
# 13   Dirección por aproximación  4.704776 -74.055186
# 79   Dirección por aproximación  4.749389 -74.037730
# 9    Dirección por aproximación  4.742083 -74.083426
# 18   Dirección por aproximación  4.678944 -74.042780
# 60   Dirección por aproximación  4.604320 -74.070337
# 62        Asignada por Catastro  4.716220 -74.042368
# 145       Asignada por Catastro  4.719060 -74.047144
# 39        Asignada por Catastro  4.720087 -74.041313
# 125       Asignada por Catastro  4.750627 -74.057467
# 72        Asignada por Catastro  4.592531 -74.105293
# 140  Dirección por aproximación  4.695933 -74.081176
# 12        Asignada por Catastro  4.752313 -74.054354
# 55   Dirección por aproximación  4.677728 -74.055608
# 117       Asignada por Catastro  4.625892 -74.085526
# 133       Asignada por Catastro  4.688222 -74.046041
# 83        Asignada por Catastro  4.641553 -74.062834
# 21        Asignada por Catastro  4.746051 -74.084564
# 120       Asignada por Catastro  4.688148 -74.060407
# 7         Asignada por Catastro  4.673191 -74.052855
# 49        Asignada por Catastro  4.683193 -74.053565
# 8    Dirección por aproximación  4.694828 -74.063398
# 40        Asignada por Catastro  4.699814 -74.051943
# 147       Asignada por Catastro  4.695271 -74.041290
# 127       Asignada por Catastro  4.691961 -74.041646
# 28   Dirección por aproximación  4.646199 -74.082929
# 112       Asignada por Catastro  4.716778 -74.065207
# 94        Asignada por Catastro  4.741445 -74.088671
# 2         Asignada por Catastro  4.695145 -74.063390
# 113  Dirección por aproximación  4.637827 -74.061158
# 44        Asignada por Catastro  4.695200 -74.044973
# 102  Dirección por aproximación  4.696368 -74.045901
# 88        Asignada por Catastro  4.700669 -74.051378
# 141       Asignada por Catastro  4.662499 -74.049053
# 30   Dirección por aproximación  4.688139 -74.049963
# 118       Asignada por Catastro  4.695623 -74.045641
# 110       Asignada por Catastro  4.682178 -74.062741
# 101  Dirección por aproximación  4.699710 -74.045726
# 68        Asignada por Catastro  4.693457 -74.062811
# 33        Asignada por Catastro  4.722667 -74.045624
# 132       Asignada por Catastro  4.692762 -74.048660
# 53        Asignada por Catastro  4.639251 -74.076521
# 80        Asignada por Catastro  4.641371 -74.067123
# 54        Asignada por Catastro  4.729281 -74.047670
# 148       Asignada por Catastro  4.686759 -74.062011
# 23        Asignada por Catastro  4.700234 -74.045767
# 5         Asignada por Catastro  4.667695 -74.044730
# 85        Asignada por Catastro  4.726803 -74.038152
# 70        Asignada por Catastro  4.701824 -74.045503
# 115  Dirección por aproximación  4.646346 -74.060840
# 131       Asignada por Catastro  4.702525 -74.043613
# 130       Asignada por Catastro  4.577469 -74.107895
# 65        Asignada por Catastro  4.646189 -74.062835
# 20        Asignada por Catastro  4.720550 -74.121933
# 78        Asignada por Catastro  4.650710 -74.079365
# 16        Asignada por Catastro  4.696645 -74.098784
# 0         Asignada por Catastro  4.701081 -74.053570
# 25        Asignada por Catastro  4.652885 -74.065220
# 103  Dirección por aproximación  4.620452 -74.196914
# 43        Asignada por Catastro  4.647279 -74.085735
# 11        Asignada por Catastro  4.688251 -74.048040
# 15        Asignada por Catastro  4.628451 -74.066927
# 90        Asignada por Catastro  4.751824 -74.053798
# 139       Asignada por Catastro  4.696118 -74.046331
# 108       Asignada por Catastro  4.644712 -74.063400
# 1                          None       NaN        NaN
# 17                         None       NaN        NaN
# 22                         None       NaN        NaN
# 27                         None       NaN        NaN
# 29                         None       NaN        NaN
# 34                         None       NaN        NaN
# 36                         None       NaN        NaN
# 41                         None       NaN        NaN
# 45                         None       NaN        NaN
# 47                         None       NaN        NaN
# 48                         None       NaN        NaN
# 52                         None       NaN        NaN
# 57                         None       NaN        NaN
# 58                         None       NaN        NaN
# 61                         None       NaN        NaN
# 63                         None       NaN        NaN
# 64                         None       NaN        NaN
# 67                         None       NaN        NaN
# 73                         None       NaN        NaN
# 74                         None       NaN        NaN
# 75                         None       NaN        NaN
# 77                         None       NaN        NaN
# 82                         None       NaN        NaN
# 87                         None       NaN        NaN
# 89                         None       NaN        NaN
# 95                         None       NaN        NaN
# 97                         None       NaN        NaN
# 98                         None       NaN        NaN
# 100                        None       NaN        NaN
# 104                        None       NaN        NaN
# 107                        None       NaN        NaN
# 109                        None       NaN        NaN
# 114                        None       NaN        NaN
# 121                        None       NaN        NaN
# 122                        None       NaN        NaN
# 126                        None       NaN        NaN
# 128                        None       NaN        NaN
# 135                        None       NaN        NaN
# 136                        None       NaN        NaN
# 144                        None       NaN        NaN
# 146                        None       NaN        NaN
#
#                                    real_geom  \
# 143              POINT (-74.056134 4.928275)
# 111              POINT (-74.030511 4.921657)
# 137              POINT (-74.231625 4.560258)
# 42               POINT (-74.227222 4.557297)
# 35               POINT (-74.218326 4.611606)
# 129              POINT (-74.218876 4.599556)
# 84               POINT (-74.204551 4.588568)
# 69          POINT (-74.20784898 4.607616422)
# 32               POINT (-74.205741 4.612116)
# 149                  POINT (-74.0724 4.7449)
# 51          POINT (-74.15271407 4.641065392)
# 6    POINT (-74.1218956688515 4.58708616134)
# 59   POINT (-74.1571566049582 4.58941159729)
# 91                POINT (-74.116513 4.69941)
# 134          POINT (-74.04606403 4.69193092)
# 31               POINT (-74.078554 4.579696)
# 124              POINT (-74.124458 4.723551)
# 3    POINT (-74.1800456333217 4.62047247616)
# 81                   POINT (-74.0788 4.7246)
# 96               POINT (-74.028115 4.698071)
# 119              POINT (-74.151862 4.646213)
# 123         POINT (-74.106152789 4.75747303)
# 99           POINT (-74.14446174 4.64476127)
# 93             POINT (-74.077926 4.63698811)
# 66                   POINT (-74.0319 4.7064)
# 19                POINT (-74.052836 4.68785)
# 26             POINT (-74.153706 4.64007019)
# 50               POINT (-74.083209 4.751816)
# 106              POINT (-74.062305 4.735948)
# 14             POINT (-74.056047 4.67601901)
# 142              POINT (-74.135033 4.705389)
# 24          POINT (-74.16979691 4.591470523)
# 116         POINT (-74.062722882 4.62962624)
# 71           POINT (-74.20553695 4.61105243)
# 56               POINT (-74.057251 4.693401)
# 76                   POINT (-74.0582 4.6923)
# 37   POINT (-74.0481801502397 4.72233507316)
# 10               POINT (-74.166777 4.595302)
# 138   POINT (-74.0847456655374 4.5818697279)
# 92                 POINT (-74.08919 4.71954)
# 38                   POINT (-74.0696 4.7387)
# 4    POINT (-74.0683832415586 4.69709316198)
# 46                POINT (-74.068983 4.60267)
# 86          POINT (-74.02745378 4.696548642)
# 105              POINT (-74.150768 4.683818)
# 13           POINT (-74.05522076 4.70443215)
# 79                POINT (-74.037412 4.74935)
# 9                    POINT (-74.0834 4.7424)
# 18             POINT (-74.042556 4.67914115)
# 60            POINT (-74.07018512 4.6045714)
# 62                 POINT (-74.04223 4.71647)
# 145              POINT (-74.047026 4.719315)
# 39                 POINT (-74.0414 4.720337)
# 125              POINT (-74.057622 4.750414)
# 72               POINT (-74.105351 4.592295)
# 140                   POINT (-74.081 4.6961)
# 12         POINT (-74.054423404 4.752079872)
# 55   POINT (-74.0553958197012 4.67761756577)
# 117               POINT (-74.08568 4.625725)
# 133              POINT (-74.045863 4.688115)
# 83           POINT (-74.06263119 4.64152571)
# 21             POINT (-74.0845182 4.7458536)
# 120               POINT (-74.06049 4.687974)
# 7                     POINT (-74.053 4.6733)
# 49               POINT (-74.053737 4.683143)
# 8                 POINT (-74.06349 4.694978)
# 40   POINT (-74.0518100323077 4.69992045975)
# 147                  POINT (-74.0414 4.6954)
# 127                  POINT (-74.0416 4.6918)
# 28         POINT (-74.082985581 4.646351214)
# 112          POINT (-74.06505863 4.71683306)
# 94           POINT (-74.08851372 4.74144314)
# 2                POINT (-74.063294 4.695022)
# 113   POINT (-74.0612204632919 4.6376855186)
# 44                POINT (-74.04488 4.695313)
# 102  POINT (-74.0457594654194 4.69635828817)
# 88   POINT (-74.0513344590833 4.70054195487)
# 141               POINT (-74.049086 4.66237)
# 30               POINT (-74.049938 4.688268)
# 118  POINT (-74.0456671532539 4.69549684601)
# 110               POINT (-74.062784 4.68207)
# 101            POINT (-74.045795 4.69979435)
# 68             POINT (-74.062716 4.69350573)
# 33                POINT (-74.04572 4.722622)
# 132              POINT (-74.048662 4.692667)
# 53               POINT (-74.076542 4.639161)
# 80   POINT (-74.0671271685461 4.64128168977)
# 54   POINT (-74.0476477530418 4.72919944145)
# 148              POINT (-74.061932 4.686787)
# 23             POINT (-74.0457353 4.7001597)
# 5                POINT (-74.044656 4.667664)
# 85                 POINT (-74.03813 4.72673)
# 70               POINT (-74.045444 4.701781)
# 115         POINT (-74.06090299 4.646308376)
# 131              POINT (-74.043563 4.702575)
# 130              POINT (-74.107905 4.577536)
# 65               POINT (-74.062897 4.646169)
# 20            POINT (-74.12187423 4.7205627)
# 78                POINT (-74.079358 4.65077)
# 16                   POINT (-74.0988 4.6967)
# 0    POINT (-74.0535361677524 4.70112381522)
# 25                POINT (-74.065266 4.65286)
# 103         POINT (-74.19686767 4.620465794)
# 43           POINT (-74.08574578 4.64723611)
# 11               POINT (-74.048051 4.688211)
# 15    POINT (-74.066958863598 4.62846910171)
# 90           POINT (-74.05378623 4.75179038)
# 139         POINT (-74.04630587 4.696133203)
# 108              POINT (-74.063412 4.644715)
# 1                POINT (-74.223172 4.606742)
# 17                POINT (-74.049001 4.87859)
# 22                POINT (-74.24723 4.728154)
# 27               POINT (-74.144847 4.651675)
# 29               POINT (-74.052843 4.849615)
# 34               POINT (-74.217817 4.608079)
# 36                 POINT (-74.04242 4.77915)
# 41               POINT (-74.230824 4.712169)
# 45               POINT (-74.100027 4.750868)
# 47               POINT (-73.986546 5.035737)
# 48                 POINT (-74.0445 4.914895)
# 52                POINT (-74.198253 4.58974)
# 57               POINT (-74.218997 4.596001)
# 58                POINT (-74.051042 4.85465)
# 61    POINT (-74.152041555367 4.64463725823)
# 63                POINT (-74.071184 4.85549)
# 64               POINT (-74.014422 4.917218)
# 67               POINT (-74.201592 4.587196)
# 73               POINT (-74.113913 4.569777)
# 74    POINT (-74.160992623295 4.58810906009)
# 75               POINT (-74.077809 4.856644)
# 77               POINT (-74.028805 4.710843)
# 82           POINT (-74.07078539 4.60812695)
# 87               POINT (-74.012794 4.923045)
# 89               POINT (-74.190716 4.573177)
# 95               POINT (-74.047462 4.875833)
# 97               POINT (-74.220796 4.731429)
# 98               POINT (-74.057244 4.849349)
# 100               POINT (-74.18465 4.595495)
# 104              POINT (-74.226857 4.591226)
# 107              POINT (-74.220854 4.596069)
# 109              POINT (-74.001846 4.895372)
# 114            POINT (-74.0467072 4.7794521)
# 121                POINT (-74.13427 4.66053)
# 122              POINT (-74.140309 4.872338)
# 126              POINT (-74.231472 4.569233)
# 128              POINT (-74.057141 4.857728)
# 135              POINT (-74.282278 4.730449)
# 136              POINT (-74.218805 4.624731)
# 144  POINT (-74.2066055856784 4.62384214783)
# 146              POINT (-74.026651 4.925344)
#
#                               geocoded_geom  degrees_distance      distance
# 143  POINT (-74.086989031 4.59519733899998)          0.334504  36981.142907
# 111  POINT (-74.082310544 4.59462831600001)          0.331106  36607.507963
# 137  POINT (-74.070825203 4.61288866799998)          0.169194  18762.941533
# 42         POINT (-74.092275491 4.56309969)          0.135071  14984.299643
# 35   POINT (-74.085699881 4.63274391700003)          0.134300  14896.331551
# 129       POINT (-74.091261944 4.615505971)          0.128607  14265.597499
# 84   POINT (-74.084745815 4.62543926500001)          0.125351  13901.047129
# 69   POINT (-74.203483756 4.61919627100002)          0.012375   1368.648446
# 32   POINT (-74.196756681 4.60611733399998)          0.010803   1197.078432
# 149       POINT (-74.063928461 4.744105617)          0.008509    943.681102
# 51    POINT (-74.15578887 4.64439897699998)          0.004535    502.135535
# 6    POINT (-74.120824117 4.58978583999999)          0.002905    321.251790
# 59   POINT (-74.157523735 4.59229313600002)          0.002905    321.144437
# 91   POINT (-74.118394437 4.69959016899998)          0.001890    209.630815
# 134  POINT (-74.047945603 4.69204128299998)          0.001885    209.060200
# 31        POINT (-74.080291618 4.579754283)          0.001739    192.872695
# 124  POINT (-74.125638917 4.72228026099998)          0.001735    192.068296
# 3    POINT (-74.181165383 4.62166295700001)          0.001634    180.965092
# 81        POINT (-74.077203475 4.724596631)          0.001597    177.076951
# 96        POINT (-74.027839171 4.696590222)          0.001506    166.539441
# 119   POINT (-74.15116627 4.64511780399999)          0.001297    143.577303
# 123   POINT (-74.10730515 4.75806349499999)          0.001295    143.510592
# 99   POINT (-74.143359202 4.64518963699999)          0.001183    131.146639
# 93   POINT (-74.078512807 4.63598645500002)          0.001161    128.449431
# 66   POINT (-74.032170729 4.70527794700001)          0.001154    127.629538
# 19        POINT (-74.053096927 4.688930271)          0.001111    122.883635
# 26   POINT (-74.152889301 4.64065052500001)          0.001002    111.008500
# 50   POINT (-74.084048169 4.75225746699999)          0.000948    105.091577
# 106  POINT (-74.062938384 4.73663367699999)          0.000933    103.349941
# 14   POINT (-74.056706941 4.67658364099998)          0.000869     96.202684
# 142  POINT (-74.134959835 4.70625419800001)          0.000868     95.991377
# 24   POINT (-74.168975035 4.59154769399998)          0.000825     91.570418
# 116  POINT (-74.062226627 4.63023029099998)          0.000782     86.543946
# 71   POINT (-74.204868052 4.61065366399998)          0.000779     86.306701
# 56    POINT (-74.05722613 4.69265207699999)          0.000749     82.841208
# 76   POINT (-74.057581771 4.69196114900001)          0.000705     78.138713
# 37   POINT (-74.048124708 4.72293989899998)          0.000607     67.147378
# 10    POINT (-74.16623455 4.59549135499998)          0.000575     63.711750
# 138  POINT (-74.085108903 4.58143774600001)          0.000564     62.485373
# 92   POINT (-74.088719779 4.71933140300001)          0.000514     57.025055
# 38   POINT (-74.069729313 4.73825445099999)          0.000464     51.302021
# 4    POINT (-74.068132402 4.69747488399997)          0.000457     50.546594
# 46   POINT (-74.069409913 4.60279830600001)          0.000446     49.437382
# 86        POINT (-74.027839171 4.696590222)          0.000388     42.993937
# 105  POINT (-74.150530985 4.68354963299998)          0.000358     39.639705
# 13    POINT (-74.05518552 4.70477617300003)          0.000346     38.232946
# 79        POINT (-74.037730067 4.749389345)          0.000320     35.544305
# 9         POINT (-74.083425694 4.742083288)          0.000318     35.128854
# 18        POINT (-74.042779739 4.678943737)          0.000298     33.048826
# 60   POINT (-74.070336883 4.60432023200002)          0.000293     32.472202
# 62   POINT (-74.042367672 4.71622011900001)          0.000285     31.564541
# 145  POINT (-74.047143752 4.71906001000002)          0.000281     31.068413
# 39   POINT (-74.041313476 4.72008665499999)          0.000265     29.293051
# 125        POINT (-74.05746712 4.750626899)          0.000263     29.138374
# 72   POINT (-74.105293246 4.59253104800001)          0.000243     26.870250
# 140       POINT (-74.081175761 4.695932884)          0.000243     26.858566
# 12   POINT (-74.054353915 4.75231252600003)          0.000243     26.850402
# 55   POINT (-74.055608277 4.67772809600001)          0.000239     26.545760
# 117  POINT (-74.085526403 4.62589163899997)          0.000227     25.093469
# 133  POINT (-74.046040869 4.68822221699997)          0.000208     23.016148
# 83   POINT (-74.062834237 4.64155325799999)          0.000205     22.728421
# 21   POINT (-74.084564018 4.74605096200003)          0.000203     22.402674
# 120  POINT (-74.060407032 4.68814782200002)          0.000193     21.306404
# 7    POINT (-74.052855283 4.67319139699998)          0.000181     20.045733
# 49   POINT (-74.053565434 4.68319315899998)          0.000179     19.821730
# 8     POINT (-74.06339843 4.69482766099998)          0.000176     19.478099
# 40        POINT (-74.051942805 4.699813834)          0.000170     18.863567
# 147  POINT (-74.041289656 4.69527119600002)          0.000170     18.776811
# 127  POINT (-74.041645571 4.69196112100002)          0.000167     18.515722
# 28   POINT (-74.082928988 4.64619881300001)          0.000163     17.979685
# 112  POINT (-74.065207046 4.71677788199997)          0.000158     17.555497
# 94   POINT (-74.088671476 4.74144471300002)          0.000158     17.497697
# 2    POINT (-74.063390484 4.69514499399997)          0.000156     17.303647
# 113  POINT (-74.061158471 4.63782650299999)          0.000154     17.035729
# 44   POINT (-74.044973092 4.69519952799999)          0.000147     16.247727
# 102  POINT (-74.045900642 4.69636804200002)          0.000142     15.696281
# 88   POINT (-74.051378466 4.70066922000001)          0.000135     14.892167
# 141  POINT (-74.049053028 4.66249851499998)          0.000133     14.670870
# 30   POINT (-74.049963131 4.68813949899999)          0.000131     14.477031
# 118        POINT (-74.045640601 4.69562298)          0.000129     14.252093
# 110  POINT (-74.062740876 4.68217791000001)          0.000116     12.852938
# 101  POINT (-74.045726446 4.69970991899999)          0.000109     12.039301
# 68   POINT (-74.062810827 4.69345699000002)          0.000107     11.817996
# 33   POINT (-74.045624057 4.72266676599997)          0.000106     11.736046
# 132  POINT (-74.048659649 4.69276198799997)          0.000095     10.504418
# 53   POINT (-74.076521067 4.63925146100001)          0.000093     10.266653
# 80        POINT (-74.067123402 4.641370591)          0.000089      9.837083
# 54    POINT (-74.04766951 4.72928119300002)          0.000085      9.354483
# 148  POINT (-74.062010852 4.68675886400001)          0.000084      9.282923
# 23   POINT (-74.045767207 4.70023366999999)          0.000081      8.910562
# 5    POINT (-74.044729728 4.66769536599998)          0.000080      8.882962
# 85   POINT (-74.038152066 4.72680337899999)          0.000077      8.473433
# 70   POINT (-74.045503253 4.70182422699997)          0.000073      8.126008
# 115  POINT (-74.060840133 4.64634571800002)          0.000073      8.102982
# 131       POINT (-74.043612693 4.702524595)          0.000071      7.837889
# 130  POINT (-74.107895304 4.57746884199997)          0.000068      7.501866
# 65   POINT (-74.062834713 4.64618907699997)          0.000065      7.257040
# 20   POINT (-74.121933475 4.72055046100002)          0.000060      6.708897
# 78    POINT (-74.07936527 4.65071009100001)          0.000060      6.671952
# 16   POINT (-74.098783534 4.69664494699998)          0.000057      6.354300
# 0    POINT (-74.053570134 4.70108114800001)          0.000055      6.036862
# 25   POINT (-74.065220006 4.65288473499999)          0.000052      5.788520
# 103  POINT (-74.196913813 4.62045219800001)          0.000048      5.334601
# 43        POINT (-74.085734978 4.647278798)          0.000044      4.868958
# 11   POINT (-74.048039799 4.68825063600002)          0.000041      4.554599
# 15   POINT (-74.066927164 4.62845056499998)          0.000037      4.069970
# 90   POINT (-74.053798252 4.75182436699998)          0.000036      3.986926
# 139  POINT (-74.046331054 4.69611777900002)          0.000030      3.272709
# 108  POINT (-74.063399878 4.64471191400003)          0.000013      1.387259
# 1                               POINT EMPTY               NaN           NaN
# 17                              POINT EMPTY               NaN           NaN
# 22                              POINT EMPTY               NaN           NaN
# 27                              POINT EMPTY               NaN           NaN
# 29                              POINT EMPTY               NaN           NaN
# 34                              POINT EMPTY               NaN           NaN
# 36                              POINT EMPTY               NaN           NaN
# 41                              POINT EMPTY               NaN           NaN
# 45                              POINT EMPTY               NaN           NaN
# 47                              POINT EMPTY               NaN           NaN
# 48                              POINT EMPTY               NaN           NaN
# 52                              POINT EMPTY               NaN           NaN
# 57                              POINT EMPTY               NaN           NaN
# 58                              POINT EMPTY               NaN           NaN
# 61                              POINT EMPTY               NaN           NaN
# 63                              POINT EMPTY               NaN           NaN
# 64                              POINT EMPTY               NaN           NaN
# 67                              POINT EMPTY               NaN           NaN
# 73                              POINT EMPTY               NaN           NaN
# 74                              POINT EMPTY               NaN           NaN
# 75                              POINT EMPTY               NaN           NaN
# 77                              POINT EMPTY               NaN           NaN
# 82                              POINT EMPTY               NaN           NaN
# 87                              POINT EMPTY               NaN           NaN
# 89                              POINT EMPTY               NaN           NaN
# 95                              POINT EMPTY               NaN           NaN
# 97                              POINT EMPTY               NaN           NaN
# 98                              POINT EMPTY               NaN           NaN
# 100                             POINT EMPTY               NaN           NaN
# 104                             POINT EMPTY               NaN           NaN
# 107                             POINT EMPTY               NaN           NaN
# 109                             POINT EMPTY               NaN           NaN
# 114                             POINT EMPTY               NaN           NaN
# 121                             POINT EMPTY               NaN           NaN
# 122                             POINT EMPTY               NaN           NaN
# 126                             POINT EMPTY               NaN           NaN
# 128                             POINT EMPTY               NaN           NaN
# 135                             POINT EMPTY               NaN           NaN
# 136                             POINT EMPTY               NaN           NaN
# 144                             POINT EMPTY               NaN           NaN
# 146                             POINT EMPTY               NaN           NaN

# %%
pd.set_option('display.max_rows', 10)

# %%
sample_6['estado'].value_counts(normalize=True)
# Out:
# estado
# success           0.726667
# failed            0.166667
# outside_bogota    0.106667
# Name: proportion, dtype: float64

# %%
sample_6['distance'].describe()
# Out:
# count      109.000000
# mean      1464.510520
# std       5832.785382
# min          1.387259
# 25%         12.039301
# 50%         26.870250
# 75%        105.091577
# max      36981.142907
# Name: distance, dtype: float64

# %%
sample_6['distance'].sort_values(ascending=False).plot.bar(figsize=(30,5))
# Out:
# <Axes: >

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# El 16% de la muestra aleatoria del sexto dataframe (df_def_base_proyecto) no pudo ser georeferenciada por las siguientes razones:
#
# * Nombres de vías que no son aceptados por el API
# * Detalles de texto en la dirección
# * Referencia a lugares especificos (no direcciones)
#
# Hay un 10% adicional que hace referencia a direcciones fuera de Bogotá (en otras ciudades o en vías nacionales)
#
# Adicionalmente, en este dataframe se contaba con coordenadas reales de referencia. En la revisión de los datos, el geocodificador muestra una alta presición. El 19% de los casos se ubicaron a mas de 100 metros de la coordenada original.

# %% [markdown]
# ## Procesamiento

# %%
df_vivienda_usada_venta['geocode_result'] = df_vivienda_usada_venta[vivienda_usada_dir].swifter.apply(georeferenciar)

# %%
pd.set_option('display.max_colwidth', 50)

# %%
# Caso especial que parte de un xlsx intermedio (por eso es diferente a los samples)
df_vivienda_usada_venta['estado'] = df_vivienda_usada_venta.apply(lambda x: json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['estado'] if type(x['geocode_result']) is str else x['geocode_result']['estado'], axis=1)
df_vivienda_usada_venta['tipo_direccion'] = df_vivienda_usada_venta.apply(lambda x: None if 'tipo_direccion' not in json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0','')) else json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['tipo_direccion'] if type(x['geocode_result']) is str else x['geocode_result']['tipo_direccion'], axis=1)
df_vivienda_usada_venta['lat'] = df_vivienda_usada_venta.apply(lambda x: None if 'yinput' not in json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0','')) else json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['yinput'] if type(x['geocode_result']) is str else x['geocode_result']['yinput'], axis=1)
df_vivienda_usada_venta['lng'] = df_vivienda_usada_venta.apply(lambda x: None if 'xinput' not in json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0','')) else json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['xinput'] if type(x['geocode_result']) is str else x['geocode_result']['xinput'], axis=1)

# %%
df_vivienda_usada_venta['estado'].value_counts(normalize=True)
# Out:
# estado
# success     0.993987
# failed      0.005876
# error_ws    0.000137
# Name: proportion, dtype: float64

# %%
df_vivienda_usada_arriendo['geocode_result'] = df_vivienda_usada_arriendo[vivienda_usada_dir].swifter.apply(georeferenciar)
# Out:
# Pandas Apply:   0%|          | 0/38301 [00:00<?, ?it/s]

# %%
# Caso especial que parte de un xlsx intermedio (por eso es diferente a los samples)
df_vivienda_usada_arriendo['estado'] = df_vivienda_usada_arriendo.apply(lambda x: json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['estado'] if type(x['geocode_result']) is str else x['geocode_result']['estado'], axis=1)
df_vivienda_usada_arriendo['tipo_direccion'] = df_vivienda_usada_arriendo.apply(lambda x: None if 'tipo_direccion' not in json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0','')) else json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['tipo_direccion'] if type(x['geocode_result']) is str else x['geocode_result']['tipo_direccion'], axis=1)
df_vivienda_usada_arriendo['lat'] = df_vivienda_usada_arriendo.apply(lambda x: None if 'yinput' not in json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0','')) else json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['yinput'] if type(x['geocode_result']) is str else x['geocode_result']['yinput'], axis=1)
df_vivienda_usada_arriendo['lng'] = df_vivienda_usada_arriendo.apply(lambda x: None if 'xinput' not in json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0','')) else json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['xinput'] if type(x['geocode_result']) is str else x['geocode_result']['xinput'], axis=1)

# %%
df_vivienda_usada_arriendo['estado'].value_counts(normalize=True)
# Out:
# estado
# success     0.981410
# error_ws    0.013289
# failed      0.005300
# Name: proportion, dtype: float64

# %%
df_comercio_base_proyecto['geocode_result'] = df_comercio_base_proyecto[comercio_dir].swifter.apply(georeferenciar)
# Out:
# Pandas Apply:   0%|          | 0/1071 [00:00<?, ?it/s]

# %%
# Caso especial que parte de un xlsx intermedio (por eso es diferente a los samples)
df_comercio_base_proyecto['estado'] = df_comercio_base_proyecto.apply(lambda x: json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['estado'] if type(x['geocode_result']) is str else x['geocode_result']['estado'], axis=1)
df_comercio_base_proyecto['tipo_direccion'] = df_comercio_base_proyecto.apply(lambda x: None if 'tipo_direccion' not in json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0','')) else json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['tipo_direccion'] if type(x['geocode_result']) is str else x['geocode_result']['tipo_direccion'], axis=1)
df_comercio_base_proyecto['lat'] = df_comercio_base_proyecto.apply(lambda x: None if 'yinput' not in json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0','')) else json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['yinput'] if type(x['geocode_result']) is str else x['geocode_result']['yinput'], axis=1)
df_comercio_base_proyecto['lng'] = df_comercio_base_proyecto.apply(lambda x: None if 'xinput' not in json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0','')) else json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['xinput'] if type(x['geocode_result']) is str else x['geocode_result']['xinput'], axis=1)

# %%
df_comercio_base_proyecto['estado'].value_counts(normalize=True)
# Out:
# estado
# success    0.587302
# failed     0.412698
# Name: proportion, dtype: float64

# %%
df_comercio_base_proyecto[df_comercio_base_proyecto['Ciudad']=='Bogota']['estado'].value_counts(normalize=True)
# Out:
# estado
# success    0.587302
# failed     0.412698
# Name: proportion, dtype: float64

# %%
df_comercio_base_inmuebles['geocode_result'] = df_comercio_base_inmuebles[comercio_dir].swifter.apply(georeferenciar)
# Out:
# Pandas Apply:   0%|          | 0/7654 [00:00<?, ?it/s]

# %%
# Caso especial que parte de un xlsx intermedio (por eso es diferente a los samples)
df_comercio_base_inmuebles['estado'] = df_comercio_base_inmuebles.apply(lambda x: json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['estado'] if type(x['geocode_result']) is str else x['geocode_result']['estado'], axis=1)
df_comercio_base_inmuebles['tipo_direccion'] = df_comercio_base_inmuebles.apply(lambda x: None if 'tipo_direccion' not in json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0','')) else json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['tipo_direccion'] if type(x['geocode_result']) is str else x['geocode_result']['tipo_direccion'], axis=1)
df_comercio_base_inmuebles['lat'] = df_comercio_base_inmuebles.apply(lambda x: None if 'yinput' not in json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0','')) else json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['yinput'] if type(x['geocode_result']) is str else x['geocode_result']['yinput'], axis=1)
df_comercio_base_inmuebles['lng'] = df_comercio_base_inmuebles.apply(lambda x: None if 'xinput' not in json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0','')) else json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['xinput'] if type(x['geocode_result']) is str else x['geocode_result']['xinput'], axis=1)

# %%
df_comercio_base_inmuebles['estado'].value_counts(normalize=True)
# Out:
# estado
# success    0.606088
# failed     0.393912
# Name: proportion, dtype: float64

# %%
df_comercio_base_historia['geocode_result'] = df_comercio_base_historia[comercio_dir].swifter.apply(georeferenciar)
# Out:
# Pandas Apply:   0%|          | 0/1071 [00:00<?, ?it/s]

# %%
# Caso especial que parte de un xlsx intermedio (por eso es diferente a los samples)
df_comercio_base_historia['estado'] = df_comercio_base_historia.apply(lambda x: json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['estado'] if type(x['geocode_result']) is str else x['geocode_result']['estado'], axis=1)
df_comercio_base_historia['tipo_direccion'] = df_comercio_base_historia.apply(lambda x: None if 'tipo_direccion' not in json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0','')) else json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['tipo_direccion'] if type(x['geocode_result']) is str else x['geocode_result']['tipo_direccion'], axis=1)
df_comercio_base_historia['lat'] = df_comercio_base_historia.apply(lambda x: None if 'yinput' not in json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0','')) else json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['yinput'] if type(x['geocode_result']) is str else x['geocode_result']['yinput'], axis=1)
df_comercio_base_historia['lng'] = df_comercio_base_historia.apply(lambda x: None if 'xinput' not in json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0','')) else json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['xinput'] if type(x['geocode_result']) is str else x['geocode_result']['xinput'], axis=1)

# %%
df_comercio_base_historia['estado'].value_counts(normalize=True)
# Out:
# estado
# success    0.587302
# failed     0.412698
# Name: proportion, dtype: float64

# %%
df_def_base_proyecto['geocode_result'] = df_def_base_proyecto[def_dir].swifter.apply(georeferenciar)
# Out:
# Pandas Apply:   0%|          | 0/5311 [00:00<?, ?it/s]

# %%
# Caso especial que parte de un xlsx intermedio (por eso es diferente a los samples)
df_def_base_proyecto['estado'] = df_def_base_proyecto.apply(lambda x: json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['estado'] if type(x['geocode_result']) is str else x['geocode_result']['estado'], axis=1)
df_def_base_proyecto['tipo_direccion'] = df_def_base_proyecto.apply(lambda x: None if 'tipo_direccion' not in json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0','')) else json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['tipo_direccion'] if type(x['geocode_result']) is str else x['geocode_result']['tipo_direccion'], axis=1)
df_def_base_proyecto['lat'] = df_def_base_proyecto.apply(lambda x: None if 'yinput' not in json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0','')) else json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['yinput'] if type(x['geocode_result']) is str else x['geocode_result']['yinput'], axis=1)
df_def_base_proyecto['lng'] = df_def_base_proyecto.apply(lambda x: None if 'xinput' not in json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0','')) else json.loads(x['geocode_result'].replace("'",'"').replace('\\xa0',''))['xinput'] if type(x['geocode_result']) is str else x['geocode_result']['xinput'], axis=1)

# %%
df_def_base_proyecto['estado'].value_counts(normalize=True)
# Out:
# estado
# success     0.768217
# failed      0.231407
# error_ws    0.000377
# Name: proportion, dtype: float64

# %% [markdown]
# ## Generación de resultados

# %% [markdown]
# ### XLSX

# %%
df_vivienda_usada_venta.to_excel('MAYO/df_vivienda_usada_venta_v3.xlsx')

# %%
df_vivienda_usada_arriendo.to_excel('MAYO/df_vivienda_usada_arriendo_v3.xlsx')

# %%
df_comercio_base_proyecto.to_excel('MAYO/df_comercio_base_proyecto_v3.xlsx')

# %%
df_comercio_base_inmuebles.to_excel('MAYO/df_comercio_base_inmuebles_v3.xlsx')

# %%
df_comercio_base_historia.to_excel('MaAYO/df_comercio_base_historia_v3.xlsx')

# %%
df_def_base_proyecto.to_excel('MAYO/df_def_base_proyecto_v3.xlsx')

# %% [markdown]
# ### CSV

# %%
df_vivienda_usada_venta.to_csv('MAYO/df_vivienda_usada_venta_v3.csv')

# %%
df_vivienda_usada_arriendo.to_csv('MAYO/df_vivienda_usada_arriendo_v3.csv')

# %%
df_comercio_base_proyecto.to_csv('MAYO/df_comercio_base_proyecto_v3.csv')

# %%
df_comercio_base_inmuebles.to_csv('MAYO/df_comercio_base_inmuebles_v3.csv')

# %%
df_comercio_base_historia.to_csv('MAYO/df_comercio_base_historia_v3.csv')

# %%
df_def_base_proyecto.to_csv('MAYO/df_def_base_proyecto_v3.csv')

# %% [markdown]
# ### Geojson

# %%
df_vivienda_usada_venta['geocoded_geom'] = df_vivienda_usada_venta.apply(lambda x: Point(x['lng'],x['lat']), axis=1)
gpd.GeoDataFrame(df_vivienda_usada_venta, geometry='geocoded_geom', crs="EPSG:4326").to_file('MAYO/df_vivienda_usada_venta_v3.geojson', driver="GeoJSON")

# %%
df_vivienda_usada_arriendo['geocoded_geom'] = df_vivienda_usada_arriendo.apply(lambda x: Point(x['lng'],x['lat']), axis=1)
gpd.GeoDataFrame(df_vivienda_usada_arriendo, geometry='geocoded_geom', crs="EPSG:4326").to_file('MAYO/df_vivienda_usada_arriendo_v3.geojson', driver="GeoJSON")

# %%
df_comercio_base_proyecto['geocoded_geom'] = df_comercio_base_proyecto.apply(lambda x: Point(x['lng'],x['lat']), axis=1)
gpd.GeoDataFrame(df_comercio_base_proyecto, geometry='geocoded_geom', crs="EPSG:4326").to_file('MAYO/df_comercio_base_proyecto_v3.geojson', driver="GeoJSON")

# %%
df_comercio_base_inmuebles['geocoded_geom'] = df_comercio_base_inmuebles.apply(lambda x: Point(x['lng'],x['lat']), axis=1)
gpd.GeoDataFrame(df_comercio_base_inmuebles, geometry='geocoded_geom', crs="EPSG:4326").to_file('MAYO/df_comercio_base_inmuebles_v3.geojson', driver="GeoJSON")

# %%
df_comercio_base_historia['geocoded_geom'] = df_comercio_base_historia.apply(lambda x: Point(x['lng'],x['lat']), axis=1)
gpd.GeoDataFrame(df_comercio_base_historia, geometry='geocoded_geom', crs="EPSG:4326").to_file('MAYO/df_comercio_base_historia_v3.geojson', driver="GeoJSON")

# %%
df_def_base_proyecto['geocoded_geom'] = df_def_base_proyecto.apply(lambda x: Point(x['lng'],x['lat']), axis=1)

# %%
del df_def_base_proyecto['Dg(*)']
del df_def_base_proyecto['84(*)']
del df_def_base_proyecto['A']
del df_def_base_proyecto['Bis']
del df_def_base_proyecto['B']
del df_def_base_proyecto['Sur']
del df_def_base_proyecto['No. 8(*)']
del df_def_base_proyecto['C']
del df_def_base_proyecto[-62]
del df_def_base_proyecto['Este']

# %%
gpd.GeoDataFrame(df_def_base_proyecto, geometry='geocoded_geom', crs="EPSG:4326").to_file('MAYO/df_def_base_proyecto_v3.geojson', driver="GeoJSON")

# %%
df_def_base_proyecto['real_geom'] = df_def_base_proyecto.apply(lambda x: Point(x['Longitud\n(Coordenada Real)'],x['Latitud (Coordenada Real)']), axis=1)
del df_def_base_proyecto['geocoded_geom']
gpd.GeoDataFrame(df_def_base_proyecto, geometry='real_geom', crs="EPSG:4326").to_file('MAYO/df_def_base_proyecto_coord_real_v3.geojson', driver="GeoJSON")
